# %%
# Import dependency 
import numpy as np 
import torch 
import torch.optim as optim
import torch.nn as nn

# %%
# Data generation 
true_b = 1
true_w = 2 
N = 100

# set the random seed for numpy 
np.random.seed(43)

x= np.random.rand(N,1)
epsilon = (.1 * np.random.rand(N,1))

y = true_b + true_w *x + epsilon

# %%
#Generate training and validating sets
idx = np.arange(N)

# Use first 80 random indices for train 
train_idx = idx[:int(N*.8)]
val_idx = idx[int(N*.8):]

# Generate train and validation sets
x_train, y_train = x[train_idx], y[train_idx]

# %%
# Data preparation 

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Transform data from numpy array to torch tensor
x_train_tensor = torch.as_tensor(x_train).float().to(device)
y_train_tensor = torch.as_tensor(y_train).float().to(device)

# %%
# Build a Dataset
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, x_tensor, y_tensor):
        self.x = x_tensor
        self.y = y_tensor
    
    def __getitem__(self, index):
        return (self.x[index], self.y[index])
    
    def __len__(self):
        return len(self.x)

train_data = CustomDataset(x_train_tensor, y_train_tensor)
print(train_data[0])
print(len(train_data))
# Out:
# (tensor([0.1151]), tensor([1.2404]))
# 80

# %%
from torch.utils.data import DataLoader

# Build a data loader that yields mini-batches of size 2
train_loader = DataLoader(
        dataset=train_data,
        batch_size=2,
        shuffle=True
)
print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7f97f0bc4190>

# %%
print(next(iter(train_loader)))
# Out:
# [tensor([[0.6701],
#         [0.2544]]), tensor([[2.4077],
#         [1.6011]])]

# %%
#Define the train step

def make_train_step(model, loss_fn, optimizer):
    # Builds function that performs a step in the train loop 
    def perform_train_step(x,y):
        
        # Set the model to TRAIN mode
        model.train()
        
        # Step1: Compute the model's predicition - forward pass
        yhat = model(x)
        
        # Step2: Compute the loss
        loss = loss_fn(yhat, y)
        
        # Step3: Compute gradients for "b" and "w" parameters
        loss.backward()
        
        # Step4: Updates parameters using gradients and the learning rate
        optimizer.step()
        optimizer.zero_grad()
        
        #print(model.state_dict())
        # Return the loss 
        return loss.item()
    #Return the function that will be called inside the train loop
    return perform_train_step

# %%
# Model config 

# Define the model 
class ManualLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1,1)
    def forward(self,x):
        return self.linear(x)


# Set learning rate 
lr = 0.1

torch.manual_seed(42)

# Create a model and send it to the device 
model = ManualLinearRegression().to(device)
print(model.state_dict())

# Define a SGD optimizer to update the parameters 
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")


# Create a train_step 
train_step = make_train_step(model, loss_fn, optimizer)
# Out:
# OrderedDict([('linear.weight', tensor([[0.7645]])), ('linear.bias', tensor([0.8300]))])

# %%
# Model training

n_epochs = 1000
losses = []
for epoch in range(n_epochs):
    
    # Add the inner loop to fetch the data
    mini_batch_losses = []
    for x_batch, y_batch in train_loader:
        #The dataset "lives" in the CPU, so do our mini-batches
        # we need send to mini-batches to the device 
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        
        # Performs one train step and returns the corresonding loss 
        mini_batch_loss = train_step(x_batch, y_batch)
        mini_batch_losses.append(mini_batch_loss)
        
        
    # Compute average loss over all mini-batches
    loss = np.mean(mini_batch_loss)
    losses.append(loss)
# Out:
# OrderedDict([('linear.weight', tensor([[0.9270]])), ('linear.bias', tensor([1.0402]))])
# OrderedDict([('linear.weight', tensor([[0.9615]])), ('linear.bias', tensor([1.1255]))])
# OrderedDict([('linear.weight', tensor([[1.0181]])), ('linear.bias', tensor([1.2145]))])
# OrderedDict([('linear.weight', tensor([[1.0480]])), ('linear.bias', tensor([1.2750]))])
# OrderedDict([('linear.weight', tensor([[1.1444]])), ('linear.bias', tensor([1.3914]))])
# OrderedDict([('linear.weight', tensor([[1.1813]])), ('linear.bias', tensor([1.4218]))])
# OrderedDict([('linear.weight', tensor([[1.1819]])), ('linear.bias', tensor([1.4188]))])
# OrderedDict([('linear.weight', tensor([[1.2366]])), ('linear.bias', tensor([1.4812]))])
# OrderedDict([('linear.weight', tensor([[1.2485]])), ('linear.bias', tensor([1.4505]))])
# OrderedDict([('linear.weight', tensor([[1.2436]])), ('linear.bias', tensor([1.3844]))])
# OrderedDict([('linear.weight', tensor([[1.2379]])), ('linear.bias', tensor([1.3640]))])
# OrderedDict([('linear.weight', tensor([[1.2404]])), ('linear.bias', tensor([1.3675]))])
# OrderedDict([('linear.weight', tensor([[1.2364]])), ('linear.bias', tensor([1.3546]))])
# OrderedDict([('linear.weight', tensor([[1.2672]])), ('linear.bias', tensor([1.3759]))])
# OrderedDict([('linear.weight', tensor([[1.2970]])), ('linear.bias', tensor([1.3822]))])
# OrderedDict([('linear.weight', tensor([[1.3122]])), ('linear.bias', tensor([1.4046]))])
# OrderedDict([('linear.weight', tensor([[1.3260]])), ('linear.bias', tensor([1.3983]))])
# OrderedDict([('linear.weight', tensor([[1.3248]])), ('linear.bias', tensor([1.3717]))])
# OrderedDict([('linear.weight', tensor([[1.3393]])), ('linear.bias', tensor([1.3884]))])
# OrderedDict([('linear.weight', tensor([[1.3491]])), ('linear.bias', tensor([1.4035]))])
# OrderedDict([('linear.weight', tensor([[1.3793]])), ('linear.bias', tensor([1.4390]))])
# OrderedDict([('linear.weight', tensor([[1.3816]])), ('linear.bias', tensor([1.4299]))])
# OrderedDict([('linear.weight', tensor([[1.3727]])), ('linear.bias', tensor([1.3816]))])
# OrderedDict([('linear.weight', tensor([[1.3935]])), ('linear.bias', tensor([1.4069]))])
# OrderedDict([('linear.weight', tensor([[1.4123]])), ('linear.bias', tensor([1.4066]))])
# OrderedDict([('linear.weight', tensor([[1.4042]])), ('linear.bias', tensor([1.3887]))])
# OrderedDict([('linear.weight', tensor([[1.4148]])), ('linear.bias', tensor([1.3935]))])
# OrderedDict([('linear.weight', tensor([[1.4261]])), ('linear.bias', tensor([1.4029]))])
# OrderedDict([('linear.weight', tensor([[1.4428]])), ('linear.bias', tensor([1.4199]))])
# OrderedDict([('linear.weight', tensor([[1.4659]])), ('linear.bias', tensor([1.4460]))])
# OrderedDict([('linear.weight', tensor([[1.4710]])), ('linear.bias', tensor([1.4502]))])
# OrderedDict([('linear.weight', tensor([[1.4560]])), ('linear.bias', tensor([1.3994]))])
# OrderedDict([('linear.weight', tensor([[1.4478]])), ('linear.bias', tensor([1.3717]))])
# OrderedDict([('linear.weight', tensor([[1.4490]])), ('linear.bias', tensor([1.3472]))])
# OrderedDict([('linear.weight', tensor([[1.4624]])), ('linear.bias', tensor([1.3664]))])
# OrderedDict([('linear.weight', tensor([[1.4526]])), ('linear.bias', tensor([1.3257]))])
# OrderedDict([('linear.weight', tensor([[1.4693]])), ('linear.bias', tensor([1.3413]))])
# OrderedDict([('linear.weight', tensor([[1.4664]])), ('linear.bias', tensor([1.3275]))])
# OrderedDict([('linear.weight', tensor([[1.4658]])), ('linear.bias', tensor([1.3072]))])
# OrderedDict([('linear.weight', tensor([[1.4592]])), ('linear.bias', tensor([1.2697]))])
# OrderedDict([('linear.weight', tensor([[1.4689]])), ('linear.bias', tensor([1.2817]))])
# OrderedDict([('linear.weight', tensor([[1.4666]])), ('linear.bias', tensor([1.2708]))])
# OrderedDict([('linear.weight', tensor([[1.5148]])), ('linear.bias', tensor([1.3229]))])
# OrderedDict([('linear.weight', tensor([[1.5092]])), ('linear.bias', tensor([1.2835]))])
# OrderedDict([('linear.weight', tensor([[1.5185]])), ('linear.bias', tensor([1.2984]))])
# OrderedDict([('linear.weight', tensor([[1.5238]])), ('linear.bias', tensor([1.3041]))])
# OrderedDict([('linear.weight', tensor([[1.5376]])), ('linear.bias', tensor([1.3041]))])
# OrderedDict([('linear.weight', tensor([[1.5304]])), ('linear.bias', tensor([1.2794]))])
# OrderedDict([('linear.weight', tensor([[1.5469]])), ('linear.bias', tensor([1.2841]))])
# OrderedDict([('linear.weight', tensor([[1.5410]])), ('linear.bias', tensor([1.2669]))])
# OrderedDict([('linear.weight', tensor([[1.5537]])), ('linear.bias', tensor([1.2746]))])
# OrderedDict([('linear.weight', tensor([[1.5737]])), ('linear.bias', tensor([1.3023]))])
# OrderedDict([('linear.weight', tensor([[1.5715]])), ('linear.bias', tensor([1.2802]))])
# OrderedDict([('linear.weight', tensor([[1.5735]])), ('linear.bias', tensor([1.2810]))])
# OrderedDict([('linear.weight', tensor([[1.5810]])), ('linear.bias', tensor([1.2736]))])
# OrderedDict([('linear.weight', tensor([[1.5867]])), ('linear.bias', tensor([1.2687]))])
# OrderedDict([('linear.weight', tensor([[1.5811]])), ('linear.bias', tensor([1.2372]))])
# OrderedDict([('linear.weight', tensor([[1.5856]])), ('linear.bias', tensor([1.2455]))])
# OrderedDict([('linear.weight', tensor([[1.5856]])), ('linear.bias', tensor([1.2390]))])
# OrderedDict([('linear.weight', tensor([[1.5867]])), ('linear.bias', tensor([1.2386]))])
# OrderedDict([('linear.weight', tensor([[1.5835]])), ('linear.bias', tensor([1.2240]))])
# OrderedDict([('linear.weight', tensor([[1.5881]])), ('linear.bias', tensor([1.2295]))])
# OrderedDict([('linear.weight', tensor([[1.6103]])), ('linear.bias', tensor([1.2561]))])
# OrderedDict([('linear.weight', tensor([[1.6108]])), ('linear.bias', tensor([1.2562]))])
# OrderedDict([('linear.weight', tensor([[1.6190]])), ('linear.bias', tensor([1.2613]))])
# OrderedDict([('linear.weight', tensor([[1.6193]])), ('linear.bias', tensor([1.2476]))])
# OrderedDict([('linear.weight', tensor([[1.6250]])), ('linear.bias', tensor([1.2526]))])
# OrderedDict([('linear.weight', tensor([[1.6492]])), ('linear.bias', tensor([1.2800]))])
# OrderedDict([('linear.weight', tensor([[1.6571]])), ('linear.bias', tensor([1.2621]))])
# OrderedDict([('linear.weight', tensor([[1.6797]])), ('linear.bias', tensor([1.2855]))])
# OrderedDict([('linear.weight', tensor([[1.6729]])), ('linear.bias', tensor([1.2635]))])
# OrderedDict([('linear.weight', tensor([[1.6808]])), ('linear.bias', tensor([1.2724]))])
# OrderedDict([('linear.weight', tensor([[1.6759]])), ('linear.bias', tensor([1.2560]))])
# OrderedDict([('linear.weight', tensor([[1.6715]])), ('linear.bias', tensor([1.2308]))])
# OrderedDict([('linear.weight', tensor([[1.6793]])), ('linear.bias', tensor([1.2394]))])
# OrderedDict([('linear.weight', tensor([[1.6746]])), ('linear.bias', tensor([1.2201]))])
# OrderedDict([('linear.weight', tensor([[1.6851]])), ('linear.bias', tensor([1.2221]))])
# OrderedDict([('linear.weight', tensor([[1.6932]])), ('linear.bias', tensor([1.2328]))])
# OrderedDict([('linear.weight', tensor([[1.6896]])), ('linear.bias', tensor([1.2162]))])
# OrderedDict([('linear.weight', tensor([[1.7008]])), ('linear.bias', tensor([1.2279]))])
# OrderedDict([('linear.weight', tensor([[1.7081]])), ('linear.bias', tensor([1.2195]))])
# OrderedDict([('linear.weight', tensor([[1.7135]])), ('linear.bias', tensor([1.2223]))])
# OrderedDict([('linear.weight', tensor([[1.7092]])), ('linear.bias', tensor([1.2036]))])
# OrderedDict([('linear.weight', tensor([[1.7290]])), ('linear.bias', tensor([1.2253]))])
# OrderedDict([('linear.weight', tensor([[1.7273]])), ('linear.bias', tensor([1.2188]))])
# OrderedDict([('linear.weight', tensor([[1.7236]])), ('linear.bias', tensor([1.2053]))])
# OrderedDict([('linear.weight', tensor([[1.7216]])), ('linear.bias', tensor([1.1931]))])
# OrderedDict([('linear.weight', tensor([[1.7324]])), ('linear.bias', tensor([1.2049]))])
# OrderedDict([('linear.weight', tensor([[1.7262]])), ('linear.bias', tensor([1.1912]))])
# OrderedDict([('linear.weight', tensor([[1.7264]])), ('linear.bias', tensor([1.1901]))])
# OrderedDict([('linear.weight', tensor([[1.7333]])), ('linear.bias', tensor([1.2007]))])
# OrderedDict([('linear.weight', tensor([[1.7290]])), ('linear.bias', tensor([1.1904]))])
# OrderedDict([('linear.weight', tensor([[1.7391]])), ('linear.bias', tensor([1.1905]))])
# OrderedDict([('linear.weight', tensor([[1.7377]])), ('linear.bias', tensor([1.1714]))])
# OrderedDict([('linear.weight', tensor([[1.7528]])), ('linear.bias', tensor([1.1892]))])
# OrderedDict([('linear.weight', tensor([[1.7623]])), ('linear.bias', tensor([1.2021]))])
# OrderedDict([('linear.weight', tensor([[1.7665]])), ('linear.bias', tensor([1.2058]))])
# OrderedDict([('linear.weight', tensor([[1.7651]])), ('linear.bias', tensor([1.1962]))])
# OrderedDict([('linear.weight', tensor([[1.7621]])), ('linear.bias', tensor([1.1861]))])
# OrderedDict([('linear.weight', tensor([[1.7718]])), ('linear.bias', tensor([1.1877]))])
# OrderedDict([('linear.weight', tensor([[1.7753]])), ('linear.bias', tensor([1.1800]))])
# OrderedDict([('linear.weight', tensor([[1.7725]])), ('linear.bias', tensor([1.1759]))])
# OrderedDict([('linear.weight', tensor([[1.7675]])), ('linear.bias', tensor([1.1618]))])
# OrderedDict([('linear.weight', tensor([[1.7764]])), ('linear.bias', tensor([1.1730]))])
# OrderedDict([('linear.weight', tensor([[1.7905]])), ('linear.bias', tensor([1.1902]))])
# OrderedDict([('linear.weight', tensor([[1.7851]])), ('linear.bias', tensor([1.1763]))])
# OrderedDict([('linear.weight', tensor([[1.7816]])), ('linear.bias', tensor([1.1626]))])
# OrderedDict([('linear.weight', tensor([[1.7791]])), ('linear.bias', tensor([1.1517]))])
# OrderedDict([('linear.weight', tensor([[1.7785]])), ('linear.bias', tensor([1.1342]))])
# OrderedDict([('linear.weight', tensor([[1.7906]])), ('linear.bias', tensor([1.1519]))])
# OrderedDict([('linear.weight', tensor([[1.7917]])), ('linear.bias', tensor([1.1535]))])
# OrderedDict([('linear.weight', tensor([[1.7977]])), ('linear.bias', tensor([1.1560]))])
# OrderedDict([('linear.weight', tensor([[1.8010]])), ('linear.bias', tensor([1.1544]))])
# OrderedDict([('linear.weight', tensor([[1.8078]])), ('linear.bias', tensor([1.1614]))])
# OrderedDict([('linear.weight', tensor([[1.8111]])), ('linear.bias', tensor([1.1541]))])
# OrderedDict([('linear.weight', tensor([[1.8105]])), ('linear.bias', tensor([1.1483]))])
# OrderedDict([('linear.weight', tensor([[1.8140]])), ('linear.bias', tensor([1.1490]))])
# OrderedDict([('linear.weight', tensor([[1.8160]])), ('linear.bias', tensor([1.1488]))])
# OrderedDict([('linear.weight', tensor([[1.8150]])), ('linear.bias', tensor([1.1463]))])
# OrderedDict([('linear.weight', tensor([[1.8254]])), ('linear.bias', tensor([1.1584]))])
# OrderedDict([('linear.weight', tensor([[1.8290]])), ('linear.bias', tensor([1.1506]))])
# OrderedDict([('linear.weight', tensor([[1.8246]])), ('linear.bias', tensor([1.1405]))])
# OrderedDict([('linear.weight', tensor([[1.8260]])), ('linear.bias', tensor([1.1384]))])
# OrderedDict([('linear.weight', tensor([[1.8233]])), ('linear.bias', tensor([1.1272]))])
# OrderedDict([('linear.weight', tensor([[1.8307]])), ('linear.bias', tensor([1.1346]))])
# OrderedDict([('linear.weight', tensor([[1.8376]])), ('linear.bias', tensor([1.1441]))])
# OrderedDict([('linear.weight', tensor([[1.8415]])), ('linear.bias', tensor([1.1455]))])
# OrderedDict([('linear.weight', tensor([[1.8407]])), ('linear.bias', tensor([1.1390]))])
# OrderedDict([('linear.weight', tensor([[1.8365]])), ('linear.bias', tensor([1.1259]))])
# OrderedDict([('linear.weight', tensor([[1.8443]])), ('linear.bias', tensor([1.1351]))])
# OrderedDict([('linear.weight', tensor([[1.8431]])), ('linear.bias', tensor([1.1315]))])
# OrderedDict([('linear.weight', tensor([[1.8457]])), ('linear.bias', tensor([1.1244]))])
# OrderedDict([('linear.weight', tensor([[1.8438]])), ('linear.bias', tensor([1.1155]))])
# OrderedDict([('linear.weight', tensor([[1.8452]])), ('linear.bias', tensor([1.1154]))])
# OrderedDict([('linear.weight', tensor([[1.8536]])), ('linear.bias', tensor([1.1273]))])
# OrderedDict([('linear.weight', tensor([[1.8592]])), ('linear.bias', tensor([1.1291]))])
# OrderedDict([('linear.weight', tensor([[1.8655]])), ('linear.bias', tensor([1.1350]))])
# OrderedDict([('linear.weight', tensor([[1.8673]])), ('linear.bias', tensor([1.1274]))])
# OrderedDict([('linear.weight', tensor([[1.8694]])), ('linear.bias', tensor([1.1278]))])
# OrderedDict([('linear.weight', tensor([[1.8701]])), ('linear.bias', tensor([1.1278]))])
# OrderedDict([('linear.weight', tensor([[1.8743]])), ('linear.bias', tensor([1.1338]))])
# OrderedDict([('linear.weight', tensor([[1.8688]])), ('linear.bias', tensor([1.1234]))])
# OrderedDict([('linear.weight', tensor([[1.8690]])), ('linear.bias', tensor([1.1238]))])
# OrderedDict([('linear.weight', tensor([[1.8759]])), ('linear.bias', tensor([1.1325]))])
# OrderedDict([('linear.weight', tensor([[1.8783]])), ('linear.bias', tensor([1.1321]))])
# OrderedDict([('linear.weight', tensor([[1.8771]])), ('linear.bias', tensor([1.1303]))])
# OrderedDict([('linear.weight', tensor([[1.8758]])), ('linear.bias', tensor([1.1197]))])
# OrderedDict([('linear.weight', tensor([[1.8806]])), ('linear.bias', tensor([1.1250]))])
# OrderedDict([('linear.weight', tensor([[1.8823]])), ('linear.bias', tensor([1.1255]))])
# OrderedDict([('linear.weight', tensor([[1.8808]])), ('linear.bias', tensor([1.1068]))])
# OrderedDict([('linear.weight', tensor([[1.8813]])), ('linear.bias', tensor([1.1082]))])
# OrderedDict([('linear.weight', tensor([[1.8796]])), ('linear.bias', tensor([1.1015]))])
# OrderedDict([('linear.weight', tensor([[1.8799]])), ('linear.bias', tensor([1.1028]))])
# OrderedDict([('linear.weight', tensor([[1.8854]])), ('linear.bias', tensor([1.1125]))])
# OrderedDict([('linear.weight', tensor([[1.8837]])), ('linear.bias', tensor([1.1078]))])
# OrderedDict([('linear.weight', tensor([[1.8851]])), ('linear.bias', tensor([1.1087]))])
# OrderedDict([('linear.weight', tensor([[1.8871]])), ('linear.bias', tensor([1.1123]))])
# OrderedDict([('linear.weight', tensor([[1.8859]])), ('linear.bias', tensor([1.1078]))])
# OrderedDict([('linear.weight', tensor([[1.8923]])), ('linear.bias', tensor([1.1165]))])
# OrderedDict([('linear.weight', tensor([[1.8940]])), ('linear.bias', tensor([1.1203]))])
# OrderedDict([('linear.weight', tensor([[1.8962]])), ('linear.bias', tensor([1.1198]))])
# OrderedDict([('linear.weight', tensor([[1.8939]])), ('linear.bias', tensor([1.1141]))])
# OrderedDict([('linear.weight', tensor([[1.8933]])), ('linear.bias', tensor([1.1125]))])
# OrderedDict([('linear.weight', tensor([[1.8901]])), ('linear.bias', tensor([1.1023]))])
# OrderedDict([('linear.weight', tensor([[1.8925]])), ('linear.bias', tensor([1.1065]))])
# OrderedDict([('linear.weight', tensor([[1.8928]])), ('linear.bias', tensor([1.1069]))])
# OrderedDict([('linear.weight', tensor([[1.8917]])), ('linear.bias', tensor([1.0963]))])
# OrderedDict([('linear.weight', tensor([[1.8961]])), ('linear.bias', tensor([1.1016]))])
# OrderedDict([('linear.weight', tensor([[1.8972]])), ('linear.bias', tensor([1.1011]))])
# OrderedDict([('linear.weight', tensor([[1.9050]])), ('linear.bias', tensor([1.1099]))])
# OrderedDict([('linear.weight', tensor([[1.9091]])), ('linear.bias', tensor([1.1151]))])
# OrderedDict([('linear.weight', tensor([[1.9082]])), ('linear.bias', tensor([1.1138]))])
# OrderedDict([('linear.weight', tensor([[1.9068]])), ('linear.bias', tensor([1.1065]))])
# OrderedDict([('linear.weight', tensor([[1.9048]])), ('linear.bias', tensor([1.1032]))])
# OrderedDict([('linear.weight', tensor([[1.9066]])), ('linear.bias', tensor([1.0978]))])
# OrderedDict([('linear.weight', tensor([[1.9171]])), ('linear.bias', tensor([1.1090]))])
# OrderedDict([('linear.weight', tensor([[1.9180]])), ('linear.bias', tensor([1.1087]))])
# OrderedDict([('linear.weight', tensor([[1.9215]])), ('linear.bias', tensor([1.1139]))])
# OrderedDict([('linear.weight', tensor([[1.9197]])), ('linear.bias', tensor([1.1015]))])
# OrderedDict([('linear.weight', tensor([[1.9194]])), ('linear.bias', tensor([1.0936]))])
# OrderedDict([('linear.weight', tensor([[1.9256]])), ('linear.bias', tensor([1.1013]))])
# OrderedDict([('linear.weight', tensor([[1.9225]])), ('linear.bias', tensor([1.0851]))])
# OrderedDict([('linear.weight', tensor([[1.9265]])), ('linear.bias', tensor([1.0920]))])
# OrderedDict([('linear.weight', tensor([[1.9274]])), ('linear.bias', tensor([1.0943]))])
# OrderedDict([('linear.weight', tensor([[1.9306]])), ('linear.bias', tensor([1.0955]))])
# OrderedDict([('linear.weight', tensor([[1.9304]])), ('linear.bias', tensor([1.0939]))])
# OrderedDict([('linear.weight', tensor([[1.9290]])), ('linear.bias', tensor([1.0898]))])
# OrderedDict([('linear.weight', tensor([[1.9290]])), ('linear.bias', tensor([1.0895]))])
# OrderedDict([('linear.weight', tensor([[1.9255]])), ('linear.bias', tensor([1.0781]))])
# OrderedDict([('linear.weight', tensor([[1.9258]])), ('linear.bias', tensor([1.0770]))])
# OrderedDict([('linear.weight', tensor([[1.9286]])), ('linear.bias', tensor([1.0834]))])
# OrderedDict([('linear.weight', tensor([[1.9262]])), ('linear.bias', tensor([1.0771]))])
# OrderedDict([('linear.weight', tensor([[1.9248]])), ('linear.bias', tensor([1.0724]))])
# OrderedDict([('linear.weight', tensor([[1.9258]])), ('linear.bias', tensor([1.0766]))])
# OrderedDict([('linear.weight', tensor([[1.9320]])), ('linear.bias', tensor([1.0862]))])
# OrderedDict([('linear.weight', tensor([[1.9371]])), ('linear.bias', tensor([1.0926]))])
# OrderedDict([('linear.weight', tensor([[1.9410]])), ('linear.bias', tensor([1.0982]))])
# OrderedDict([('linear.weight', tensor([[1.9401]])), ('linear.bias', tensor([1.0937]))])
# OrderedDict([('linear.weight', tensor([[1.9346]])), ('linear.bias', tensor([1.0865]))])
# OrderedDict([('linear.weight', tensor([[1.9357]])), ('linear.bias', tensor([1.0897]))])
# OrderedDict([('linear.weight', tensor([[1.9355]])), ('linear.bias', tensor([1.0892]))])
# OrderedDict([('linear.weight', tensor([[1.9347]])), ('linear.bias', tensor([1.0858]))])
# OrderedDict([('linear.weight', tensor([[1.9384]])), ('linear.bias', tensor([1.0909]))])
# OrderedDict([('linear.weight', tensor([[1.9417]])), ('linear.bias', tensor([1.0961]))])
# OrderedDict([('linear.weight', tensor([[1.9350]])), ('linear.bias', tensor([1.0873]))])
# OrderedDict([('linear.weight', tensor([[1.9385]])), ('linear.bias', tensor([1.0922]))])
# OrderedDict([('linear.weight', tensor([[1.9377]])), ('linear.bias', tensor([1.0835]))])
# OrderedDict([('linear.weight', tensor([[1.9419]])), ('linear.bias', tensor([1.0901]))])
# OrderedDict([('linear.weight', tensor([[1.9386]])), ('linear.bias', tensor([1.0799]))])
# OrderedDict([('linear.weight', tensor([[1.9451]])), ('linear.bias', tensor([1.0885]))])
# OrderedDict([('linear.weight', tensor([[1.9453]])), ('linear.bias', tensor([1.0883]))])
# OrderedDict([('linear.weight', tensor([[1.9443]])), ('linear.bias', tensor([1.0778]))])
# OrderedDict([('linear.weight', tensor([[1.9492]])), ('linear.bias', tensor([1.0844]))])
# OrderedDict([('linear.weight', tensor([[1.9525]])), ('linear.bias', tensor([1.0898]))])
# OrderedDict([('linear.weight', tensor([[1.9488]])), ('linear.bias', tensor([1.0845]))])
# OrderedDict([('linear.weight', tensor([[1.9514]])), ('linear.bias', tensor([1.0871]))])
# OrderedDict([('linear.weight', tensor([[1.9514]])), ('linear.bias', tensor([1.0844]))])
# OrderedDict([('linear.weight', tensor([[1.9530]])), ('linear.bias', tensor([1.0856]))])
# OrderedDict([('linear.weight', tensor([[1.9510]])), ('linear.bias', tensor([1.0814]))])
# OrderedDict([('linear.weight', tensor([[1.9545]])), ('linear.bias', tensor([1.0863]))])
# OrderedDict([('linear.weight', tensor([[1.9542]])), ('linear.bias', tensor([1.0842]))])
# OrderedDict([('linear.weight', tensor([[1.9529]])), ('linear.bias', tensor([1.0775]))])
# OrderedDict([('linear.weight', tensor([[1.9510]])), ('linear.bias', tensor([1.0745]))])
# OrderedDict([('linear.weight', tensor([[1.9539]])), ('linear.bias', tensor([1.0799]))])
# OrderedDict([('linear.weight', tensor([[1.9545]])), ('linear.bias', tensor([1.0762]))])
# OrderedDict([('linear.weight', tensor([[1.9523]])), ('linear.bias', tensor([1.0688]))])
# OrderedDict([('linear.weight', tensor([[1.9547]])), ('linear.bias', tensor([1.0754]))])
# OrderedDict([('linear.weight', tensor([[1.9569]])), ('linear.bias', tensor([1.0764]))])
# OrderedDict([('linear.weight', tensor([[1.9542]])), ('linear.bias', tensor([1.0699]))])
# OrderedDict([('linear.weight', tensor([[1.9545]])), ('linear.bias', tensor([1.0731]))])
# OrderedDict([('linear.weight', tensor([[1.9545]])), ('linear.bias', tensor([1.0727]))])
# OrderedDict([('linear.weight', tensor([[1.9539]])), ('linear.bias', tensor([1.0719]))])
# OrderedDict([('linear.weight', tensor([[1.9536]])), ('linear.bias', tensor([1.0686]))])
# OrderedDict([('linear.weight', tensor([[1.9528]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[1.9561]])), ('linear.bias', tensor([1.0651]))])
# OrderedDict([('linear.weight', tensor([[1.9546]])), ('linear.bias', tensor([1.0627]))])
# OrderedDict([('linear.weight', tensor([[1.9535]])), ('linear.bias', tensor([1.0609]))])
# OrderedDict([('linear.weight', tensor([[1.9577]])), ('linear.bias', tensor([1.0655]))])
# OrderedDict([('linear.weight', tensor([[1.9580]])), ('linear.bias', tensor([1.0657]))])
# OrderedDict([('linear.weight', tensor([[1.9612]])), ('linear.bias', tensor([1.0699]))])
# OrderedDict([('linear.weight', tensor([[1.9614]])), ('linear.bias', tensor([1.0703]))])
# OrderedDict([('linear.weight', tensor([[1.9633]])), ('linear.bias', tensor([1.0725]))])
# OrderedDict([('linear.weight', tensor([[1.9669]])), ('linear.bias', tensor([1.0776]))])
# OrderedDict([('linear.weight', tensor([[1.9675]])), ('linear.bias', tensor([1.0777]))])
# OrderedDict([('linear.weight', tensor([[1.9622]])), ('linear.bias', tensor([1.0660]))])
# OrderedDict([('linear.weight', tensor([[1.9607]])), ('linear.bias', tensor([1.0631]))])
# OrderedDict([('linear.weight', tensor([[1.9629]])), ('linear.bias', tensor([1.0679]))])
# OrderedDict([('linear.weight', tensor([[1.9625]])), ('linear.bias', tensor([1.0668]))])
# OrderedDict([('linear.weight', tensor([[1.9637]])), ('linear.bias', tensor([1.0709]))])
# OrderedDict([('linear.weight', tensor([[1.9639]])), ('linear.bias', tensor([1.0738]))])
# OrderedDict([('linear.weight', tensor([[1.9683]])), ('linear.bias', tensor([1.0786]))])
# OrderedDict([('linear.weight', tensor([[1.9691]])), ('linear.bias', tensor([1.0795]))])
# OrderedDict([('linear.weight', tensor([[1.9655]])), ('linear.bias', tensor([1.0715]))])
# OrderedDict([('linear.weight', tensor([[1.9634]])), ('linear.bias', tensor([1.0694]))])
# OrderedDict([('linear.weight', tensor([[1.9641]])), ('linear.bias', tensor([1.0712]))])
# OrderedDict([('linear.weight', tensor([[1.9660]])), ('linear.bias', tensor([1.0782]))])
# OrderedDict([('linear.weight', tensor([[1.9650]])), ('linear.bias', tensor([1.0759]))])
# OrderedDict([('linear.weight', tensor([[1.9681]])), ('linear.bias', tensor([1.0803]))])
# OrderedDict([('linear.weight', tensor([[1.9716]])), ('linear.bias', tensor([1.0864]))])
# OrderedDict([('linear.weight', tensor([[1.9739]])), ('linear.bias', tensor([1.0904]))])
# OrderedDict([('linear.weight', tensor([[1.9706]])), ('linear.bias', tensor([1.0869]))])
# OrderedDict([('linear.weight', tensor([[1.9682]])), ('linear.bias', tensor([1.0771]))])
# OrderedDict([('linear.weight', tensor([[1.9659]])), ('linear.bias', tensor([1.0718]))])
# OrderedDict([('linear.weight', tensor([[1.9689]])), ('linear.bias', tensor([1.0739]))])
# OrderedDict([('linear.weight', tensor([[1.9681]])), ('linear.bias', tensor([1.0715]))])
# OrderedDict([('linear.weight', tensor([[1.9714]])), ('linear.bias', tensor([1.0785]))])
# OrderedDict([('linear.weight', tensor([[1.9691]])), ('linear.bias', tensor([1.0685]))])
# OrderedDict([('linear.weight', tensor([[1.9671]])), ('linear.bias', tensor([1.0621]))])
# OrderedDict([('linear.weight', tensor([[1.9684]])), ('linear.bias', tensor([1.0639]))])
# OrderedDict([('linear.weight', tensor([[1.9668]])), ('linear.bias', tensor([1.0613]))])
# OrderedDict([('linear.weight', tensor([[1.9693]])), ('linear.bias', tensor([1.0666]))])
# OrderedDict([('linear.weight', tensor([[1.9672]])), ('linear.bias', tensor([1.0610]))])
# OrderedDict([('linear.weight', tensor([[1.9653]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9664]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[1.9694]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[1.9673]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9670]])), ('linear.bias', tensor([1.0511]))])
# OrderedDict([('linear.weight', tensor([[1.9729]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9725]])), ('linear.bias', tensor([1.0550]))])
# OrderedDict([('linear.weight', tensor([[1.9726]])), ('linear.bias', tensor([1.0546]))])
# OrderedDict([('linear.weight', tensor([[1.9731]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9725]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9748]])), ('linear.bias', tensor([1.0621]))])
# OrderedDict([('linear.weight', tensor([[1.9771]])), ('linear.bias', tensor([1.0631]))])
# OrderedDict([('linear.weight', tensor([[1.9752]])), ('linear.bias', tensor([1.0593]))])
# OrderedDict([('linear.weight', tensor([[1.9712]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9743]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[1.9714]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9719]])), ('linear.bias', tensor([1.0594]))])
# OrderedDict([('linear.weight', tensor([[1.9707]])), ('linear.bias', tensor([1.0596]))])
# OrderedDict([('linear.weight', tensor([[1.9713]])), ('linear.bias', tensor([1.0628]))])
# OrderedDict([('linear.weight', tensor([[1.9715]])), ('linear.bias', tensor([1.0653]))])
# OrderedDict([('linear.weight', tensor([[1.9748]])), ('linear.bias', tensor([1.0692]))])
# OrderedDict([('linear.weight', tensor([[1.9782]])), ('linear.bias', tensor([1.0748]))])
# OrderedDict([('linear.weight', tensor([[1.9761]])), ('linear.bias', tensor([1.0706]))])
# OrderedDict([('linear.weight', tensor([[1.9792]])), ('linear.bias', tensor([1.0767]))])
# OrderedDict([('linear.weight', tensor([[1.9775]])), ('linear.bias', tensor([1.0678]))])
# OrderedDict([('linear.weight', tensor([[1.9804]])), ('linear.bias', tensor([1.0696]))])
# OrderedDict([('linear.weight', tensor([[1.9778]])), ('linear.bias', tensor([1.0651]))])
# OrderedDict([('linear.weight', tensor([[1.9780]])), ('linear.bias', tensor([1.0619]))])
# OrderedDict([('linear.weight', tensor([[1.9784]])), ('linear.bias', tensor([1.0600]))])
# OrderedDict([('linear.weight', tensor([[1.9817]])), ('linear.bias', tensor([1.0588]))])
# OrderedDict([('linear.weight', tensor([[1.9824]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[1.9813]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9801]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9813]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9790]])), ('linear.bias', tensor([1.0543]))])
# OrderedDict([('linear.weight', tensor([[1.9828]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[1.9812]])), ('linear.bias', tensor([1.0531]))])
# OrderedDict([('linear.weight', tensor([[1.9856]])), ('linear.bias', tensor([1.0601]))])
# OrderedDict([('linear.weight', tensor([[1.9860]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9881]])), ('linear.bias', tensor([1.0579]))])
# OrderedDict([('linear.weight', tensor([[1.9873]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9890]])), ('linear.bias', tensor([1.0596]))])
# OrderedDict([('linear.weight', tensor([[1.9884]])), ('linear.bias', tensor([1.0615]))])
# OrderedDict([('linear.weight', tensor([[1.9887]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[1.9880]])), ('linear.bias', tensor([1.0587]))])
# OrderedDict([('linear.weight', tensor([[1.9882]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9897]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[1.9892]])), ('linear.bias', tensor([1.0604]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[1.9923]])), ('linear.bias', tensor([1.0613]))])
# OrderedDict([('linear.weight', tensor([[1.9911]])), ('linear.bias', tensor([1.0613]))])
# OrderedDict([('linear.weight', tensor([[1.9913]])), ('linear.bias', tensor([1.0633]))])
# OrderedDict([('linear.weight', tensor([[1.9920]])), ('linear.bias', tensor([1.0650]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0658]))])
# OrderedDict([('linear.weight', tensor([[1.9896]])), ('linear.bias', tensor([1.0609]))])
# OrderedDict([('linear.weight', tensor([[1.9887]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9886]])), ('linear.bias', tensor([1.0608]))])
# OrderedDict([('linear.weight', tensor([[1.9842]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[1.9862]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9855]])), ('linear.bias', tensor([1.0490]))])
# OrderedDict([('linear.weight', tensor([[1.9877]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9891]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9907]])), ('linear.bias', tensor([1.0584]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0612]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0601]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0627]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0701]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0668]))])
# OrderedDict([('linear.weight', tensor([[1.9948]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9908]])), ('linear.bias', tensor([1.0476]))])
# OrderedDict([('linear.weight', tensor([[1.9874]])), ('linear.bias', tensor([1.0397]))])
# OrderedDict([('linear.weight', tensor([[1.9890]])), ('linear.bias', tensor([1.0438]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[1.9906]])), ('linear.bias', tensor([1.0504]))])
# OrderedDict([('linear.weight', tensor([[1.9904]])), ('linear.bias', tensor([1.0470]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0494]))])
# OrderedDict([('linear.weight', tensor([[1.9956]])), ('linear.bias', tensor([1.0544]))])
# OrderedDict([('linear.weight', tensor([[1.9910]])), ('linear.bias', tensor([1.0481]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0502]))])
# OrderedDict([('linear.weight', tensor([[1.9943]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9911]])), ('linear.bias', tensor([1.0503]))])
# OrderedDict([('linear.weight', tensor([[1.9959]])), ('linear.bias', tensor([1.0593]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0544]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0514]))])
# OrderedDict([('linear.weight', tensor([[1.9942]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9941]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9915]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[1.9964]])), ('linear.bias', tensor([1.0628]))])
# OrderedDict([('linear.weight', tensor([[1.9953]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9968]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0626]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0670]))])
# OrderedDict([('linear.weight', tensor([[1.9995]])), ('linear.bias', tensor([1.0670]))])
# OrderedDict([('linear.weight', tensor([[1.9942]])), ('linear.bias', tensor([1.0582]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0647]))])
# OrderedDict([('linear.weight', tensor([[1.9950]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0554]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0545]))])
# OrderedDict([('linear.weight', tensor([[1.9957]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9949]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9918]])), ('linear.bias', tensor([1.0451]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0484]))])
# OrderedDict([('linear.weight', tensor([[1.9941]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[1.9953]])), ('linear.bias', tensor([1.0546]))])
# OrderedDict([('linear.weight', tensor([[1.9950]])), ('linear.bias', tensor([1.0490]))])
# OrderedDict([('linear.weight', tensor([[1.9950]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[1.9908]])), ('linear.bias', tensor([1.0463]))])
# OrderedDict([('linear.weight', tensor([[1.9898]])), ('linear.bias', tensor([1.0453]))])
# OrderedDict([('linear.weight', tensor([[1.9912]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9904]])), ('linear.bias', tensor([1.0500]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0552]))])
# OrderedDict([('linear.weight', tensor([[1.9917]])), ('linear.bias', tensor([1.0450]))])
# OrderedDict([('linear.weight', tensor([[1.9902]])), ('linear.bias', tensor([1.0428]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0452]))])
# OrderedDict([('linear.weight', tensor([[1.9949]])), ('linear.bias', tensor([1.0467]))])
# OrderedDict([('linear.weight', tensor([[2.0008]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9962]])), ('linear.bias', tensor([1.0500]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9995]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0541]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0502]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[2.0002]])), ('linear.bias', tensor([1.0551]))])
# OrderedDict([('linear.weight', tensor([[2.0014]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[1.9997]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[2.0026]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[2.0036]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0552]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0502]))])
# OrderedDict([('linear.weight', tensor([[2.0011]])), ('linear.bias', tensor([1.0445]))])
# OrderedDict([('linear.weight', tensor([[2.0062]])), ('linear.bias', tensor([1.0545]))])
# OrderedDict([('linear.weight', tensor([[2.0085]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[2.0052]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[2.0081]])), ('linear.bias', tensor([1.0556]))])
# OrderedDict([('linear.weight', tensor([[2.0064]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[2.0078]])), ('linear.bias', tensor([1.0630]))])
# OrderedDict([('linear.weight', tensor([[2.0051]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[2.0062]])), ('linear.bias', tensor([1.0598]))])
# OrderedDict([('linear.weight', tensor([[2.0053]])), ('linear.bias', tensor([1.0552]))])
# OrderedDict([('linear.weight', tensor([[2.0060]])), ('linear.bias', tensor([1.0606]))])
# OrderedDict([('linear.weight', tensor([[2.0008]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9986]])), ('linear.bias', tensor([1.0461]))])
# OrderedDict([('linear.weight', tensor([[2.0005]])), ('linear.bias', tensor([1.0493]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0424]))])
# OrderedDict([('linear.weight', tensor([[1.9960]])), ('linear.bias', tensor([1.0421]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0450]))])
# OrderedDict([('linear.weight', tensor([[1.9962]])), ('linear.bias', tensor([1.0412]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0361]))])
# OrderedDict([('linear.weight', tensor([[1.9955]])), ('linear.bias', tensor([1.0422]))])
# OrderedDict([('linear.weight', tensor([[1.9963]])), ('linear.bias', tensor([1.0430]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0488]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0501]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9991]])), ('linear.bias', tensor([1.0477]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0469]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0453]))])
# OrderedDict([('linear.weight', tensor([[2.0011]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0442]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0472]))])
# OrderedDict([('linear.weight', tensor([[1.9963]])), ('linear.bias', tensor([1.0476]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0477]))])
# OrderedDict([('linear.weight', tensor([[1.9959]])), ('linear.bias', tensor([1.0429]))])
# OrderedDict([('linear.weight', tensor([[1.9995]])), ('linear.bias', tensor([1.0483]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0444]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0457]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0484]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0412]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0386]))])
# OrderedDict([('linear.weight', tensor([[1.9955]])), ('linear.bias', tensor([1.0419]))])
# OrderedDict([('linear.weight', tensor([[2.0015]])), ('linear.bias', tensor([1.0496]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[2.0007]])), ('linear.bias', tensor([1.0488]))])
# OrderedDict([('linear.weight', tensor([[2.0019]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0479]))])
# OrderedDict([('linear.weight', tensor([[2.0002]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0559]))])
# OrderedDict([('linear.weight', tensor([[2.0023]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[2.0052]])), ('linear.bias', tensor([1.0635]))])
# OrderedDict([('linear.weight', tensor([[2.0036]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[2.0042]])), ('linear.bias', tensor([1.0605]))])
# OrderedDict([('linear.weight', tensor([[2.0053]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[2.0031]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[2.0037]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[2.0052]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[2.0063]])), ('linear.bias', tensor([1.0621]))])
# OrderedDict([('linear.weight', tensor([[2.0026]])), ('linear.bias', tensor([1.0559]))])
# OrderedDict([('linear.weight', tensor([[2.0028]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[2.0048]])), ('linear.bias', tensor([1.0585]))])
# OrderedDict([('linear.weight', tensor([[2.0015]])), ('linear.bias', tensor([1.0540]))])
# OrderedDict([('linear.weight', tensor([[2.0037]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9989]])), ('linear.bias', tensor([1.0465]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0401]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0430]))])
# OrderedDict([('linear.weight', tensor([[1.9998]])), ('linear.bias', tensor([1.0416]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0390]))])
# OrderedDict([('linear.weight', tensor([[1.9991]])), ('linear.bias', tensor([1.0474]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0388]))])
# OrderedDict([('linear.weight', tensor([[2.0006]])), ('linear.bias', tensor([1.0421]))])
# OrderedDict([('linear.weight', tensor([[2.0032]])), ('linear.bias', tensor([1.0451]))])
# OrderedDict([('linear.weight', tensor([[2.0046]])), ('linear.bias', tensor([1.0460]))])
# OrderedDict([('linear.weight', tensor([[2.0056]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[2.0053]])), ('linear.bias', tensor([1.0511]))])
# OrderedDict([('linear.weight', tensor([[2.0082]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[2.0043]])), ('linear.bias', tensor([1.0503]))])
# OrderedDict([('linear.weight', tensor([[1.9998]])), ('linear.bias', tensor([1.0458]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0481]))])
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0537]))])
# OrderedDict([('linear.weight', tensor([[2.0043]])), ('linear.bias', tensor([1.0505]))])
# OrderedDict([('linear.weight', tensor([[2.0052]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[2.0057]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[2.0013]])), ('linear.bias', tensor([1.0404]))])
# OrderedDict([('linear.weight', tensor([[2.0059]])), ('linear.bias', tensor([1.0470]))])
# OrderedDict([('linear.weight', tensor([[2.0060]])), ('linear.bias', tensor([1.0514]))])
# OrderedDict([('linear.weight', tensor([[2.0023]])), ('linear.bias', tensor([1.0474]))])
# OrderedDict([('linear.weight', tensor([[2.0030]])), ('linear.bias', tensor([1.0466]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0490]))])
# OrderedDict([('linear.weight', tensor([[2.0076]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[2.0062]])), ('linear.bias', tensor([1.0560]))])
# OrderedDict([('linear.weight', tensor([[2.0064]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[2.0013]])), ('linear.bias', tensor([1.0511]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0488]))])
# OrderedDict([('linear.weight', tensor([[2.0057]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0481]))])
# OrderedDict([('linear.weight', tensor([[2.0035]])), ('linear.bias', tensor([1.0462]))])
# OrderedDict([('linear.weight', tensor([[2.0067]])), ('linear.bias', tensor([1.0505]))])
# OrderedDict([('linear.weight', tensor([[2.0030]])), ('linear.bias', tensor([1.0480]))])
# OrderedDict([('linear.weight', tensor([[2.0003]])), ('linear.bias', tensor([1.0461]))])
# OrderedDict([('linear.weight', tensor([[2.0008]])), ('linear.bias', tensor([1.0486]))])
# OrderedDict([('linear.weight', tensor([[1.9999]])), ('linear.bias', tensor([1.0462]))])
# OrderedDict([('linear.weight', tensor([[2.0016]])), ('linear.bias', tensor([1.0497]))])
# OrderedDict([('linear.weight', tensor([[2.0034]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[2.0023]])), ('linear.bias', tensor([1.0508]))])
# OrderedDict([('linear.weight', tensor([[1.9990]])), ('linear.bias', tensor([1.0446]))])
# OrderedDict([('linear.weight', tensor([[2.0001]])), ('linear.bias', tensor([1.0489]))])
# OrderedDict([('linear.weight', tensor([[1.9968]])), ('linear.bias', tensor([1.0437]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0474]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0482]))])
# OrderedDict([('linear.weight', tensor([[1.9986]])), ('linear.bias', tensor([1.0468]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0477]))])
# OrderedDict([('linear.weight', tensor([[2.0000]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[2.0032]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[2.0034]])), ('linear.bias', tensor([1.0603]))])
# OrderedDict([('linear.weight', tensor([[1.9988]])), ('linear.bias', tensor([1.0486]))])
# OrderedDict([('linear.weight', tensor([[2.0012]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[2.0000]])), ('linear.bias', tensor([1.0490]))])
# OrderedDict([('linear.weight', tensor([[2.0018]])), ('linear.bias', tensor([1.0529]))])
# OrderedDict([('linear.weight', tensor([[1.9991]])), ('linear.bias', tensor([1.0462]))])
# OrderedDict([('linear.weight', tensor([[2.0018]])), ('linear.bias', tensor([1.0493]))])
# OrderedDict([('linear.weight', tensor([[2.0022]])), ('linear.bias', tensor([1.0494]))])
# OrderedDict([('linear.weight', tensor([[2.0027]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0458]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0413]))])
# OrderedDict([('linear.weight', tensor([[2.0005]])), ('linear.bias', tensor([1.0477]))])
# OrderedDict([('linear.weight', tensor([[2.0045]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0502]))])
# OrderedDict([('linear.weight', tensor([[2.0053]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[2.0014]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[2.0012]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[2.0011]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[2.0032]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[2.0024]])), ('linear.bias', tensor([1.0589]))])
# ...
# OrderedDict([('linear.weight', tensor([[1.9988]])), ('linear.bias', tensor([1.0499]))])
# OrderedDict([('linear.weight', tensor([[1.9987]])), ('linear.bias', tensor([1.0513]))])
# OrderedDict([('linear.weight', tensor([[2.0028]])), ('linear.bias', tensor([1.0599]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9990]])), ('linear.bias', tensor([1.0545]))])
# OrderedDict([('linear.weight', tensor([[1.9997]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[2.0004]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[2.0012]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0634]))])
# OrderedDict([('linear.weight', tensor([[2.0016]])), ('linear.bias', tensor([1.0541]))])
# OrderedDict([('linear.weight', tensor([[2.0011]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0442]))])
# OrderedDict([('linear.weight', tensor([[1.9956]])), ('linear.bias', tensor([1.0406]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0459]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0498]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0487]))])
# OrderedDict([('linear.weight', tensor([[2.0032]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0554]))])
# OrderedDict([('linear.weight', tensor([[2.0047]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[2.0033]])), ('linear.bias', tensor([1.0505]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0482]))])
# OrderedDict([('linear.weight', tensor([[2.0055]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[2.0017]])), ('linear.bias', tensor([1.0440]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0381]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0380]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0365]))])
# OrderedDict([('linear.weight', tensor([[2.0012]])), ('linear.bias', tensor([1.0418]))])
# OrderedDict([('linear.weight', tensor([[2.0006]])), ('linear.bias', tensor([1.0414]))])
# OrderedDict([('linear.weight', tensor([[2.0004]])), ('linear.bias', tensor([1.0369]))])
# OrderedDict([('linear.weight', tensor([[2.0059]])), ('linear.bias', tensor([1.0447]))])
# OrderedDict([('linear.weight', tensor([[2.0089]])), ('linear.bias', tensor([1.0480]))])
# OrderedDict([('linear.weight', tensor([[2.0111]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[2.0108]])), ('linear.bias', tensor([1.0559]))])
# OrderedDict([('linear.weight', tensor([[2.0116]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[2.0074]])), ('linear.bias', tensor([1.0484]))])
# OrderedDict([('linear.weight', tensor([[2.0109]])), ('linear.bias', tensor([1.0547]))])
# OrderedDict([('linear.weight', tensor([[2.0047]])), ('linear.bias', tensor([1.0478]))])
# OrderedDict([('linear.weight', tensor([[2.0062]])), ('linear.bias', tensor([1.0500]))])
# OrderedDict([('linear.weight', tensor([[2.0057]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[2.0043]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[2.0039]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[2.0023]])), ('linear.bias', tensor([1.0509]))])
# OrderedDict([('linear.weight', tensor([[2.0028]])), ('linear.bias', tensor([1.0503]))])
# OrderedDict([('linear.weight', tensor([[2.0039]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[2.0027]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[2.0009]])), ('linear.bias', tensor([1.0494]))])
# OrderedDict([('linear.weight', tensor([[2.0006]])), ('linear.bias', tensor([1.0509]))])
# OrderedDict([('linear.weight', tensor([[2.0036]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[2.0018]])), ('linear.bias', tensor([1.0509]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[2.0058]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[2.0050]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[2.0004]])), ('linear.bias', tensor([1.0488]))])
# OrderedDict([('linear.weight', tensor([[2.0017]])), ('linear.bias', tensor([1.0503]))])
# OrderedDict([('linear.weight', tensor([[2.0017]])), ('linear.bias', tensor([1.0494]))])
# OrderedDict([('linear.weight', tensor([[2.0031]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9986]])), ('linear.bias', tensor([1.0472]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9943]])), ('linear.bias', tensor([1.0441]))])
# OrderedDict([('linear.weight', tensor([[1.9941]])), ('linear.bias', tensor([1.0419]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9958]])), ('linear.bias', tensor([1.0491]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0422]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0430]))])
# OrderedDict([('linear.weight', tensor([[1.9952]])), ('linear.bias', tensor([1.0442]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0383]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0417]))])
# OrderedDict([('linear.weight', tensor([[1.9921]])), ('linear.bias', tensor([1.0382]))])
# OrderedDict([('linear.weight', tensor([[1.9945]])), ('linear.bias', tensor([1.0409]))])
# OrderedDict([('linear.weight', tensor([[1.9998]])), ('linear.bias', tensor([1.0481]))])
# OrderedDict([('linear.weight', tensor([[2.0007]])), ('linear.bias', tensor([1.0463]))])
# OrderedDict([('linear.weight', tensor([[1.9987]])), ('linear.bias', tensor([1.0458]))])
# OrderedDict([('linear.weight', tensor([[2.0008]])), ('linear.bias', tensor([1.0498]))])
# OrderedDict([('linear.weight', tensor([[2.0002]])), ('linear.bias', tensor([1.0505]))])
# OrderedDict([('linear.weight', tensor([[1.9990]])), ('linear.bias', tensor([1.0486]))])
# OrderedDict([('linear.weight', tensor([[2.0032]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[2.0056]])), ('linear.bias', tensor([1.0622]))])
# OrderedDict([('linear.weight', tensor([[2.0061]])), ('linear.bias', tensor([1.0636]))])
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[2.0067]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[2.0071]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[2.0030]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[2.0020]])), ('linear.bias', tensor([1.0554]))])
# OrderedDict([('linear.weight', tensor([[2.0013]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[2.0045]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[2.0051]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[2.0060]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[2.0096]])), ('linear.bias', tensor([1.0674]))])
# OrderedDict([('linear.weight', tensor([[2.0073]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[2.0001]])), ('linear.bias', tensor([1.0457]))])
# OrderedDict([('linear.weight', tensor([[2.0020]])), ('linear.bias', tensor([1.0482]))])
# OrderedDict([('linear.weight', tensor([[2.0020]])), ('linear.bias', tensor([1.0440]))])
# OrderedDict([('linear.weight', tensor([[2.0022]])), ('linear.bias', tensor([1.0442]))])
# OrderedDict([('linear.weight', tensor([[2.0036]])), ('linear.bias', tensor([1.0457]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0448]))])
# OrderedDict([('linear.weight', tensor([[2.0023]])), ('linear.bias', tensor([1.0450]))])
# OrderedDict([('linear.weight', tensor([[2.0030]])), ('linear.bias', tensor([1.0486]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[2.0038]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[2.0038]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[2.0046]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[2.0056]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[2.0025]])), ('linear.bias', tensor([1.0508]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0449]))])
# OrderedDict([('linear.weight', tensor([[2.0010]])), ('linear.bias', tensor([1.0492]))])
# OrderedDict([('linear.weight', tensor([[1.9986]])), ('linear.bias', tensor([1.0463]))])
# OrderedDict([('linear.weight', tensor([[1.9965]])), ('linear.bias', tensor([1.0441]))])
# OrderedDict([('linear.weight', tensor([[1.9991]])), ('linear.bias', tensor([1.0463]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0444]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0493]))])
# OrderedDict([('linear.weight', tensor([[2.0068]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[2.0073]])), ('linear.bias', tensor([1.0610]))])
# OrderedDict([('linear.weight', tensor([[2.0089]])), ('linear.bias', tensor([1.0640]))])
# OrderedDict([('linear.weight', tensor([[2.0044]])), ('linear.bias', tensor([1.0599]))])
# OrderedDict([('linear.weight', tensor([[2.0024]])), ('linear.bias', tensor([1.0581]))])
# OrderedDict([('linear.weight', tensor([[2.0002]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9962]])), ('linear.bias', tensor([1.0502]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0497]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0496]))])
# OrderedDict([('linear.weight', tensor([[1.9956]])), ('linear.bias', tensor([1.0450]))])
# OrderedDict([('linear.weight', tensor([[1.9987]])), ('linear.bias', tensor([1.0453]))])
# OrderedDict([('linear.weight', tensor([[2.0035]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[2.0022]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[2.0022]])), ('linear.bias', tensor([1.0509]))])
# OrderedDict([('linear.weight', tensor([[2.0034]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[2.0028]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[2.0021]])), ('linear.bias', tensor([1.0507]))])
# OrderedDict([('linear.weight', tensor([[2.0024]])), ('linear.bias', tensor([1.0506]))])
# OrderedDict([('linear.weight', tensor([[1.9998]])), ('linear.bias', tensor([1.0493]))])
# OrderedDict([('linear.weight', tensor([[1.9997]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0433]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0457]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0448]))])
# OrderedDict([('linear.weight', tensor([[2.0008]])), ('linear.bias', tensor([1.0467]))])
# OrderedDict([('linear.weight', tensor([[2.0011]])), ('linear.bias', tensor([1.0481]))])
# OrderedDict([('linear.weight', tensor([[1.9988]])), ('linear.bias', tensor([1.0418]))])
# OrderedDict([('linear.weight', tensor([[2.0005]])), ('linear.bias', tensor([1.0432]))])
# OrderedDict([('linear.weight', tensor([[1.9997]])), ('linear.bias', tensor([1.0413]))])
# OrderedDict([('linear.weight', tensor([[2.0053]])), ('linear.bias', tensor([1.0501]))])
# OrderedDict([('linear.weight', tensor([[2.0034]])), ('linear.bias', tensor([1.0461]))])
# OrderedDict([('linear.weight', tensor([[2.0047]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[2.0042]])), ('linear.bias', tensor([1.0487]))])
# OrderedDict([('linear.weight', tensor([[2.0066]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[2.0084]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[2.0063]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[2.0049]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[2.0050]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0476]))])
# OrderedDict([('linear.weight', tensor([[2.0001]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0512]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0492]))])
# OrderedDict([('linear.weight', tensor([[2.0022]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0475]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0396]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0383]))])
# OrderedDict([('linear.weight', tensor([[1.9957]])), ('linear.bias', tensor([1.0421]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0458]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0469]))])
# OrderedDict([('linear.weight', tensor([[2.0009]])), ('linear.bias', tensor([1.0560]))])
# OrderedDict([('linear.weight', tensor([[1.9992]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0500]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0413]))])
# OrderedDict([('linear.weight', tensor([[1.9906]])), ('linear.bias', tensor([1.0360]))])
# OrderedDict([('linear.weight', tensor([[1.9900]])), ('linear.bias', tensor([1.0355]))])
# OrderedDict([('linear.weight', tensor([[1.9912]])), ('linear.bias', tensor([1.0364]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0440]))])
# OrderedDict([('linear.weight', tensor([[2.0036]])), ('linear.bias', tensor([1.0547]))])
# OrderedDict([('linear.weight', tensor([[2.0052]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0558]))])
# OrderedDict([('linear.weight', tensor([[2.0035]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[2.0018]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[2.0024]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[2.0038]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0554]))])

# %%
# Model's parameter before training 
print(model.state_dict())
# Out:
# OrderedDict([('linear.weight', tensor([[2.0054]])), ('linear.bias', tensor([1.0554]))])

# %%
# Check model's parameters
#print(model.state_dict())

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[1.9994]], requires_grad=True), Parameter containing:
# tensor([1.0510], requires_grad=True)]
