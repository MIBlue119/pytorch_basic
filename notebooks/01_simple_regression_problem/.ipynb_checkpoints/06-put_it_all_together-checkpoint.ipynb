# %% [markdown]
# # Deep Learning with Pytorh step-by-step

# %% [markdown]
# ## Simple Regression Problem

# %%
import numpy as np 
import torch 
import torch.optim as optim
import torch.nn as nn

# %% [markdown]
# ## Data generation

# %%
true_b = 1
true_w = 2 
N = 100

# set the random seed for numpy 
np.random.seed(43)

x= np.random.rand(N,1)
epsilon = (.1 * np.random.rand(N,1))

y = true_b + true_w *x + epsilon

# %% [markdown]
# ### Generating training and validaiton sets

# %%
# Generate training and validating sets 
idx = np.arange(N)
np.random.shuffle(idx)

# Use first 80 randowm indices for train
train_idx = idx[:int(N*.8)]
val_idx = idx[int(N*.8):]

# Generate train and validation sets
x_train, y_train = x[train_idx], y[train_idx]
x_val, y_val = x[val_idx], y[val_idx]

# %% [markdown]
# ## Full Pipeline

# %% [markdown]
# ### Data preparation

# %%
# %%writefile ./data_preparation.py

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Tranform the data from numpy array to torch tensor
x_train_tensor = torch.as_tensor(x_train).float().to(device)
y_train_tensor = torch.as_tensor(y_train).float().to(device)
# Out:
# Overwriting ./data_preparation.py

# %%
# %run -i ./data_preparation.py

# %% [markdown]
# ### Model Config

# %%
# %%writefile ./model_configuration.py
class ManualLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)
        #Make `b` and `w` be the parameters of the model
        #Wrap them with `nn.Parameter` 
        #self.b = nn.Parameter(torch.randn(1,
        #                                requires_grad=True,
        #                                dtype=torch.float))
        #self.w = nn.Parameter(torch.randn(1,
        #                                requires_grad=True,
        #                                dtype=torch.float))
    def forward(self, x):
        # Compute the outputs /predictions
        return self.linear(x)

# Sets learning rate
lr = 0.1 

# Step 0 : Initialize parameters 'b' and 'w' randomly
torch.manual_seed(42)

# Create a model and send it at once to the device
model = ManualLinearRegression().to(device) # 1)

# Define a SGD optimizer to update the parameters
#optimizer = torch.optim.SGD([b,w], lr=lr)
optimizer = torch.optim.SGD(model.parameters(),lr=lr)


#Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")
# Out:
# Overwriting ./model_configuration.py

# %%
# %run -i ./model_configuration.py

# %% [markdown]
# ### Model training

# %%
# %%writefile ./model_training.py
# Define number of epochs 
n_epochs=1000

for epoch in range(n_epochs): 
    model.train()  #2)
    # Step 1: Computes the model's predicted output - forward pass
    # No more manula prediction 
    #yhat = b + w*x_train_tensor 
    yhat = model(x_train_tensor)  #3)
    
    # Step 2: Computes the loss
    # No more manual loss
    # error = (yhat - y_train_tensor)
    # loss = (error**2).mean()
    loss = loss_fn(yhat, y_train_tensor) #2
    
    # Step 3: Computes gradients for both 'b' and 'w' parameters
    loss.backward()
    
    # Step 4: Updates parameters using gradients and the learning rate
    # No more manual update
    # with torch.no_grade():
    #    b-=lr*b.grad
    #    w-=lr*w.grad
    optimizer.step()
    
    
    # Graident Zeroing
    # No more telling pytorch to let gradients go 
    #b.grad.zero()
    #w.grad.zero()
    optimizer.zero_grad()
    print(model.state_dict())
# Out:
# Overwriting ./model_training.py

# %%
# %run -i ./model_training.py
# Out:
# OrderedDict([('linear.weight', tensor([[0.9544]])), ('linear.bias', tensor([1.1259]))])
# OrderedDict([('linear.weight', tensor([[1.0185]])), ('linear.bias', tensor([1.2179]))])
# OrderedDict([('linear.weight', tensor([[1.0689]])), ('linear.bias', tensor([1.2849]))])
# OrderedDict([('linear.weight', tensor([[1.1089]])), ('linear.bias', tensor([1.3334]))])
# OrderedDict([('linear.weight', tensor([[1.1413]])), ('linear.bias', tensor([1.3681]))])
# OrderedDict([('linear.weight', tensor([[1.1680]])), ('linear.bias', tensor([1.3925]))])
# OrderedDict([('linear.weight', tensor([[1.1903]])), ('linear.bias', tensor([1.4094]))])
# OrderedDict([('linear.weight', tensor([[1.2094]])), ('linear.bias', tensor([1.4206]))])
# OrderedDict([('linear.weight', tensor([[1.2260]])), ('linear.bias', tensor([1.4276]))])
# OrderedDict([('linear.weight', tensor([[1.2408]])), ('linear.bias', tensor([1.4316]))])
# OrderedDict([('linear.weight', tensor([[1.2542]])), ('linear.bias', tensor([1.4332]))])
# OrderedDict([('linear.weight', tensor([[1.2664]])), ('linear.bias', tensor([1.4331]))])
# OrderedDict([('linear.weight', tensor([[1.2779]])), ('linear.bias', tensor([1.4319]))])
# OrderedDict([('linear.weight', tensor([[1.2887]])), ('linear.bias', tensor([1.4297]))])
# OrderedDict([('linear.weight', tensor([[1.2990]])), ('linear.bias', tensor([1.4268]))])
# OrderedDict([('linear.weight', tensor([[1.3088]])), ('linear.bias', tensor([1.4235]))])
# OrderedDict([('linear.weight', tensor([[1.3184]])), ('linear.bias', tensor([1.4198]))])
# OrderedDict([('linear.weight', tensor([[1.3276]])), ('linear.bias', tensor([1.4159]))])
# OrderedDict([('linear.weight', tensor([[1.3366]])), ('linear.bias', tensor([1.4118]))])
# OrderedDict([('linear.weight', tensor([[1.3454]])), ('linear.bias', tensor([1.4076]))])
# OrderedDict([('linear.weight', tensor([[1.3541]])), ('linear.bias', tensor([1.4034]))])
# OrderedDict([('linear.weight', tensor([[1.3625]])), ('linear.bias', tensor([1.3991]))])
# OrderedDict([('linear.weight', tensor([[1.3709]])), ('linear.bias', tensor([1.3948]))])
# OrderedDict([('linear.weight', tensor([[1.3791]])), ('linear.bias', tensor([1.3906]))])
# OrderedDict([('linear.weight', tensor([[1.3871]])), ('linear.bias', tensor([1.3863]))])
# OrderedDict([('linear.weight', tensor([[1.3951]])), ('linear.bias', tensor([1.3821]))])
# OrderedDict([('linear.weight', tensor([[1.4029]])), ('linear.bias', tensor([1.3779]))])
# OrderedDict([('linear.weight', tensor([[1.4106]])), ('linear.bias', tensor([1.3738]))])
# OrderedDict([('linear.weight', tensor([[1.4182]])), ('linear.bias', tensor([1.3697]))])
# OrderedDict([('linear.weight', tensor([[1.4258]])), ('linear.bias', tensor([1.3656]))])
# OrderedDict([('linear.weight', tensor([[1.4332]])), ('linear.bias', tensor([1.3616]))])
# OrderedDict([('linear.weight', tensor([[1.4405]])), ('linear.bias', tensor([1.3576]))])
# OrderedDict([('linear.weight', tensor([[1.4477]])), ('linear.bias', tensor([1.3537]))])
# OrderedDict([('linear.weight', tensor([[1.4548]])), ('linear.bias', tensor([1.3498]))])
# OrderedDict([('linear.weight', tensor([[1.4618]])), ('linear.bias', tensor([1.3460]))])
# OrderedDict([('linear.weight', tensor([[1.4688]])), ('linear.bias', tensor([1.3422]))])
# OrderedDict([('linear.weight', tensor([[1.4756]])), ('linear.bias', tensor([1.3385]))])
# OrderedDict([('linear.weight', tensor([[1.4824]])), ('linear.bias', tensor([1.3348]))])
# OrderedDict([('linear.weight', tensor([[1.4890]])), ('linear.bias', tensor([1.3312]))])
# OrderedDict([('linear.weight', tensor([[1.4956]])), ('linear.bias', tensor([1.3276]))])
# OrderedDict([('linear.weight', tensor([[1.5021]])), ('linear.bias', tensor([1.3241]))])
# OrderedDict([('linear.weight', tensor([[1.5085]])), ('linear.bias', tensor([1.3206]))])
# OrderedDict([('linear.weight', tensor([[1.5149]])), ('linear.bias', tensor([1.3172]))])
# OrderedDict([('linear.weight', tensor([[1.5211]])), ('linear.bias', tensor([1.3138]))])
# OrderedDict([('linear.weight', tensor([[1.5273]])), ('linear.bias', tensor([1.3104]))])
# OrderedDict([('linear.weight', tensor([[1.5333]])), ('linear.bias', tensor([1.3071]))])
# OrderedDict([('linear.weight', tensor([[1.5393]])), ('linear.bias', tensor([1.3038]))])
# OrderedDict([('linear.weight', tensor([[1.5453]])), ('linear.bias', tensor([1.3006]))])
# OrderedDict([('linear.weight', tensor([[1.5511]])), ('linear.bias', tensor([1.2974]))])
# OrderedDict([('linear.weight', tensor([[1.5569]])), ('linear.bias', tensor([1.2943]))])
# OrderedDict([('linear.weight', tensor([[1.5626]])), ('linear.bias', tensor([1.2912]))])
# OrderedDict([('linear.weight', tensor([[1.5682]])), ('linear.bias', tensor([1.2881]))])
# OrderedDict([('linear.weight', tensor([[1.5738]])), ('linear.bias', tensor([1.2851]))])
# OrderedDict([('linear.weight', tensor([[1.5792]])), ('linear.bias', tensor([1.2821]))])
# OrderedDict([('linear.weight', tensor([[1.5846]])), ('linear.bias', tensor([1.2791]))])
# OrderedDict([('linear.weight', tensor([[1.5900]])), ('linear.bias', tensor([1.2762]))])
# OrderedDict([('linear.weight', tensor([[1.5952]])), ('linear.bias', tensor([1.2734]))])
# OrderedDict([('linear.weight', tensor([[1.6004]])), ('linear.bias', tensor([1.2705]))])
# OrderedDict([('linear.weight', tensor([[1.6056]])), ('linear.bias', tensor([1.2677]))])
# OrderedDict([('linear.weight', tensor([[1.6106]])), ('linear.bias', tensor([1.2650]))])
# OrderedDict([('linear.weight', tensor([[1.6156]])), ('linear.bias', tensor([1.2623]))])
# OrderedDict([('linear.weight', tensor([[1.6206]])), ('linear.bias', tensor([1.2596]))])
# OrderedDict([('linear.weight', tensor([[1.6254]])), ('linear.bias', tensor([1.2569]))])
# OrderedDict([('linear.weight', tensor([[1.6302]])), ('linear.bias', tensor([1.2543]))])
# OrderedDict([('linear.weight', tensor([[1.6350]])), ('linear.bias', tensor([1.2517]))])
# OrderedDict([('linear.weight', tensor([[1.6396]])), ('linear.bias', tensor([1.2492]))])
# OrderedDict([('linear.weight', tensor([[1.6443]])), ('linear.bias', tensor([1.2467]))])
# OrderedDict([('linear.weight', tensor([[1.6488]])), ('linear.bias', tensor([1.2442]))])
# OrderedDict([('linear.weight', tensor([[1.6533]])), ('linear.bias', tensor([1.2417]))])
# OrderedDict([('linear.weight', tensor([[1.6578]])), ('linear.bias', tensor([1.2393]))])
# OrderedDict([('linear.weight', tensor([[1.6621]])), ('linear.bias', tensor([1.2369]))])
# OrderedDict([('linear.weight', tensor([[1.6665]])), ('linear.bias', tensor([1.2346]))])
# OrderedDict([('linear.weight', tensor([[1.6707]])), ('linear.bias', tensor([1.2322]))])
# OrderedDict([('linear.weight', tensor([[1.6750]])), ('linear.bias', tensor([1.2299]))])
# OrderedDict([('linear.weight', tensor([[1.6791]])), ('linear.bias', tensor([1.2277]))])
# OrderedDict([('linear.weight', tensor([[1.6832]])), ('linear.bias', tensor([1.2254]))])
# OrderedDict([('linear.weight', tensor([[1.6873]])), ('linear.bias', tensor([1.2232]))])
# OrderedDict([('linear.weight', tensor([[1.6913]])), ('linear.bias', tensor([1.2210]))])
# OrderedDict([('linear.weight', tensor([[1.6952]])), ('linear.bias', tensor([1.2189]))])
# OrderedDict([('linear.weight', tensor([[1.6991]])), ('linear.bias', tensor([1.2168]))])
# OrderedDict([('linear.weight', tensor([[1.7030]])), ('linear.bias', tensor([1.2147]))])
# OrderedDict([('linear.weight', tensor([[1.7068]])), ('linear.bias', tensor([1.2126]))])
# OrderedDict([('linear.weight', tensor([[1.7105]])), ('linear.bias', tensor([1.2106]))])
# OrderedDict([('linear.weight', tensor([[1.7142]])), ('linear.bias', tensor([1.2085]))])
# OrderedDict([('linear.weight', tensor([[1.7179]])), ('linear.bias', tensor([1.2066]))])
# OrderedDict([('linear.weight', tensor([[1.7215]])), ('linear.bias', tensor([1.2046]))])
# OrderedDict([('linear.weight', tensor([[1.7250]])), ('linear.bias', tensor([1.2027]))])
# OrderedDict([('linear.weight', tensor([[1.7285]])), ('linear.bias', tensor([1.2007]))])
# OrderedDict([('linear.weight', tensor([[1.7320]])), ('linear.bias', tensor([1.1989]))])
# OrderedDict([('linear.weight', tensor([[1.7354]])), ('linear.bias', tensor([1.1970]))])
# OrderedDict([('linear.weight', tensor([[1.7388]])), ('linear.bias', tensor([1.1952]))])
# OrderedDict([('linear.weight', tensor([[1.7421]])), ('linear.bias', tensor([1.1933]))])
# OrderedDict([('linear.weight', tensor([[1.7454]])), ('linear.bias', tensor([1.1916]))])
# OrderedDict([('linear.weight', tensor([[1.7486]])), ('linear.bias', tensor([1.1898]))])
# OrderedDict([('linear.weight', tensor([[1.7518]])), ('linear.bias', tensor([1.1880]))])
# OrderedDict([('linear.weight', tensor([[1.7550]])), ('linear.bias', tensor([1.1863]))])
# OrderedDict([('linear.weight', tensor([[1.7581]])), ('linear.bias', tensor([1.1846]))])
# OrderedDict([('linear.weight', tensor([[1.7612]])), ('linear.bias', tensor([1.1829]))])
# OrderedDict([('linear.weight', tensor([[1.7642]])), ('linear.bias', tensor([1.1813]))])
# OrderedDict([('linear.weight', tensor([[1.7672]])), ('linear.bias', tensor([1.1797]))])
# OrderedDict([('linear.weight', tensor([[1.7702]])), ('linear.bias', tensor([1.1780]))])
# OrderedDict([('linear.weight', tensor([[1.7731]])), ('linear.bias', tensor([1.1765]))])
# OrderedDict([('linear.weight', tensor([[1.7760]])), ('linear.bias', tensor([1.1749]))])
# OrderedDict([('linear.weight', tensor([[1.7788]])), ('linear.bias', tensor([1.1733]))])
# OrderedDict([('linear.weight', tensor([[1.7816]])), ('linear.bias', tensor([1.1718]))])
# OrderedDict([('linear.weight', tensor([[1.7844]])), ('linear.bias', tensor([1.1703]))])
# OrderedDict([('linear.weight', tensor([[1.7872]])), ('linear.bias', tensor([1.1688]))])
# OrderedDict([('linear.weight', tensor([[1.7899]])), ('linear.bias', tensor([1.1673]))])
# OrderedDict([('linear.weight', tensor([[1.7925]])), ('linear.bias', tensor([1.1659]))])
# OrderedDict([('linear.weight', tensor([[1.7952]])), ('linear.bias', tensor([1.1644]))])
# OrderedDict([('linear.weight', tensor([[1.7977]])), ('linear.bias', tensor([1.1630]))])
# OrderedDict([('linear.weight', tensor([[1.8003]])), ('linear.bias', tensor([1.1616]))])
# OrderedDict([('linear.weight', tensor([[1.8028]])), ('linear.bias', tensor([1.1603]))])
# OrderedDict([('linear.weight', tensor([[1.8053]])), ('linear.bias', tensor([1.1589]))])
# OrderedDict([('linear.weight', tensor([[1.8078]])), ('linear.bias', tensor([1.1576]))])
# OrderedDict([('linear.weight', tensor([[1.8102]])), ('linear.bias', tensor([1.1562]))])
# OrderedDict([('linear.weight', tensor([[1.8126]])), ('linear.bias', tensor([1.1549]))])
# OrderedDict([('linear.weight', tensor([[1.8150]])), ('linear.bias', tensor([1.1536]))])
# OrderedDict([('linear.weight', tensor([[1.8173]])), ('linear.bias', tensor([1.1524]))])
# OrderedDict([('linear.weight', tensor([[1.8196]])), ('linear.bias', tensor([1.1511]))])
# OrderedDict([('linear.weight', tensor([[1.8219]])), ('linear.bias', tensor([1.1499]))])
# OrderedDict([('linear.weight', tensor([[1.8242]])), ('linear.bias', tensor([1.1486]))])
# OrderedDict([('linear.weight', tensor([[1.8264]])), ('linear.bias', tensor([1.1474]))])
# OrderedDict([('linear.weight', tensor([[1.8286]])), ('linear.bias', tensor([1.1462]))])
# OrderedDict([('linear.weight', tensor([[1.8307]])), ('linear.bias', tensor([1.1451]))])
# OrderedDict([('linear.weight', tensor([[1.8329]])), ('linear.bias', tensor([1.1439]))])
# OrderedDict([('linear.weight', tensor([[1.8350]])), ('linear.bias', tensor([1.1428]))])
# OrderedDict([('linear.weight', tensor([[1.8371]])), ('linear.bias', tensor([1.1416]))])
# OrderedDict([('linear.weight', tensor([[1.8391]])), ('linear.bias', tensor([1.1405]))])
# OrderedDict([('linear.weight', tensor([[1.8411]])), ('linear.bias', tensor([1.1394]))])
# OrderedDict([('linear.weight', tensor([[1.8431]])), ('linear.bias', tensor([1.1383]))])
# OrderedDict([('linear.weight', tensor([[1.8451]])), ('linear.bias', tensor([1.1372]))])
# OrderedDict([('linear.weight', tensor([[1.8470]])), ('linear.bias', tensor([1.1362]))])
# OrderedDict([('linear.weight', tensor([[1.8490]])), ('linear.bias', tensor([1.1351]))])
# OrderedDict([('linear.weight', tensor([[1.8509]])), ('linear.bias', tensor([1.1341]))])
# OrderedDict([('linear.weight', tensor([[1.8527]])), ('linear.bias', tensor([1.1331]))])
# OrderedDict([('linear.weight', tensor([[1.8546]])), ('linear.bias', tensor([1.1321]))])
# OrderedDict([('linear.weight', tensor([[1.8564]])), ('linear.bias', tensor([1.1311]))])
# OrderedDict([('linear.weight', tensor([[1.8582]])), ('linear.bias', tensor([1.1301]))])
# OrderedDict([('linear.weight', tensor([[1.8600]])), ('linear.bias', tensor([1.1291]))])
# OrderedDict([('linear.weight', tensor([[1.8617]])), ('linear.bias', tensor([1.1282]))])
# OrderedDict([('linear.weight', tensor([[1.8635]])), ('linear.bias', tensor([1.1272]))])
# OrderedDict([('linear.weight', tensor([[1.8652]])), ('linear.bias', tensor([1.1263]))])
# OrderedDict([('linear.weight', tensor([[1.8669]])), ('linear.bias', tensor([1.1254]))])
# OrderedDict([('linear.weight', tensor([[1.8685]])), ('linear.bias', tensor([1.1245]))])
# OrderedDict([('linear.weight', tensor([[1.8702]])), ('linear.bias', tensor([1.1236]))])
# OrderedDict([('linear.weight', tensor([[1.8718]])), ('linear.bias', tensor([1.1227]))])
# OrderedDict([('linear.weight', tensor([[1.8734]])), ('linear.bias', tensor([1.1218]))])
# OrderedDict([('linear.weight', tensor([[1.8750]])), ('linear.bias', tensor([1.1210]))])
# OrderedDict([('linear.weight', tensor([[1.8765]])), ('linear.bias', tensor([1.1201]))])
# OrderedDict([('linear.weight', tensor([[1.8781]])), ('linear.bias', tensor([1.1193]))])
# OrderedDict([('linear.weight', tensor([[1.8796]])), ('linear.bias', tensor([1.1185]))])
# OrderedDict([('linear.weight', tensor([[1.8811]])), ('linear.bias', tensor([1.1176]))])
# OrderedDict([('linear.weight', tensor([[1.8826]])), ('linear.bias', tensor([1.1168]))])
# OrderedDict([('linear.weight', tensor([[1.8840]])), ('linear.bias', tensor([1.1160]))])
# OrderedDict([('linear.weight', tensor([[1.8855]])), ('linear.bias', tensor([1.1153]))])
# OrderedDict([('linear.weight', tensor([[1.8869]])), ('linear.bias', tensor([1.1145]))])
# OrderedDict([('linear.weight', tensor([[1.8883]])), ('linear.bias', tensor([1.1137]))])
# OrderedDict([('linear.weight', tensor([[1.8897]])), ('linear.bias', tensor([1.1130]))])
# OrderedDict([('linear.weight', tensor([[1.8910]])), ('linear.bias', tensor([1.1122]))])
# OrderedDict([('linear.weight', tensor([[1.8924]])), ('linear.bias', tensor([1.1115]))])
# OrderedDict([('linear.weight', tensor([[1.8937]])), ('linear.bias', tensor([1.1108]))])
# OrderedDict([('linear.weight', tensor([[1.8950]])), ('linear.bias', tensor([1.1100]))])
# OrderedDict([('linear.weight', tensor([[1.8963]])), ('linear.bias', tensor([1.1093]))])
# OrderedDict([('linear.weight', tensor([[1.8976]])), ('linear.bias', tensor([1.1086]))])
# OrderedDict([('linear.weight', tensor([[1.8989]])), ('linear.bias', tensor([1.1079]))])
# OrderedDict([('linear.weight', tensor([[1.9001]])), ('linear.bias', tensor([1.1073]))])
# OrderedDict([('linear.weight', tensor([[1.9013]])), ('linear.bias', tensor([1.1066]))])
# OrderedDict([('linear.weight', tensor([[1.9026]])), ('linear.bias', tensor([1.1059]))])
# OrderedDict([('linear.weight', tensor([[1.9038]])), ('linear.bias', tensor([1.1053]))])
# OrderedDict([('linear.weight', tensor([[1.9049]])), ('linear.bias', tensor([1.1046]))])
# OrderedDict([('linear.weight', tensor([[1.9061]])), ('linear.bias', tensor([1.1040]))])
# OrderedDict([('linear.weight', tensor([[1.9073]])), ('linear.bias', tensor([1.1034]))])
# OrderedDict([('linear.weight', tensor([[1.9084]])), ('linear.bias', tensor([1.1028]))])
# OrderedDict([('linear.weight', tensor([[1.9095]])), ('linear.bias', tensor([1.1021]))])
# OrderedDict([('linear.weight', tensor([[1.9106]])), ('linear.bias', tensor([1.1015]))])
# OrderedDict([('linear.weight', tensor([[1.9117]])), ('linear.bias', tensor([1.1009]))])
# OrderedDict([('linear.weight', tensor([[1.9128]])), ('linear.bias', tensor([1.1004]))])
# OrderedDict([('linear.weight', tensor([[1.9139]])), ('linear.bias', tensor([1.0998]))])
# OrderedDict([('linear.weight', tensor([[1.9149]])), ('linear.bias', tensor([1.0992]))])
# OrderedDict([('linear.weight', tensor([[1.9160]])), ('linear.bias', tensor([1.0986]))])
# OrderedDict([('linear.weight', tensor([[1.9170]])), ('linear.bias', tensor([1.0981]))])
# OrderedDict([('linear.weight', tensor([[1.9180]])), ('linear.bias', tensor([1.0975]))])
# OrderedDict([('linear.weight', tensor([[1.9190]])), ('linear.bias', tensor([1.0970]))])
# OrderedDict([('linear.weight', tensor([[1.9200]])), ('linear.bias', tensor([1.0964]))])
# OrderedDict([('linear.weight', tensor([[1.9209]])), ('linear.bias', tensor([1.0959]))])
# OrderedDict([('linear.weight', tensor([[1.9219]])), ('linear.bias', tensor([1.0954]))])
# OrderedDict([('linear.weight', tensor([[1.9229]])), ('linear.bias', tensor([1.0949]))])
# OrderedDict([('linear.weight', tensor([[1.9238]])), ('linear.bias', tensor([1.0944]))])
# OrderedDict([('linear.weight', tensor([[1.9247]])), ('linear.bias', tensor([1.0939]))])
# OrderedDict([('linear.weight', tensor([[1.9256]])), ('linear.bias', tensor([1.0934]))])
# OrderedDict([('linear.weight', tensor([[1.9265]])), ('linear.bias', tensor([1.0929]))])
# OrderedDict([('linear.weight', tensor([[1.9274]])), ('linear.bias', tensor([1.0924]))])
# OrderedDict([('linear.weight', tensor([[1.9283]])), ('linear.bias', tensor([1.0919]))])
# OrderedDict([('linear.weight', tensor([[1.9291]])), ('linear.bias', tensor([1.0914]))])
# OrderedDict([('linear.weight', tensor([[1.9300]])), ('linear.bias', tensor([1.0910]))])
# OrderedDict([('linear.weight', tensor([[1.9308]])), ('linear.bias', tensor([1.0905]))])
# OrderedDict([('linear.weight', tensor([[1.9317]])), ('linear.bias', tensor([1.0901]))])
# OrderedDict([('linear.weight', tensor([[1.9325]])), ('linear.bias', tensor([1.0896]))])
# OrderedDict([('linear.weight', tensor([[1.9333]])), ('linear.bias', tensor([1.0892]))])
# OrderedDict([('linear.weight', tensor([[1.9341]])), ('linear.bias', tensor([1.0888]))])
# OrderedDict([('linear.weight', tensor([[1.9349]])), ('linear.bias', tensor([1.0883]))])
# OrderedDict([('linear.weight', tensor([[1.9357]])), ('linear.bias', tensor([1.0879]))])
# OrderedDict([('linear.weight', tensor([[1.9364]])), ('linear.bias', tensor([1.0875]))])
# OrderedDict([('linear.weight', tensor([[1.9372]])), ('linear.bias', tensor([1.0871]))])
# OrderedDict([('linear.weight', tensor([[1.9379]])), ('linear.bias', tensor([1.0867]))])
# OrderedDict([('linear.weight', tensor([[1.9387]])), ('linear.bias', tensor([1.0863]))])
# OrderedDict([('linear.weight', tensor([[1.9394]])), ('linear.bias', tensor([1.0859]))])
# OrderedDict([('linear.weight', tensor([[1.9401]])), ('linear.bias', tensor([1.0855]))])
# OrderedDict([('linear.weight', tensor([[1.9408]])), ('linear.bias', tensor([1.0851]))])
# OrderedDict([('linear.weight', tensor([[1.9415]])), ('linear.bias', tensor([1.0847]))])
# OrderedDict([('linear.weight', tensor([[1.9422]])), ('linear.bias', tensor([1.0843]))])
# OrderedDict([('linear.weight', tensor([[1.9429]])), ('linear.bias', tensor([1.0839]))])
# OrderedDict([('linear.weight', tensor([[1.9436]])), ('linear.bias', tensor([1.0836]))])
# OrderedDict([('linear.weight', tensor([[1.9443]])), ('linear.bias', tensor([1.0832]))])
# OrderedDict([('linear.weight', tensor([[1.9449]])), ('linear.bias', tensor([1.0829]))])
# OrderedDict([('linear.weight', tensor([[1.9456]])), ('linear.bias', tensor([1.0825]))])
# OrderedDict([('linear.weight', tensor([[1.9462]])), ('linear.bias', tensor([1.0822]))])
# OrderedDict([('linear.weight', tensor([[1.9468]])), ('linear.bias', tensor([1.0818]))])
# OrderedDict([('linear.weight', tensor([[1.9475]])), ('linear.bias', tensor([1.0815]))])
# OrderedDict([('linear.weight', tensor([[1.9481]])), ('linear.bias', tensor([1.0811]))])
# OrderedDict([('linear.weight', tensor([[1.9487]])), ('linear.bias', tensor([1.0808]))])
# OrderedDict([('linear.weight', tensor([[1.9493]])), ('linear.bias', tensor([1.0805]))])
# OrderedDict([('linear.weight', tensor([[1.9499]])), ('linear.bias', tensor([1.0802]))])
# OrderedDict([('linear.weight', tensor([[1.9504]])), ('linear.bias', tensor([1.0798]))])
# OrderedDict([('linear.weight', tensor([[1.9510]])), ('linear.bias', tensor([1.0795]))])
# OrderedDict([('linear.weight', tensor([[1.9516]])), ('linear.bias', tensor([1.0792]))])
# OrderedDict([('linear.weight', tensor([[1.9522]])), ('linear.bias', tensor([1.0789]))])
# OrderedDict([('linear.weight', tensor([[1.9527]])), ('linear.bias', tensor([1.0786]))])
# OrderedDict([('linear.weight', tensor([[1.9533]])), ('linear.bias', tensor([1.0783]))])
# OrderedDict([('linear.weight', tensor([[1.9538]])), ('linear.bias', tensor([1.0780]))])
# OrderedDict([('linear.weight', tensor([[1.9543]])), ('linear.bias', tensor([1.0777]))])
# OrderedDict([('linear.weight', tensor([[1.9548]])), ('linear.bias', tensor([1.0774]))])
# OrderedDict([('linear.weight', tensor([[1.9554]])), ('linear.bias', tensor([1.0772]))])
# OrderedDict([('linear.weight', tensor([[1.9559]])), ('linear.bias', tensor([1.0769]))])
# OrderedDict([('linear.weight', tensor([[1.9564]])), ('linear.bias', tensor([1.0766]))])
# OrderedDict([('linear.weight', tensor([[1.9569]])), ('linear.bias', tensor([1.0763]))])
# OrderedDict([('linear.weight', tensor([[1.9574]])), ('linear.bias', tensor([1.0761]))])
# OrderedDict([('linear.weight', tensor([[1.9579]])), ('linear.bias', tensor([1.0758]))])
# OrderedDict([('linear.weight', tensor([[1.9583]])), ('linear.bias', tensor([1.0755]))])
# OrderedDict([('linear.weight', tensor([[1.9588]])), ('linear.bias', tensor([1.0753]))])
# OrderedDict([('linear.weight', tensor([[1.9593]])), ('linear.bias', tensor([1.0750]))])
# OrderedDict([('linear.weight', tensor([[1.9597]])), ('linear.bias', tensor([1.0748]))])
# OrderedDict([('linear.weight', tensor([[1.9602]])), ('linear.bias', tensor([1.0745]))])
# OrderedDict([('linear.weight', tensor([[1.9606]])), ('linear.bias', tensor([1.0743]))])
# OrderedDict([('linear.weight', tensor([[1.9611]])), ('linear.bias', tensor([1.0740]))])
# OrderedDict([('linear.weight', tensor([[1.9615]])), ('linear.bias', tensor([1.0738]))])
# OrderedDict([('linear.weight', tensor([[1.9620]])), ('linear.bias', tensor([1.0736]))])
# OrderedDict([('linear.weight', tensor([[1.9624]])), ('linear.bias', tensor([1.0733]))])
# OrderedDict([('linear.weight', tensor([[1.9628]])), ('linear.bias', tensor([1.0731]))])
# OrderedDict([('linear.weight', tensor([[1.9632]])), ('linear.bias', tensor([1.0729]))])
# OrderedDict([('linear.weight', tensor([[1.9636]])), ('linear.bias', tensor([1.0727]))])
# OrderedDict([('linear.weight', tensor([[1.9640]])), ('linear.bias', tensor([1.0724]))])
# OrderedDict([('linear.weight', tensor([[1.9644]])), ('linear.bias', tensor([1.0722]))])
# OrderedDict([('linear.weight', tensor([[1.9648]])), ('linear.bias', tensor([1.0720]))])
# OrderedDict([('linear.weight', tensor([[1.9652]])), ('linear.bias', tensor([1.0718]))])
# OrderedDict([('linear.weight', tensor([[1.9656]])), ('linear.bias', tensor([1.0716]))])
# OrderedDict([('linear.weight', tensor([[1.9660]])), ('linear.bias', tensor([1.0714]))])
# OrderedDict([('linear.weight', tensor([[1.9664]])), ('linear.bias', tensor([1.0712]))])
# OrderedDict([('linear.weight', tensor([[1.9667]])), ('linear.bias', tensor([1.0710]))])
# OrderedDict([('linear.weight', tensor([[1.9671]])), ('linear.bias', tensor([1.0708]))])
# OrderedDict([('linear.weight', tensor([[1.9674]])), ('linear.bias', tensor([1.0706]))])
# OrderedDict([('linear.weight', tensor([[1.9678]])), ('linear.bias', tensor([1.0704]))])
# OrderedDict([('linear.weight', tensor([[1.9681]])), ('linear.bias', tensor([1.0702]))])
# OrderedDict([('linear.weight', tensor([[1.9685]])), ('linear.bias', tensor([1.0700]))])
# OrderedDict([('linear.weight', tensor([[1.9688]])), ('linear.bias', tensor([1.0698]))])
# OrderedDict([('linear.weight', tensor([[1.9692]])), ('linear.bias', tensor([1.0696]))])
# OrderedDict([('linear.weight', tensor([[1.9695]])), ('linear.bias', tensor([1.0695]))])
# OrderedDict([('linear.weight', tensor([[1.9698]])), ('linear.bias', tensor([1.0693]))])
# OrderedDict([('linear.weight', tensor([[1.9702]])), ('linear.bias', tensor([1.0691]))])
# OrderedDict([('linear.weight', tensor([[1.9705]])), ('linear.bias', tensor([1.0689]))])
# OrderedDict([('linear.weight', tensor([[1.9708]])), ('linear.bias', tensor([1.0688]))])
# OrderedDict([('linear.weight', tensor([[1.9711]])), ('linear.bias', tensor([1.0686]))])
# OrderedDict([('linear.weight', tensor([[1.9714]])), ('linear.bias', tensor([1.0684]))])
# OrderedDict([('linear.weight', tensor([[1.9717]])), ('linear.bias', tensor([1.0683]))])
# OrderedDict([('linear.weight', tensor([[1.9720]])), ('linear.bias', tensor([1.0681]))])
# OrderedDict([('linear.weight', tensor([[1.9723]])), ('linear.bias', tensor([1.0679]))])
# OrderedDict([('linear.weight', tensor([[1.9726]])), ('linear.bias', tensor([1.0678]))])
# OrderedDict([('linear.weight', tensor([[1.9729]])), ('linear.bias', tensor([1.0676]))])
# OrderedDict([('linear.weight', tensor([[1.9732]])), ('linear.bias', tensor([1.0675]))])
# OrderedDict([('linear.weight', tensor([[1.9734]])), ('linear.bias', tensor([1.0673]))])
# OrderedDict([('linear.weight', tensor([[1.9737]])), ('linear.bias', tensor([1.0672]))])
# OrderedDict([('linear.weight', tensor([[1.9740]])), ('linear.bias', tensor([1.0670]))])
# OrderedDict([('linear.weight', tensor([[1.9743]])), ('linear.bias', tensor([1.0669]))])
# OrderedDict([('linear.weight', tensor([[1.9745]])), ('linear.bias', tensor([1.0667]))])
# OrderedDict([('linear.weight', tensor([[1.9748]])), ('linear.bias', tensor([1.0666]))])
# OrderedDict([('linear.weight', tensor([[1.9751]])), ('linear.bias', tensor([1.0664]))])
# OrderedDict([('linear.weight', tensor([[1.9753]])), ('linear.bias', tensor([1.0663]))])
# OrderedDict([('linear.weight', tensor([[1.9756]])), ('linear.bias', tensor([1.0662]))])
# OrderedDict([('linear.weight', tensor([[1.9758]])), ('linear.bias', tensor([1.0660]))])
# OrderedDict([('linear.weight', tensor([[1.9761]])), ('linear.bias', tensor([1.0659]))])
# OrderedDict([('linear.weight', tensor([[1.9763]])), ('linear.bias', tensor([1.0658]))])
# OrderedDict([('linear.weight', tensor([[1.9765]])), ('linear.bias', tensor([1.0656]))])
# OrderedDict([('linear.weight', tensor([[1.9768]])), ('linear.bias', tensor([1.0655]))])
# OrderedDict([('linear.weight', tensor([[1.9770]])), ('linear.bias', tensor([1.0654]))])
# OrderedDict([('linear.weight', tensor([[1.9772]])), ('linear.bias', tensor([1.0652]))])
# OrderedDict([('linear.weight', tensor([[1.9775]])), ('linear.bias', tensor([1.0651]))])
# OrderedDict([('linear.weight', tensor([[1.9777]])), ('linear.bias', tensor([1.0650]))])
# OrderedDict([('linear.weight', tensor([[1.9779]])), ('linear.bias', tensor([1.0649]))])
# OrderedDict([('linear.weight', tensor([[1.9781]])), ('linear.bias', tensor([1.0648]))])
# OrderedDict([('linear.weight', tensor([[1.9783]])), ('linear.bias', tensor([1.0646]))])
# OrderedDict([('linear.weight', tensor([[1.9786]])), ('linear.bias', tensor([1.0645]))])
# OrderedDict([('linear.weight', tensor([[1.9788]])), ('linear.bias', tensor([1.0644]))])
# OrderedDict([('linear.weight', tensor([[1.9790]])), ('linear.bias', tensor([1.0643]))])
# OrderedDict([('linear.weight', tensor([[1.9792]])), ('linear.bias', tensor([1.0642]))])
# OrderedDict([('linear.weight', tensor([[1.9794]])), ('linear.bias', tensor([1.0641]))])
# OrderedDict([('linear.weight', tensor([[1.9796]])), ('linear.bias', tensor([1.0640]))])
# OrderedDict([('linear.weight', tensor([[1.9798]])), ('linear.bias', tensor([1.0639]))])
# OrderedDict([('linear.weight', tensor([[1.9800]])), ('linear.bias', tensor([1.0638]))])
# OrderedDict([('linear.weight', tensor([[1.9802]])), ('linear.bias', tensor([1.0637]))])
# OrderedDict([('linear.weight', tensor([[1.9804]])), ('linear.bias', tensor([1.0636]))])
# OrderedDict([('linear.weight', tensor([[1.9805]])), ('linear.bias', tensor([1.0634]))])
# OrderedDict([('linear.weight', tensor([[1.9807]])), ('linear.bias', tensor([1.0633]))])
# OrderedDict([('linear.weight', tensor([[1.9809]])), ('linear.bias', tensor([1.0632]))])
# OrderedDict([('linear.weight', tensor([[1.9811]])), ('linear.bias', tensor([1.0632]))])
# OrderedDict([('linear.weight', tensor([[1.9813]])), ('linear.bias', tensor([1.0631]))])
# OrderedDict([('linear.weight', tensor([[1.9814]])), ('linear.bias', tensor([1.0630]))])
# OrderedDict([('linear.weight', tensor([[1.9816]])), ('linear.bias', tensor([1.0629]))])
# OrderedDict([('linear.weight', tensor([[1.9818]])), ('linear.bias', tensor([1.0628]))])
# OrderedDict([('linear.weight', tensor([[1.9820]])), ('linear.bias', tensor([1.0627]))])
# OrderedDict([('linear.weight', tensor([[1.9821]])), ('linear.bias', tensor([1.0626]))])
# OrderedDict([('linear.weight', tensor([[1.9823]])), ('linear.bias', tensor([1.0625]))])
# OrderedDict([('linear.weight', tensor([[1.9824]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[1.9826]])), ('linear.bias', tensor([1.0623]))])
# OrderedDict([('linear.weight', tensor([[1.9828]])), ('linear.bias', tensor([1.0622]))])
# OrderedDict([('linear.weight', tensor([[1.9829]])), ('linear.bias', tensor([1.0622]))])
# OrderedDict([('linear.weight', tensor([[1.9831]])), ('linear.bias', tensor([1.0621]))])
# OrderedDict([('linear.weight', tensor([[1.9832]])), ('linear.bias', tensor([1.0620]))])
# OrderedDict([('linear.weight', tensor([[1.9834]])), ('linear.bias', tensor([1.0619]))])
# OrderedDict([('linear.weight', tensor([[1.9835]])), ('linear.bias', tensor([1.0618]))])
# OrderedDict([('linear.weight', tensor([[1.9837]])), ('linear.bias', tensor([1.0617]))])
# OrderedDict([('linear.weight', tensor([[1.9838]])), ('linear.bias', tensor([1.0617]))])
# OrderedDict([('linear.weight', tensor([[1.9839]])), ('linear.bias', tensor([1.0616]))])
# OrderedDict([('linear.weight', tensor([[1.9841]])), ('linear.bias', tensor([1.0615]))])
# OrderedDict([('linear.weight', tensor([[1.9842]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[1.9844]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[1.9845]])), ('linear.bias', tensor([1.0613]))])
# OrderedDict([('linear.weight', tensor([[1.9846]])), ('linear.bias', tensor([1.0612]))])
# OrderedDict([('linear.weight', tensor([[1.9848]])), ('linear.bias', tensor([1.0612]))])
# OrderedDict([('linear.weight', tensor([[1.9849]])), ('linear.bias', tensor([1.0611]))])
# OrderedDict([('linear.weight', tensor([[1.9850]])), ('linear.bias', tensor([1.0610]))])
# OrderedDict([('linear.weight', tensor([[1.9851]])), ('linear.bias', tensor([1.0609]))])
# OrderedDict([('linear.weight', tensor([[1.9853]])), ('linear.bias', tensor([1.0609]))])
# OrderedDict([('linear.weight', tensor([[1.9854]])), ('linear.bias', tensor([1.0608]))])
# OrderedDict([('linear.weight', tensor([[1.9855]])), ('linear.bias', tensor([1.0607]))])
# OrderedDict([('linear.weight', tensor([[1.9856]])), ('linear.bias', tensor([1.0607]))])
# OrderedDict([('linear.weight', tensor([[1.9857]])), ('linear.bias', tensor([1.0606]))])
# OrderedDict([('linear.weight', tensor([[1.9859]])), ('linear.bias', tensor([1.0605]))])
# OrderedDict([('linear.weight', tensor([[1.9860]])), ('linear.bias', tensor([1.0605]))])
# OrderedDict([('linear.weight', tensor([[1.9861]])), ('linear.bias', tensor([1.0604]))])
# OrderedDict([('linear.weight', tensor([[1.9862]])), ('linear.bias', tensor([1.0604]))])
# OrderedDict([('linear.weight', tensor([[1.9863]])), ('linear.bias', tensor([1.0603]))])
# OrderedDict([('linear.weight', tensor([[1.9864]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[1.9865]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[1.9866]])), ('linear.bias', tensor([1.0601]))])
# OrderedDict([('linear.weight', tensor([[1.9867]])), ('linear.bias', tensor([1.0601]))])
# OrderedDict([('linear.weight', tensor([[1.9868]])), ('linear.bias', tensor([1.0600]))])
# OrderedDict([('linear.weight', tensor([[1.9870]])), ('linear.bias', tensor([1.0600]))])
# OrderedDict([('linear.weight', tensor([[1.9871]])), ('linear.bias', tensor([1.0599]))])
# OrderedDict([('linear.weight', tensor([[1.9872]])), ('linear.bias', tensor([1.0598]))])
# OrderedDict([('linear.weight', tensor([[1.9873]])), ('linear.bias', tensor([1.0598]))])
# OrderedDict([('linear.weight', tensor([[1.9873]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[1.9874]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[1.9875]])), ('linear.bias', tensor([1.0596]))])
# OrderedDict([('linear.weight', tensor([[1.9876]])), ('linear.bias', tensor([1.0596]))])
# OrderedDict([('linear.weight', tensor([[1.9877]])), ('linear.bias', tensor([1.0595]))])
# OrderedDict([('linear.weight', tensor([[1.9878]])), ('linear.bias', tensor([1.0595]))])
# OrderedDict([('linear.weight', tensor([[1.9879]])), ('linear.bias', tensor([1.0594]))])
# OrderedDict([('linear.weight', tensor([[1.9880]])), ('linear.bias', tensor([1.0594]))])
# OrderedDict([('linear.weight', tensor([[1.9881]])), ('linear.bias', tensor([1.0593]))])
# OrderedDict([('linear.weight', tensor([[1.9882]])), ('linear.bias', tensor([1.0593]))])
# OrderedDict([('linear.weight', tensor([[1.9883]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9883]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9884]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9885]])), ('linear.bias', tensor([1.0591]))])
# OrderedDict([('linear.weight', tensor([[1.9886]])), ('linear.bias', tensor([1.0591]))])
# OrderedDict([('linear.weight', tensor([[1.9887]])), ('linear.bias', tensor([1.0590]))])
# OrderedDict([('linear.weight', tensor([[1.9887]])), ('linear.bias', tensor([1.0590]))])
# OrderedDict([('linear.weight', tensor([[1.9888]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[1.9889]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[1.9890]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[1.9890]])), ('linear.bias', tensor([1.0588]))])
# OrderedDict([('linear.weight', tensor([[1.9891]])), ('linear.bias', tensor([1.0588]))])
# OrderedDict([('linear.weight', tensor([[1.9892]])), ('linear.bias', tensor([1.0587]))])
# OrderedDict([('linear.weight', tensor([[1.9893]])), ('linear.bias', tensor([1.0587]))])
# OrderedDict([('linear.weight', tensor([[1.9893]])), ('linear.bias', tensor([1.0587]))])
# OrderedDict([('linear.weight', tensor([[1.9894]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[1.9895]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[1.9895]])), ('linear.bias', tensor([1.0585]))])
# OrderedDict([('linear.weight', tensor([[1.9896]])), ('linear.bias', tensor([1.0585]))])
# OrderedDict([('linear.weight', tensor([[1.9897]])), ('linear.bias', tensor([1.0585]))])
# OrderedDict([('linear.weight', tensor([[1.9897]])), ('linear.bias', tensor([1.0584]))])
# OrderedDict([('linear.weight', tensor([[1.9898]])), ('linear.bias', tensor([1.0584]))])
# OrderedDict([('linear.weight', tensor([[1.9899]])), ('linear.bias', tensor([1.0584]))])
# OrderedDict([('linear.weight', tensor([[1.9899]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[1.9900]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[1.9901]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[1.9901]])), ('linear.bias', tensor([1.0582]))])
# OrderedDict([('linear.weight', tensor([[1.9902]])), ('linear.bias', tensor([1.0582]))])
# OrderedDict([('linear.weight', tensor([[1.9902]])), ('linear.bias', tensor([1.0582]))])
# OrderedDict([('linear.weight', tensor([[1.9903]])), ('linear.bias', tensor([1.0581]))])
# OrderedDict([('linear.weight', tensor([[1.9903]])), ('linear.bias', tensor([1.0581]))])
# OrderedDict([('linear.weight', tensor([[1.9904]])), ('linear.bias', tensor([1.0581]))])
# OrderedDict([('linear.weight', tensor([[1.9905]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9905]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9906]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9906]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9907]])), ('linear.bias', tensor([1.0579]))])
# OrderedDict([('linear.weight', tensor([[1.9907]])), ('linear.bias', tensor([1.0579]))])
# OrderedDict([('linear.weight', tensor([[1.9908]])), ('linear.bias', tensor([1.0579]))])
# OrderedDict([('linear.weight', tensor([[1.9908]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[1.9909]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[1.9909]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[1.9910]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[1.9910]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[1.9911]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[1.9911]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[1.9912]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[1.9912]])), ('linear.bias', tensor([1.0576]))])
# OrderedDict([('linear.weight', tensor([[1.9913]])), ('linear.bias', tensor([1.0576]))])
# OrderedDict([('linear.weight', tensor([[1.9913]])), ('linear.bias', tensor([1.0576]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0576]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[1.9915]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[1.9915]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[1.9916]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9916]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9916]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9917]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9917]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9918]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9918]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9918]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9919]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9919]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9920]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9920]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9920]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9921]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9921]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9921]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9923]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9923]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9923]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9925]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9925]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9925]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9926]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9926]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9926]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9926]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0561]))])
# ...
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])

# %% [markdown]
# ## Model parameters

# %%
#print(b,w)
#Inspect the parameters using its state_dict
print(model.state_dict())
# Out:
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0557]))])

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[1.9947]], requires_grad=True), Parameter containing:
# tensor([1.0557], requires_grad=True)]

# %%
x = torch.randn(10, 1)

# %%
x
# Out:
# tensor([[ 0.4740],
#         [ 0.1978],
#         [ 1.1561],
#         [ 0.3965],
#         [-2.4661],
#         [ 0.3623],
#         [ 0.3765],
#         [-0.1808],
#         [ 0.3930],
#         [ 0.4327]])
