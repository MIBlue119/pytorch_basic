# %%
# Import dependency 
import numpy as np 
import torch 
import torch.optim as optim
import torch.nn as nn

# %%
# Data generation 
true_b = 1
true_w = 2 
N = 100

# set the random seed for numpy 
np.random.seed(43)

x= np.random.rand(N,1)
epsilon = (.1 * np.random.rand(N,1))

y = true_b + true_w *x + epsilon

# %%
#Generate training and validating sets
idx = np.arange(N)

# Use first 80 random indices for train 
train_idx = idx[:int(N*.8)]
val_idx = idx[int(N*.8):]

# Generate train and validation sets
x_train, y_train = x[train_idx], y[train_idx]

# %%
# Data preparation 

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Transform data from numpy array to torch tensor
x_train_tensor = torch.as_tensor(x_train).float().to(device)
y_train_tensor = torch.as_tensor(y_train).float().to(device)

# %%
# Build a Dataset
from torch.utils.data import Dataset

class CustomDataset(Dataset):
    def __init__(self, x_tensor, y_tensor):
        self.x = x_tensor
        self.y = y_tensor
    
    def __getitem__(self, index):
        return (self.x[index], self.y[index])
    
    def __len__(self):
        return len(self.x)

train_data = CustomDataset(x_train_tensor, y_train_tensor)
print(train_data[0])
# Out:
# (tensor([0.1151]), tensor([1.2404]))

# %%
#Define the train step

def make_train_step(model, loss_fn, optimizer):
    # Builds function that performs a step in the train loop 
    def perform_train_step(x,y):
        
        # Set the model to TRAIN mode
        model.train()
        
        # Step1: Compute the model's predicition - forward pass
        yhat = model(x)
        
        # Step2: Compute the loss
        loss = loss_fn(yhat, y)
        
        # Step3: Compute gradients for "b" and "w" parameters
        loss.backward()
        
        # Step4: Updates parameters using gradients and the learning rate
        optimizer.step()
        optimizer.zero_grad()
        
        print(model.state_dict())
        # Return the loss 
        return loss.item()
    #Return the function that will be called inside the train loop
    return perform_train_step

# %%
# Model config 

# Define the model 
class ManualLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1,1)
    def forward(self,x):
        return self.linear(x)


# Set learning rate 
lr = 0.1

torch.manual_seed(42)

# Create a model and send it to the device 
model = ManualLinearRegression().to(device)
print(model.state_dict())

# Define a SGD optimizer to update the parameters 
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")


# Create a train_step 
train_step = make_train_step(model, loss_fn, optimizer)
# Out:
# OrderedDict([('linear.weight', tensor([[0.7645]])), ('linear.bias', tensor([0.8300]))])

# %%
# Model training

n_epochs = 1000
losses = []
for epoch in range(n_epochs):
    loss = train_step(x_train_tensor, y_train_tensor)
# Out:
# OrderedDict([('linear.weight', tensor([[0.8715]])), ('linear.bias', tensor([1.0004]))])
# OrderedDict([('linear.weight', tensor([[0.9537]])), ('linear.bias', tensor([1.1258]))])
# OrderedDict([('linear.weight', tensor([[1.0175]])), ('linear.bias', tensor([1.2177]))])
# OrderedDict([('linear.weight', tensor([[1.0675]])), ('linear.bias', tensor([1.2847]))])
# OrderedDict([('linear.weight', tensor([[1.1073]])), ('linear.bias', tensor([1.3332]))])
# OrderedDict([('linear.weight', tensor([[1.1394]])), ('linear.bias', tensor([1.3680]))])
# OrderedDict([('linear.weight', tensor([[1.1657]])), ('linear.bias', tensor([1.3925]))])
# OrderedDict([('linear.weight', tensor([[1.1878]])), ('linear.bias', tensor([1.4094]))])
# OrderedDict([('linear.weight', tensor([[1.2066]])), ('linear.bias', tensor([1.4207]))])
# OrderedDict([('linear.weight', tensor([[1.2230]])), ('linear.bias', tensor([1.4278]))])
# OrderedDict([('linear.weight', tensor([[1.2375]])), ('linear.bias', tensor([1.4318]))])
# OrderedDict([('linear.weight', tensor([[1.2506]])), ('linear.bias', tensor([1.4335]))])
# OrderedDict([('linear.weight', tensor([[1.2627]])), ('linear.bias', tensor([1.4335]))])
# OrderedDict([('linear.weight', tensor([[1.2739]])), ('linear.bias', tensor([1.4323]))])
# OrderedDict([('linear.weight', tensor([[1.2845]])), ('linear.bias', tensor([1.4302]))])
# OrderedDict([('linear.weight', tensor([[1.2946]])), ('linear.bias', tensor([1.4274]))])
# OrderedDict([('linear.weight', tensor([[1.3043]])), ('linear.bias', tensor([1.4242]))])
# OrderedDict([('linear.weight', tensor([[1.3136]])), ('linear.bias', tensor([1.4206]))])
# OrderedDict([('linear.weight', tensor([[1.3227]])), ('linear.bias', tensor([1.4168]))])
# OrderedDict([('linear.weight', tensor([[1.3315]])), ('linear.bias', tensor([1.4128]))])
# OrderedDict([('linear.weight', tensor([[1.3402]])), ('linear.bias', tensor([1.4087]))])
# OrderedDict([('linear.weight', tensor([[1.3486]])), ('linear.bias', tensor([1.4045]))])
# OrderedDict([('linear.weight', tensor([[1.3570]])), ('linear.bias', tensor([1.4003]))])
# OrderedDict([('linear.weight', tensor([[1.3652]])), ('linear.bias', tensor([1.3961]))])
# OrderedDict([('linear.weight', tensor([[1.3732]])), ('linear.bias', tensor([1.3919]))])
# OrderedDict([('linear.weight', tensor([[1.3811]])), ('linear.bias', tensor([1.3877]))])
# OrderedDict([('linear.weight', tensor([[1.3890]])), ('linear.bias', tensor([1.3836]))])
# OrderedDict([('linear.weight', tensor([[1.3967]])), ('linear.bias', tensor([1.3795]))])
# OrderedDict([('linear.weight', tensor([[1.4043]])), ('linear.bias', tensor([1.3754]))])
# OrderedDict([('linear.weight', tensor([[1.4118]])), ('linear.bias', tensor([1.3713]))])
# OrderedDict([('linear.weight', tensor([[1.4192]])), ('linear.bias', tensor([1.3673]))])
# OrderedDict([('linear.weight', tensor([[1.4265]])), ('linear.bias', tensor([1.3634]))])
# OrderedDict([('linear.weight', tensor([[1.4337]])), ('linear.bias', tensor([1.3594]))])
# OrderedDict([('linear.weight', tensor([[1.4408]])), ('linear.bias', tensor([1.3556]))])
# OrderedDict([('linear.weight', tensor([[1.4478]])), ('linear.bias', tensor([1.3517]))])
# OrderedDict([('linear.weight', tensor([[1.4548]])), ('linear.bias', tensor([1.3480]))])
# OrderedDict([('linear.weight', tensor([[1.4616]])), ('linear.bias', tensor([1.3442]))])
# OrderedDict([('linear.weight', tensor([[1.4684]])), ('linear.bias', tensor([1.3406]))])
# OrderedDict([('linear.weight', tensor([[1.4751]])), ('linear.bias', tensor([1.3369]))])
# OrderedDict([('linear.weight', tensor([[1.4817]])), ('linear.bias', tensor([1.3333]))])
# OrderedDict([('linear.weight', tensor([[1.4882]])), ('linear.bias', tensor([1.3298]))])
# OrderedDict([('linear.weight', tensor([[1.4946]])), ('linear.bias', tensor([1.3263]))])
# OrderedDict([('linear.weight', tensor([[1.5010]])), ('linear.bias', tensor([1.3228]))])
# OrderedDict([('linear.weight', tensor([[1.5072]])), ('linear.bias', tensor([1.3194]))])
# OrderedDict([('linear.weight', tensor([[1.5134]])), ('linear.bias', tensor([1.3160]))])
# OrderedDict([('linear.weight', tensor([[1.5195]])), ('linear.bias', tensor([1.3127]))])
# OrderedDict([('linear.weight', tensor([[1.5256]])), ('linear.bias', tensor([1.3094]))])
# OrderedDict([('linear.weight', tensor([[1.5315]])), ('linear.bias', tensor([1.3061]))])
# OrderedDict([('linear.weight', tensor([[1.5374]])), ('linear.bias', tensor([1.3029]))])
# OrderedDict([('linear.weight', tensor([[1.5432]])), ('linear.bias', tensor([1.2998]))])
# OrderedDict([('linear.weight', tensor([[1.5490]])), ('linear.bias', tensor([1.2966]))])
# OrderedDict([('linear.weight', tensor([[1.5546]])), ('linear.bias', tensor([1.2935]))])
# OrderedDict([('linear.weight', tensor([[1.5602]])), ('linear.bias', tensor([1.2905]))])
# OrderedDict([('linear.weight', tensor([[1.5658]])), ('linear.bias', tensor([1.2875]))])
# OrderedDict([('linear.weight', tensor([[1.5712]])), ('linear.bias', tensor([1.2845]))])
# OrderedDict([('linear.weight', tensor([[1.5766]])), ('linear.bias', tensor([1.2816]))])
# OrderedDict([('linear.weight', tensor([[1.5819]])), ('linear.bias', tensor([1.2787]))])
# OrderedDict([('linear.weight', tensor([[1.5872]])), ('linear.bias', tensor([1.2758]))])
# OrderedDict([('linear.weight', tensor([[1.5923]])), ('linear.bias', tensor([1.2730]))])
# OrderedDict([('linear.weight', tensor([[1.5975]])), ('linear.bias', tensor([1.2702]))])
# OrderedDict([('linear.weight', tensor([[1.6025]])), ('linear.bias', tensor([1.2674]))])
# OrderedDict([('linear.weight', tensor([[1.6075]])), ('linear.bias', tensor([1.2647]))])
# OrderedDict([('linear.weight', tensor([[1.6124]])), ('linear.bias', tensor([1.2620]))])
# OrderedDict([('linear.weight', tensor([[1.6173]])), ('linear.bias', tensor([1.2594]))])
# OrderedDict([('linear.weight', tensor([[1.6221]])), ('linear.bias', tensor([1.2567]))])
# OrderedDict([('linear.weight', tensor([[1.6269]])), ('linear.bias', tensor([1.2542]))])
# OrderedDict([('linear.weight', tensor([[1.6315]])), ('linear.bias', tensor([1.2516]))])
# OrderedDict([('linear.weight', tensor([[1.6362]])), ('linear.bias', tensor([1.2491]))])
# OrderedDict([('linear.weight', tensor([[1.6407]])), ('linear.bias', tensor([1.2466]))])
# OrderedDict([('linear.weight', tensor([[1.6452]])), ('linear.bias', tensor([1.2441]))])
# OrderedDict([('linear.weight', tensor([[1.6497]])), ('linear.bias', tensor([1.2417]))])
# OrderedDict([('linear.weight', tensor([[1.6541]])), ('linear.bias', tensor([1.2393]))])
# OrderedDict([('linear.weight', tensor([[1.6584]])), ('linear.bias', tensor([1.2369]))])
# OrderedDict([('linear.weight', tensor([[1.6627]])), ('linear.bias', tensor([1.2346]))])
# OrderedDict([('linear.weight', tensor([[1.6670]])), ('linear.bias', tensor([1.2323]))])
# OrderedDict([('linear.weight', tensor([[1.6711]])), ('linear.bias', tensor([1.2300]))])
# OrderedDict([('linear.weight', tensor([[1.6753]])), ('linear.bias', tensor([1.2278]))])
# OrderedDict([('linear.weight', tensor([[1.6793]])), ('linear.bias', tensor([1.2255]))])
# OrderedDict([('linear.weight', tensor([[1.6834]])), ('linear.bias', tensor([1.2233]))])
# OrderedDict([('linear.weight', tensor([[1.6873]])), ('linear.bias', tensor([1.2212]))])
# OrderedDict([('linear.weight', tensor([[1.6913]])), ('linear.bias', tensor([1.2190]))])
# OrderedDict([('linear.weight', tensor([[1.6951]])), ('linear.bias', tensor([1.2169]))])
# OrderedDict([('linear.weight', tensor([[1.6990]])), ('linear.bias', tensor([1.2148]))])
# OrderedDict([('linear.weight', tensor([[1.7028]])), ('linear.bias', tensor([1.2128]))])
# OrderedDict([('linear.weight', tensor([[1.7065]])), ('linear.bias', tensor([1.2107]))])
# OrderedDict([('linear.weight', tensor([[1.7102]])), ('linear.bias', tensor([1.2087]))])
# OrderedDict([('linear.weight', tensor([[1.7138]])), ('linear.bias', tensor([1.2067]))])
# OrderedDict([('linear.weight', tensor([[1.7174]])), ('linear.bias', tensor([1.2048]))])
# OrderedDict([('linear.weight', tensor([[1.7209]])), ('linear.bias', tensor([1.2029]))])
# OrderedDict([('linear.weight', tensor([[1.7244]])), ('linear.bias', tensor([1.2009]))])
# OrderedDict([('linear.weight', tensor([[1.7279]])), ('linear.bias', tensor([1.1991]))])
# OrderedDict([('linear.weight', tensor([[1.7313]])), ('linear.bias', tensor([1.1972]))])
# OrderedDict([('linear.weight', tensor([[1.7347]])), ('linear.bias', tensor([1.1954]))])
# OrderedDict([('linear.weight', tensor([[1.7380]])), ('linear.bias', tensor([1.1935]))])
# OrderedDict([('linear.weight', tensor([[1.7413]])), ('linear.bias', tensor([1.1918]))])
# OrderedDict([('linear.weight', tensor([[1.7446]])), ('linear.bias', tensor([1.1900]))])
# OrderedDict([('linear.weight', tensor([[1.7478]])), ('linear.bias', tensor([1.1882]))])
# OrderedDict([('linear.weight', tensor([[1.7509]])), ('linear.bias', tensor([1.1865]))])
# OrderedDict([('linear.weight', tensor([[1.7540]])), ('linear.bias', tensor([1.1848]))])
# OrderedDict([('linear.weight', tensor([[1.7571]])), ('linear.bias', tensor([1.1831]))])
# OrderedDict([('linear.weight', tensor([[1.7602]])), ('linear.bias', tensor([1.1815]))])
# OrderedDict([('linear.weight', tensor([[1.7632]])), ('linear.bias', tensor([1.1798]))])
# OrderedDict([('linear.weight', tensor([[1.7662]])), ('linear.bias', tensor([1.1782]))])
# OrderedDict([('linear.weight', tensor([[1.7691]])), ('linear.bias', tensor([1.1766]))])
# OrderedDict([('linear.weight', tensor([[1.7720]])), ('linear.bias', tensor([1.1750]))])
# OrderedDict([('linear.weight', tensor([[1.7748]])), ('linear.bias', tensor([1.1735]))])
# OrderedDict([('linear.weight', tensor([[1.7777]])), ('linear.bias', tensor([1.1719]))])
# OrderedDict([('linear.weight', tensor([[1.7805]])), ('linear.bias', tensor([1.1704]))])
# OrderedDict([('linear.weight', tensor([[1.7832]])), ('linear.bias', tensor([1.1689]))])
# OrderedDict([('linear.weight', tensor([[1.7859]])), ('linear.bias', tensor([1.1674]))])
# OrderedDict([('linear.weight', tensor([[1.7886]])), ('linear.bias', tensor([1.1660]))])
# OrderedDict([('linear.weight', tensor([[1.7913]])), ('linear.bias', tensor([1.1645]))])
# OrderedDict([('linear.weight', tensor([[1.7939]])), ('linear.bias', tensor([1.1631]))])
# OrderedDict([('linear.weight', tensor([[1.7965]])), ('linear.bias', tensor([1.1617]))])
# OrderedDict([('linear.weight', tensor([[1.7990]])), ('linear.bias', tensor([1.1603]))])
# OrderedDict([('linear.weight', tensor([[1.8015]])), ('linear.bias', tensor([1.1589]))])
# OrderedDict([('linear.weight', tensor([[1.8040]])), ('linear.bias', tensor([1.1576]))])
# OrderedDict([('linear.weight', tensor([[1.8065]])), ('linear.bias', tensor([1.1562]))])
# OrderedDict([('linear.weight', tensor([[1.8089]])), ('linear.bias', tensor([1.1549]))])
# OrderedDict([('linear.weight', tensor([[1.8113]])), ('linear.bias', tensor([1.1536]))])
# OrderedDict([('linear.weight', tensor([[1.8137]])), ('linear.bias', tensor([1.1523]))])
# OrderedDict([('linear.weight', tensor([[1.8160]])), ('linear.bias', tensor([1.1510]))])
# OrderedDict([('linear.weight', tensor([[1.8183]])), ('linear.bias', tensor([1.1498]))])
# OrderedDict([('linear.weight', tensor([[1.8206]])), ('linear.bias', tensor([1.1485]))])
# OrderedDict([('linear.weight', tensor([[1.8228]])), ('linear.bias', tensor([1.1473]))])
# OrderedDict([('linear.weight', tensor([[1.8251]])), ('linear.bias', tensor([1.1461]))])
# OrderedDict([('linear.weight', tensor([[1.8273]])), ('linear.bias', tensor([1.1449]))])
# OrderedDict([('linear.weight', tensor([[1.8294]])), ('linear.bias', tensor([1.1437]))])
# OrderedDict([('linear.weight', tensor([[1.8316]])), ('linear.bias', tensor([1.1425]))])
# OrderedDict([('linear.weight', tensor([[1.8337]])), ('linear.bias', tensor([1.1414]))])
# OrderedDict([('linear.weight', tensor([[1.8358]])), ('linear.bias', tensor([1.1403]))])
# OrderedDict([('linear.weight', tensor([[1.8378]])), ('linear.bias', tensor([1.1391]))])
# OrderedDict([('linear.weight', tensor([[1.8398]])), ('linear.bias', tensor([1.1380]))])
# OrderedDict([('linear.weight', tensor([[1.8418]])), ('linear.bias', tensor([1.1369]))])
# OrderedDict([('linear.weight', tensor([[1.8438]])), ('linear.bias', tensor([1.1358]))])
# OrderedDict([('linear.weight', tensor([[1.8458]])), ('linear.bias', tensor([1.1348]))])
# OrderedDict([('linear.weight', tensor([[1.8477]])), ('linear.bias', tensor([1.1337]))])
# OrderedDict([('linear.weight', tensor([[1.8496]])), ('linear.bias', tensor([1.1327]))])
# OrderedDict([('linear.weight', tensor([[1.8515]])), ('linear.bias', tensor([1.1317]))])
# OrderedDict([('linear.weight', tensor([[1.8534]])), ('linear.bias', tensor([1.1306]))])
# OrderedDict([('linear.weight', tensor([[1.8552]])), ('linear.bias', tensor([1.1296]))])
# OrderedDict([('linear.weight', tensor([[1.8570]])), ('linear.bias', tensor([1.1287]))])
# OrderedDict([('linear.weight', tensor([[1.8588]])), ('linear.bias', tensor([1.1277]))])
# OrderedDict([('linear.weight', tensor([[1.8606]])), ('linear.bias', tensor([1.1267]))])
# OrderedDict([('linear.weight', tensor([[1.8623]])), ('linear.bias', tensor([1.1258]))])
# OrderedDict([('linear.weight', tensor([[1.8640]])), ('linear.bias', tensor([1.1248]))])
# OrderedDict([('linear.weight', tensor([[1.8657]])), ('linear.bias', tensor([1.1239]))])
# OrderedDict([('linear.weight', tensor([[1.8674]])), ('linear.bias', tensor([1.1230]))])
# OrderedDict([('linear.weight', tensor([[1.8691]])), ('linear.bias', tensor([1.1221]))])
# OrderedDict([('linear.weight', tensor([[1.8707]])), ('linear.bias', tensor([1.1212]))])
# OrderedDict([('linear.weight', tensor([[1.8723]])), ('linear.bias', tensor([1.1203]))])
# OrderedDict([('linear.weight', tensor([[1.8739]])), ('linear.bias', tensor([1.1194]))])
# OrderedDict([('linear.weight', tensor([[1.8755]])), ('linear.bias', tensor([1.1186]))])
# OrderedDict([('linear.weight', tensor([[1.8771]])), ('linear.bias', tensor([1.1177]))])
# OrderedDict([('linear.weight', tensor([[1.8786]])), ('linear.bias', tensor([1.1169]))])
# OrderedDict([('linear.weight', tensor([[1.8801]])), ('linear.bias', tensor([1.1161]))])
# OrderedDict([('linear.weight', tensor([[1.8816]])), ('linear.bias', tensor([1.1152]))])
# OrderedDict([('linear.weight', tensor([[1.8831]])), ('linear.bias', tensor([1.1144]))])
# OrderedDict([('linear.weight', tensor([[1.8846]])), ('linear.bias', tensor([1.1136]))])
# OrderedDict([('linear.weight', tensor([[1.8860]])), ('linear.bias', tensor([1.1128]))])
# OrderedDict([('linear.weight', tensor([[1.8874]])), ('linear.bias', tensor([1.1121]))])
# OrderedDict([('linear.weight', tensor([[1.8889]])), ('linear.bias', tensor([1.1113]))])
# OrderedDict([('linear.weight', tensor([[1.8902]])), ('linear.bias', tensor([1.1105]))])
# OrderedDict([('linear.weight', tensor([[1.8916]])), ('linear.bias', tensor([1.1098]))])
# OrderedDict([('linear.weight', tensor([[1.8930]])), ('linear.bias', tensor([1.1091]))])
# OrderedDict([('linear.weight', tensor([[1.8943]])), ('linear.bias', tensor([1.1083]))])
# OrderedDict([('linear.weight', tensor([[1.8956]])), ('linear.bias', tensor([1.1076]))])
# OrderedDict([('linear.weight', tensor([[1.8969]])), ('linear.bias', tensor([1.1069]))])
# OrderedDict([('linear.weight', tensor([[1.8982]])), ('linear.bias', tensor([1.1062]))])
# OrderedDict([('linear.weight', tensor([[1.8995]])), ('linear.bias', tensor([1.1055]))])
# OrderedDict([('linear.weight', tensor([[1.9008]])), ('linear.bias', tensor([1.1048]))])
# OrderedDict([('linear.weight', tensor([[1.9020]])), ('linear.bias', tensor([1.1041]))])
# OrderedDict([('linear.weight', tensor([[1.9032]])), ('linear.bias', tensor([1.1035]))])
# OrderedDict([('linear.weight', tensor([[1.9044]])), ('linear.bias', tensor([1.1028]))])
# OrderedDict([('linear.weight', tensor([[1.9056]])), ('linear.bias', tensor([1.1022]))])
# OrderedDict([('linear.weight', tensor([[1.9068]])), ('linear.bias', tensor([1.1015]))])
# OrderedDict([('linear.weight', tensor([[1.9080]])), ('linear.bias', tensor([1.1009]))])
# OrderedDict([('linear.weight', tensor([[1.9091]])), ('linear.bias', tensor([1.1002]))])
# OrderedDict([('linear.weight', tensor([[1.9103]])), ('linear.bias', tensor([1.0996]))])
# OrderedDict([('linear.weight', tensor([[1.9114]])), ('linear.bias', tensor([1.0990]))])
# OrderedDict([('linear.weight', tensor([[1.9125]])), ('linear.bias', tensor([1.0984]))])
# OrderedDict([('linear.weight', tensor([[1.9136]])), ('linear.bias', tensor([1.0978]))])
# OrderedDict([('linear.weight', tensor([[1.9147]])), ('linear.bias', tensor([1.0972]))])
# OrderedDict([('linear.weight', tensor([[1.9157]])), ('linear.bias', tensor([1.0966]))])
# OrderedDict([('linear.weight', tensor([[1.9168]])), ('linear.bias', tensor([1.0961]))])
# OrderedDict([('linear.weight', tensor([[1.9178]])), ('linear.bias', tensor([1.0955]))])
# OrderedDict([('linear.weight', tensor([[1.9188]])), ('linear.bias', tensor([1.0949]))])
# OrderedDict([('linear.weight', tensor([[1.9198]])), ('linear.bias', tensor([1.0944]))])
# OrderedDict([('linear.weight', tensor([[1.9208]])), ('linear.bias', tensor([1.0939]))])
# OrderedDict([('linear.weight', tensor([[1.9218]])), ('linear.bias', tensor([1.0933]))])
# OrderedDict([('linear.weight', tensor([[1.9228]])), ('linear.bias', tensor([1.0928]))])
# OrderedDict([('linear.weight', tensor([[1.9238]])), ('linear.bias', tensor([1.0923]))])
# OrderedDict([('linear.weight', tensor([[1.9247]])), ('linear.bias', tensor([1.0917]))])
# OrderedDict([('linear.weight', tensor([[1.9257]])), ('linear.bias', tensor([1.0912]))])
# OrderedDict([('linear.weight', tensor([[1.9266]])), ('linear.bias', tensor([1.0907]))])
# OrderedDict([('linear.weight', tensor([[1.9275]])), ('linear.bias', tensor([1.0902]))])
# OrderedDict([('linear.weight', tensor([[1.9284]])), ('linear.bias', tensor([1.0897]))])
# OrderedDict([('linear.weight', tensor([[1.9293]])), ('linear.bias', tensor([1.0892]))])
# OrderedDict([('linear.weight', tensor([[1.9302]])), ('linear.bias', tensor([1.0888]))])
# OrderedDict([('linear.weight', tensor([[1.9311]])), ('linear.bias', tensor([1.0883]))])
# OrderedDict([('linear.weight', tensor([[1.9319]])), ('linear.bias', tensor([1.0878]))])
# OrderedDict([('linear.weight', tensor([[1.9328]])), ('linear.bias', tensor([1.0874]))])
# OrderedDict([('linear.weight', tensor([[1.9336]])), ('linear.bias', tensor([1.0869]))])
# OrderedDict([('linear.weight', tensor([[1.9344]])), ('linear.bias', tensor([1.0864]))])
# OrderedDict([('linear.weight', tensor([[1.9352]])), ('linear.bias', tensor([1.0860]))])
# OrderedDict([('linear.weight', tensor([[1.9361]])), ('linear.bias', tensor([1.0856]))])
# OrderedDict([('linear.weight', tensor([[1.9368]])), ('linear.bias', tensor([1.0851]))])
# OrderedDict([('linear.weight', tensor([[1.9376]])), ('linear.bias', tensor([1.0847]))])
# OrderedDict([('linear.weight', tensor([[1.9384]])), ('linear.bias', tensor([1.0843]))])
# OrderedDict([('linear.weight', tensor([[1.9392]])), ('linear.bias', tensor([1.0839]))])
# OrderedDict([('linear.weight', tensor([[1.9399]])), ('linear.bias', tensor([1.0834]))])
# OrderedDict([('linear.weight', tensor([[1.9407]])), ('linear.bias', tensor([1.0830]))])
# OrderedDict([('linear.weight', tensor([[1.9414]])), ('linear.bias', tensor([1.0826]))])
# OrderedDict([('linear.weight', tensor([[1.9421]])), ('linear.bias', tensor([1.0822]))])
# OrderedDict([('linear.weight', tensor([[1.9429]])), ('linear.bias', tensor([1.0818]))])
# OrderedDict([('linear.weight', tensor([[1.9436]])), ('linear.bias', tensor([1.0815]))])
# OrderedDict([('linear.weight', tensor([[1.9443]])), ('linear.bias', tensor([1.0811]))])
# OrderedDict([('linear.weight', tensor([[1.9450]])), ('linear.bias', tensor([1.0807]))])
# OrderedDict([('linear.weight', tensor([[1.9457]])), ('linear.bias', tensor([1.0803]))])
# OrderedDict([('linear.weight', tensor([[1.9463]])), ('linear.bias', tensor([1.0800]))])
# OrderedDict([('linear.weight', tensor([[1.9470]])), ('linear.bias', tensor([1.0796]))])
# OrderedDict([('linear.weight', tensor([[1.9477]])), ('linear.bias', tensor([1.0792]))])
# OrderedDict([('linear.weight', tensor([[1.9483]])), ('linear.bias', tensor([1.0789]))])
# OrderedDict([('linear.weight', tensor([[1.9490]])), ('linear.bias', tensor([1.0785]))])
# OrderedDict([('linear.weight', tensor([[1.9496]])), ('linear.bias', tensor([1.0782]))])
# OrderedDict([('linear.weight', tensor([[1.9502]])), ('linear.bias', tensor([1.0778]))])
# OrderedDict([('linear.weight', tensor([[1.9508]])), ('linear.bias', tensor([1.0775]))])
# OrderedDict([('linear.weight', tensor([[1.9514]])), ('linear.bias', tensor([1.0772]))])
# OrderedDict([('linear.weight', tensor([[1.9520]])), ('linear.bias', tensor([1.0768]))])
# OrderedDict([('linear.weight', tensor([[1.9526]])), ('linear.bias', tensor([1.0765]))])
# OrderedDict([('linear.weight', tensor([[1.9532]])), ('linear.bias', tensor([1.0762]))])
# OrderedDict([('linear.weight', tensor([[1.9538]])), ('linear.bias', tensor([1.0759]))])
# OrderedDict([('linear.weight', tensor([[1.9544]])), ('linear.bias', tensor([1.0756]))])
# OrderedDict([('linear.weight', tensor([[1.9549]])), ('linear.bias', tensor([1.0753]))])
# OrderedDict([('linear.weight', tensor([[1.9555]])), ('linear.bias', tensor([1.0750]))])
# OrderedDict([('linear.weight', tensor([[1.9561]])), ('linear.bias', tensor([1.0747]))])
# OrderedDict([('linear.weight', tensor([[1.9566]])), ('linear.bias', tensor([1.0744]))])
# OrderedDict([('linear.weight', tensor([[1.9571]])), ('linear.bias', tensor([1.0741]))])
# OrderedDict([('linear.weight', tensor([[1.9577]])), ('linear.bias', tensor([1.0738]))])
# OrderedDict([('linear.weight', tensor([[1.9582]])), ('linear.bias', tensor([1.0735]))])
# OrderedDict([('linear.weight', tensor([[1.9587]])), ('linear.bias', tensor([1.0732]))])
# OrderedDict([('linear.weight', tensor([[1.9592]])), ('linear.bias', tensor([1.0729]))])
# OrderedDict([('linear.weight', tensor([[1.9597]])), ('linear.bias', tensor([1.0726]))])
# OrderedDict([('linear.weight', tensor([[1.9602]])), ('linear.bias', tensor([1.0724]))])
# OrderedDict([('linear.weight', tensor([[1.9607]])), ('linear.bias', tensor([1.0721]))])
# OrderedDict([('linear.weight', tensor([[1.9612]])), ('linear.bias', tensor([1.0718]))])
# OrderedDict([('linear.weight', tensor([[1.9617]])), ('linear.bias', tensor([1.0716]))])
# OrderedDict([('linear.weight', tensor([[1.9622]])), ('linear.bias', tensor([1.0713]))])
# OrderedDict([('linear.weight', tensor([[1.9626]])), ('linear.bias', tensor([1.0711]))])
# OrderedDict([('linear.weight', tensor([[1.9631]])), ('linear.bias', tensor([1.0708]))])
# OrderedDict([('linear.weight', tensor([[1.9635]])), ('linear.bias', tensor([1.0706]))])
# OrderedDict([('linear.weight', tensor([[1.9640]])), ('linear.bias', tensor([1.0703]))])
# OrderedDict([('linear.weight', tensor([[1.9644]])), ('linear.bias', tensor([1.0701]))])
# OrderedDict([('linear.weight', tensor([[1.9649]])), ('linear.bias', tensor([1.0698]))])
# OrderedDict([('linear.weight', tensor([[1.9653]])), ('linear.bias', tensor([1.0696]))])
# OrderedDict([('linear.weight', tensor([[1.9657]])), ('linear.bias', tensor([1.0694]))])
# OrderedDict([('linear.weight', tensor([[1.9662]])), ('linear.bias', tensor([1.0691]))])
# OrderedDict([('linear.weight', tensor([[1.9666]])), ('linear.bias', tensor([1.0689]))])
# OrderedDict([('linear.weight', tensor([[1.9670]])), ('linear.bias', tensor([1.0687]))])
# OrderedDict([('linear.weight', tensor([[1.9674]])), ('linear.bias', tensor([1.0685]))])
# OrderedDict([('linear.weight', tensor([[1.9678]])), ('linear.bias', tensor([1.0682]))])
# OrderedDict([('linear.weight', tensor([[1.9682]])), ('linear.bias', tensor([1.0680]))])
# OrderedDict([('linear.weight', tensor([[1.9686]])), ('linear.bias', tensor([1.0678]))])
# OrderedDict([('linear.weight', tensor([[1.9690]])), ('linear.bias', tensor([1.0676]))])
# OrderedDict([('linear.weight', tensor([[1.9694]])), ('linear.bias', tensor([1.0674]))])
# OrderedDict([('linear.weight', tensor([[1.9697]])), ('linear.bias', tensor([1.0672]))])
# OrderedDict([('linear.weight', tensor([[1.9701]])), ('linear.bias', tensor([1.0670]))])
# OrderedDict([('linear.weight', tensor([[1.9705]])), ('linear.bias', tensor([1.0668]))])
# OrderedDict([('linear.weight', tensor([[1.9708]])), ('linear.bias', tensor([1.0666]))])
# OrderedDict([('linear.weight', tensor([[1.9712]])), ('linear.bias', tensor([1.0664]))])
# OrderedDict([('linear.weight', tensor([[1.9716]])), ('linear.bias', tensor([1.0662]))])
# OrderedDict([('linear.weight', tensor([[1.9719]])), ('linear.bias', tensor([1.0660]))])
# OrderedDict([('linear.weight', tensor([[1.9723]])), ('linear.bias', tensor([1.0658]))])
# OrderedDict([('linear.weight', tensor([[1.9726]])), ('linear.bias', tensor([1.0656]))])
# OrderedDict([('linear.weight', tensor([[1.9729]])), ('linear.bias', tensor([1.0655]))])
# OrderedDict([('linear.weight', tensor([[1.9733]])), ('linear.bias', tensor([1.0653]))])
# OrderedDict([('linear.weight', tensor([[1.9736]])), ('linear.bias', tensor([1.0651]))])
# OrderedDict([('linear.weight', tensor([[1.9739]])), ('linear.bias', tensor([1.0649]))])
# OrderedDict([('linear.weight', tensor([[1.9742]])), ('linear.bias', tensor([1.0647]))])
# OrderedDict([('linear.weight', tensor([[1.9746]])), ('linear.bias', tensor([1.0646]))])
# OrderedDict([('linear.weight', tensor([[1.9749]])), ('linear.bias', tensor([1.0644]))])
# OrderedDict([('linear.weight', tensor([[1.9752]])), ('linear.bias', tensor([1.0642]))])
# OrderedDict([('linear.weight', tensor([[1.9755]])), ('linear.bias', tensor([1.0641]))])
# OrderedDict([('linear.weight', tensor([[1.9758]])), ('linear.bias', tensor([1.0639]))])
# OrderedDict([('linear.weight', tensor([[1.9761]])), ('linear.bias', tensor([1.0637]))])
# OrderedDict([('linear.weight', tensor([[1.9764]])), ('linear.bias', tensor([1.0636]))])
# OrderedDict([('linear.weight', tensor([[1.9767]])), ('linear.bias', tensor([1.0634]))])
# OrderedDict([('linear.weight', tensor([[1.9769]])), ('linear.bias', tensor([1.0633]))])
# OrderedDict([('linear.weight', tensor([[1.9772]])), ('linear.bias', tensor([1.0631]))])
# OrderedDict([('linear.weight', tensor([[1.9775]])), ('linear.bias', tensor([1.0630]))])
# OrderedDict([('linear.weight', tensor([[1.9778]])), ('linear.bias', tensor([1.0628]))])
# OrderedDict([('linear.weight', tensor([[1.9781]])), ('linear.bias', tensor([1.0627]))])
# OrderedDict([('linear.weight', tensor([[1.9783]])), ('linear.bias', tensor([1.0625]))])
# OrderedDict([('linear.weight', tensor([[1.9786]])), ('linear.bias', tensor([1.0624]))])
# OrderedDict([('linear.weight', tensor([[1.9788]])), ('linear.bias', tensor([1.0622]))])
# OrderedDict([('linear.weight', tensor([[1.9791]])), ('linear.bias', tensor([1.0621]))])
# OrderedDict([('linear.weight', tensor([[1.9794]])), ('linear.bias', tensor([1.0619]))])
# OrderedDict([('linear.weight', tensor([[1.9796]])), ('linear.bias', tensor([1.0618]))])
# OrderedDict([('linear.weight', tensor([[1.9799]])), ('linear.bias', tensor([1.0617]))])
# OrderedDict([('linear.weight', tensor([[1.9801]])), ('linear.bias', tensor([1.0615]))])
# OrderedDict([('linear.weight', tensor([[1.9803]])), ('linear.bias', tensor([1.0614]))])
# OrderedDict([('linear.weight', tensor([[1.9806]])), ('linear.bias', tensor([1.0613]))])
# OrderedDict([('linear.weight', tensor([[1.9808]])), ('linear.bias', tensor([1.0611]))])
# OrderedDict([('linear.weight', tensor([[1.9811]])), ('linear.bias', tensor([1.0610]))])
# OrderedDict([('linear.weight', tensor([[1.9813]])), ('linear.bias', tensor([1.0609]))])
# OrderedDict([('linear.weight', tensor([[1.9815]])), ('linear.bias', tensor([1.0608]))])
# OrderedDict([('linear.weight', tensor([[1.9817]])), ('linear.bias', tensor([1.0606]))])
# OrderedDict([('linear.weight', tensor([[1.9820]])), ('linear.bias', tensor([1.0605]))])
# OrderedDict([('linear.weight', tensor([[1.9822]])), ('linear.bias', tensor([1.0604]))])
# OrderedDict([('linear.weight', tensor([[1.9824]])), ('linear.bias', tensor([1.0603]))])
# OrderedDict([('linear.weight', tensor([[1.9826]])), ('linear.bias', tensor([1.0602]))])
# OrderedDict([('linear.weight', tensor([[1.9828]])), ('linear.bias', tensor([1.0601]))])
# OrderedDict([('linear.weight', tensor([[1.9830]])), ('linear.bias', tensor([1.0599]))])
# OrderedDict([('linear.weight', tensor([[1.9832]])), ('linear.bias', tensor([1.0598]))])
# OrderedDict([('linear.weight', tensor([[1.9834]])), ('linear.bias', tensor([1.0597]))])
# OrderedDict([('linear.weight', tensor([[1.9836]])), ('linear.bias', tensor([1.0596]))])
# OrderedDict([('linear.weight', tensor([[1.9838]])), ('linear.bias', tensor([1.0595]))])
# OrderedDict([('linear.weight', tensor([[1.9840]])), ('linear.bias', tensor([1.0594]))])
# OrderedDict([('linear.weight', tensor([[1.9842]])), ('linear.bias', tensor([1.0593]))])
# OrderedDict([('linear.weight', tensor([[1.9844]])), ('linear.bias', tensor([1.0592]))])
# OrderedDict([('linear.weight', tensor([[1.9846]])), ('linear.bias', tensor([1.0591]))])
# OrderedDict([('linear.weight', tensor([[1.9848]])), ('linear.bias', tensor([1.0590]))])
# OrderedDict([('linear.weight', tensor([[1.9850]])), ('linear.bias', tensor([1.0589]))])
# OrderedDict([('linear.weight', tensor([[1.9852]])), ('linear.bias', tensor([1.0588]))])
# OrderedDict([('linear.weight', tensor([[1.9853]])), ('linear.bias', tensor([1.0587]))])
# OrderedDict([('linear.weight', tensor([[1.9855]])), ('linear.bias', tensor([1.0586]))])
# OrderedDict([('linear.weight', tensor([[1.9857]])), ('linear.bias', tensor([1.0585]))])
# OrderedDict([('linear.weight', tensor([[1.9859]])), ('linear.bias', tensor([1.0584]))])
# OrderedDict([('linear.weight', tensor([[1.9860]])), ('linear.bias', tensor([1.0583]))])
# OrderedDict([('linear.weight', tensor([[1.9862]])), ('linear.bias', tensor([1.0582]))])
# OrderedDict([('linear.weight', tensor([[1.9864]])), ('linear.bias', tensor([1.0581]))])
# OrderedDict([('linear.weight', tensor([[1.9865]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9867]])), ('linear.bias', tensor([1.0580]))])
# OrderedDict([('linear.weight', tensor([[1.9868]])), ('linear.bias', tensor([1.0579]))])
# OrderedDict([('linear.weight', tensor([[1.9870]])), ('linear.bias', tensor([1.0578]))])
# OrderedDict([('linear.weight', tensor([[1.9872]])), ('linear.bias', tensor([1.0577]))])
# OrderedDict([('linear.weight', tensor([[1.9873]])), ('linear.bias', tensor([1.0576]))])
# OrderedDict([('linear.weight', tensor([[1.9875]])), ('linear.bias', tensor([1.0575]))])
# OrderedDict([('linear.weight', tensor([[1.9876]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9878]])), ('linear.bias', tensor([1.0574]))])
# OrderedDict([('linear.weight', tensor([[1.9879]])), ('linear.bias', tensor([1.0573]))])
# OrderedDict([('linear.weight', tensor([[1.9880]])), ('linear.bias', tensor([1.0572]))])
# OrderedDict([('linear.weight', tensor([[1.9882]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9883]])), ('linear.bias', tensor([1.0571]))])
# OrderedDict([('linear.weight', tensor([[1.9885]])), ('linear.bias', tensor([1.0570]))])
# OrderedDict([('linear.weight', tensor([[1.9886]])), ('linear.bias', tensor([1.0569]))])
# OrderedDict([('linear.weight', tensor([[1.9887]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9889]])), ('linear.bias', tensor([1.0568]))])
# OrderedDict([('linear.weight', tensor([[1.9890]])), ('linear.bias', tensor([1.0567]))])
# OrderedDict([('linear.weight', tensor([[1.9891]])), ('linear.bias', tensor([1.0566]))])
# OrderedDict([('linear.weight', tensor([[1.9893]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9894]])), ('linear.bias', tensor([1.0565]))])
# OrderedDict([('linear.weight', tensor([[1.9895]])), ('linear.bias', tensor([1.0564]))])
# OrderedDict([('linear.weight', tensor([[1.9896]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9898]])), ('linear.bias', tensor([1.0563]))])
# OrderedDict([('linear.weight', tensor([[1.9899]])), ('linear.bias', tensor([1.0562]))])
# OrderedDict([('linear.weight', tensor([[1.9900]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9901]])), ('linear.bias', tensor([1.0561]))])
# OrderedDict([('linear.weight', tensor([[1.9902]])), ('linear.bias', tensor([1.0560]))])
# OrderedDict([('linear.weight', tensor([[1.9904]])), ('linear.bias', tensor([1.0559]))])
# OrderedDict([('linear.weight', tensor([[1.9905]])), ('linear.bias', tensor([1.0559]))])
# OrderedDict([('linear.weight', tensor([[1.9906]])), ('linear.bias', tensor([1.0558]))])
# OrderedDict([('linear.weight', tensor([[1.9907]])), ('linear.bias', tensor([1.0558]))])
# OrderedDict([('linear.weight', tensor([[1.9908]])), ('linear.bias', tensor([1.0557]))])
# OrderedDict([('linear.weight', tensor([[1.9909]])), ('linear.bias', tensor([1.0556]))])
# OrderedDict([('linear.weight', tensor([[1.9910]])), ('linear.bias', tensor([1.0556]))])
# OrderedDict([('linear.weight', tensor([[1.9911]])), ('linear.bias', tensor([1.0555]))])
# OrderedDict([('linear.weight', tensor([[1.9912]])), ('linear.bias', tensor([1.0555]))])
# OrderedDict([('linear.weight', tensor([[1.9913]])), ('linear.bias', tensor([1.0554]))])
# OrderedDict([('linear.weight', tensor([[1.9914]])), ('linear.bias', tensor([1.0554]))])
# OrderedDict([('linear.weight', tensor([[1.9915]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9916]])), ('linear.bias', tensor([1.0553]))])
# OrderedDict([('linear.weight', tensor([[1.9917]])), ('linear.bias', tensor([1.0552]))])
# OrderedDict([('linear.weight', tensor([[1.9918]])), ('linear.bias', tensor([1.0552]))])
# OrderedDict([('linear.weight', tensor([[1.9919]])), ('linear.bias', tensor([1.0551]))])
# OrderedDict([('linear.weight', tensor([[1.9920]])), ('linear.bias', tensor([1.0550]))])
# OrderedDict([('linear.weight', tensor([[1.9921]])), ('linear.bias', tensor([1.0550]))])
# OrderedDict([('linear.weight', tensor([[1.9922]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[1.9923]])), ('linear.bias', tensor([1.0549]))])
# OrderedDict([('linear.weight', tensor([[1.9924]])), ('linear.bias', tensor([1.0548]))])
# OrderedDict([('linear.weight', tensor([[1.9925]])), ('linear.bias', tensor([1.0548]))])
# OrderedDict([('linear.weight', tensor([[1.9925]])), ('linear.bias', tensor([1.0548]))])
# OrderedDict([('linear.weight', tensor([[1.9926]])), ('linear.bias', tensor([1.0547]))])
# OrderedDict([('linear.weight', tensor([[1.9927]])), ('linear.bias', tensor([1.0547]))])
# OrderedDict([('linear.weight', tensor([[1.9928]])), ('linear.bias', tensor([1.0546]))])
# OrderedDict([('linear.weight', tensor([[1.9929]])), ('linear.bias', tensor([1.0546]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0545]))])
# OrderedDict([('linear.weight', tensor([[1.9930]])), ('linear.bias', tensor([1.0545]))])
# OrderedDict([('linear.weight', tensor([[1.9931]])), ('linear.bias', tensor([1.0544]))])
# OrderedDict([('linear.weight', tensor([[1.9932]])), ('linear.bias', tensor([1.0544]))])
# OrderedDict([('linear.weight', tensor([[1.9933]])), ('linear.bias', tensor([1.0544]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0543]))])
# OrderedDict([('linear.weight', tensor([[1.9934]])), ('linear.bias', tensor([1.0543]))])
# OrderedDict([('linear.weight', tensor([[1.9935]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9936]])), ('linear.bias', tensor([1.0542]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0541]))])
# OrderedDict([('linear.weight', tensor([[1.9937]])), ('linear.bias', tensor([1.0541]))])
# OrderedDict([('linear.weight', tensor([[1.9938]])), ('linear.bias', tensor([1.0541]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0540]))])
# OrderedDict([('linear.weight', tensor([[1.9939]])), ('linear.bias', tensor([1.0540]))])
# OrderedDict([('linear.weight', tensor([[1.9940]])), ('linear.bias', tensor([1.0540]))])
# OrderedDict([('linear.weight', tensor([[1.9941]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[1.9941]])), ('linear.bias', tensor([1.0539]))])
# OrderedDict([('linear.weight', tensor([[1.9942]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9943]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9943]])), ('linear.bias', tensor([1.0538]))])
# OrderedDict([('linear.weight', tensor([[1.9944]])), ('linear.bias', tensor([1.0537]))])
# OrderedDict([('linear.weight', tensor([[1.9945]])), ('linear.bias', tensor([1.0537]))])
# OrderedDict([('linear.weight', tensor([[1.9945]])), ('linear.bias', tensor([1.0537]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[1.9946]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[1.9947]])), ('linear.bias', tensor([1.0536]))])
# OrderedDict([('linear.weight', tensor([[1.9948]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[1.9948]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[1.9949]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[1.9949]])), ('linear.bias', tensor([1.0535]))])
# OrderedDict([('linear.weight', tensor([[1.9950]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[1.9950]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[1.9951]])), ('linear.bias', tensor([1.0534]))])
# OrderedDict([('linear.weight', tensor([[1.9952]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[1.9952]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[1.9953]])), ('linear.bias', tensor([1.0533]))])
# OrderedDict([('linear.weight', tensor([[1.9953]])), ('linear.bias', tensor([1.0532]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0532]))])
# OrderedDict([('linear.weight', tensor([[1.9954]])), ('linear.bias', tensor([1.0532]))])
# OrderedDict([('linear.weight', tensor([[1.9955]])), ('linear.bias', tensor([1.0532]))])
# OrderedDict([('linear.weight', tensor([[1.9955]])), ('linear.bias', tensor([1.0531]))])
# OrderedDict([('linear.weight', tensor([[1.9956]])), ('linear.bias', tensor([1.0531]))])
# OrderedDict([('linear.weight', tensor([[1.9956]])), ('linear.bias', tensor([1.0531]))])
# OrderedDict([('linear.weight', tensor([[1.9957]])), ('linear.bias', tensor([1.0531]))])
# OrderedDict([('linear.weight', tensor([[1.9957]])), ('linear.bias', tensor([1.0530]))])
# OrderedDict([('linear.weight', tensor([[1.9957]])), ('linear.bias', tensor([1.0530]))])
# OrderedDict([('linear.weight', tensor([[1.9958]])), ('linear.bias', tensor([1.0530]))])
# OrderedDict([('linear.weight', tensor([[1.9958]])), ('linear.bias', tensor([1.0530]))])
# OrderedDict([('linear.weight', tensor([[1.9959]])), ('linear.bias', tensor([1.0529]))])
# OrderedDict([('linear.weight', tensor([[1.9959]])), ('linear.bias', tensor([1.0529]))])
# OrderedDict([('linear.weight', tensor([[1.9960]])), ('linear.bias', tensor([1.0529]))])
# OrderedDict([('linear.weight', tensor([[1.9960]])), ('linear.bias', tensor([1.0529]))])
# OrderedDict([('linear.weight', tensor([[1.9961]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9961]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9961]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9962]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9962]])), ('linear.bias', tensor([1.0528]))])
# OrderedDict([('linear.weight', tensor([[1.9963]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9963]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9963]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9964]])), ('linear.bias', tensor([1.0527]))])
# OrderedDict([('linear.weight', tensor([[1.9964]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9965]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9965]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9965]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0526]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9966]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9967]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9968]])), ('linear.bias', tensor([1.0525]))])
# OrderedDict([('linear.weight', tensor([[1.9968]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9968]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9969]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0524]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9970]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9971]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9971]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9971]])), ('linear.bias', tensor([1.0523]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9972]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0522]))])
# OrderedDict([('linear.weight', tensor([[1.9973]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9974]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9974]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9974]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9974]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0521]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9975]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9976]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9976]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9976]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9976]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0520]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9977]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9978]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0519]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9979]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9980]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0518]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9981]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0517]))])
# OrderedDict([('linear.weight', tensor([[1.9982]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9983]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0516]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9984]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0515]))])
# OrderedDict([('linear.weight', tensor([[1.9985]])), ('linear.bias', tensor([1.0515]))])
# ...
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9993]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])

# %%
# Model's parameter before training 
print(model.state_dict())
# Out:
# OrderedDict([('linear.weight', tensor([[1.9994]])), ('linear.bias', tensor([1.0510]))])

# %%
# Check model's parameters
#print(model.state_dict())

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[1.9994]], requires_grad=True), Parameter containing:
# tensor([1.0510], requires_grad=True)]
