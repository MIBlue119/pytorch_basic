# %%
import torch.nn as nn
import torch 

#Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")
print(loss_fn)
# Out:
# MSELoss()

# %%
# A example to excute the loss function
predictions = torch.tensor([1.0, 2.0])
ground_truth = torch.tensor([2.0, 5.0])

# Calculate the loss 
print(loss_fn(predictions, ground_truth))
# Out:
# tensor(5.)

# %% [markdown]
# # Import the loss function

# %%
#Data generation 
import numpy as np
import torch 


true_b = 1
true_w = 2 
N = 100

# set the random seed for numpy 
np.random.seed(43)

x= np.random.rand(N,1)
epsilon = (.1 * np.random.rand(N,1))

y = true_b + true_w *x + epsilon

# Generate training and validating sets 
idx = np.arange(N)
np.random.shuffle(idx)

# Use first 80 randowm indices for train
train_idx = idx[:int(N*.8)]
val_idx = idx[int(N*.8):]

# Generate train and validation sets
x_train, y_train = x[train_idx], y[train_idx]
x_val, y_val = x[val_idx], y[val_idx]

# Data preparation 
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Tranform the data from numpy array to torch tensor
x_train_tensor = torch.as_tensor(x_train).float().to(device)
y_train_tensor = torch.as_tensor(y_train).float().to(device)

# %%
# Sets learning rate
lr = 0.1 

# Step 0 : Initialize parameters 'b' and 'w' randomly
torch.manual_seed(42)

b = torch.randn(1, requires_grad=True, \
                dtype=torch.float, device=device)
w = torch.randn(1, requires_grad=True, \
                dtype=torch.float, device=device)

# Define a SGD optimizer to update the parameters
optimizer = torch.optim.SGD([b,w], lr=lr)


#Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")  #1


# Define number of epochs 
n_epochs=1000

for epoch in range(n_epochs):
    # Step 1: Computes the model's predicted output - forward pass
    yhat = b + w*x_train_tensor 
    
    # Step 2: Computes the loss
    # No more manual loss
    # error = (yhat - y_train_tensor)
    # loss = (error**2).mean()
    loss = loss_fn(yhat, y_train_tensor) #2
    
    # Step 3: Computes gradients for both 'b' and 'w' parameters
    loss.backward()
    
    # Step 4: Updates parameters using gradients and the learning rate
    # No more manual update
    # with torch.no_grade():
    #    b-=lr*b.grad
    #    w-=lr*w.grad
    optimizer.step()
    
    
    # Graident Zeroing
    # No more telling pytorch to let gradients go 
    #b.grad.zero()
    #w.grad.zero()
    optimizer.zero_grad()
    print(b,w)

print(b,w)
# Out:
# tensor([0.6706], requires_grad=True) tensor([0.3299], requires_grad=True)
# tensor([0.9172], requires_grad=True) tensor([0.4832], requires_grad=True)
# tensor([1.0989], requires_grad=True) tensor([0.6008], requires_grad=True)
# tensor([1.2323], requires_grad=True) tensor([0.6919], requires_grad=True)
# tensor([1.3297], requires_grad=True) tensor([0.7632], requires_grad=True)
# tensor([1.4003], requires_grad=True) tensor([0.8197], requires_grad=True)
# tensor([1.4511], requires_grad=True) tensor([0.8651], requires_grad=True)
# tensor([1.4871], requires_grad=True) tensor([0.9022], requires_grad=True)
# tensor([1.5121], requires_grad=True) tensor([0.9331], requires_grad=True)
# tensor([1.5290], requires_grad=True) tensor([0.9593], requires_grad=True)
# tensor([1.5398], requires_grad=True) tensor([0.9820], requires_grad=True)
# tensor([1.5462], requires_grad=True) tensor([1.0021], requires_grad=True)
# tensor([1.5492], requires_grad=True) tensor([1.0201], requires_grad=True)
# tensor([1.5498], requires_grad=True) tensor([1.0366], requires_grad=True)
# tensor([1.5486], requires_grad=True) tensor([1.0519], requires_grad=True)
# tensor([1.5460], requires_grad=True) tensor([1.0663], requires_grad=True)
# tensor([1.5426], requires_grad=True) tensor([1.0800], requires_grad=True)
# tensor([1.5384], requires_grad=True) tensor([1.0931], requires_grad=True)
# tensor([1.5337], requires_grad=True) tensor([1.1057], requires_grad=True)
# tensor([1.5287], requires_grad=True) tensor([1.1179], requires_grad=True)
# tensor([1.5234], requires_grad=True) tensor([1.1298], requires_grad=True)
# tensor([1.5180], requires_grad=True) tensor([1.1414], requires_grad=True)
# tensor([1.5125], requires_grad=True) tensor([1.1527], requires_grad=True)
# tensor([1.5069], requires_grad=True) tensor([1.1639], requires_grad=True)
# tensor([1.5013], requires_grad=True) tensor([1.1749], requires_grad=True)
# tensor([1.4957], requires_grad=True) tensor([1.1856], requires_grad=True)
# tensor([1.4901], requires_grad=True) tensor([1.1962], requires_grad=True)
# tensor([1.4846], requires_grad=True) tensor([1.2067], requires_grad=True)
# tensor([1.4791], requires_grad=True) tensor([1.2170], requires_grad=True)
# tensor([1.4736], requires_grad=True) tensor([1.2271], requires_grad=True)
# tensor([1.4683], requires_grad=True) tensor([1.2372], requires_grad=True)
# tensor([1.4629], requires_grad=True) tensor([1.2470], requires_grad=True)
# tensor([1.4577], requires_grad=True) tensor([1.2568], requires_grad=True)
# tensor([1.4524], requires_grad=True) tensor([1.2664], requires_grad=True)
# tensor([1.4473], requires_grad=True) tensor([1.2759], requires_grad=True)
# tensor([1.4422], requires_grad=True) tensor([1.2852], requires_grad=True)
# tensor([1.4372], requires_grad=True) tensor([1.2945], requires_grad=True)
# tensor([1.4322], requires_grad=True) tensor([1.3036], requires_grad=True)
# tensor([1.4273], requires_grad=True) tensor([1.3126], requires_grad=True)
# tensor([1.4225], requires_grad=True) tensor([1.3214], requires_grad=True)
# tensor([1.4177], requires_grad=True) tensor([1.3302], requires_grad=True)
# tensor([1.4130], requires_grad=True) tensor([1.3388], requires_grad=True)
# tensor([1.4084], requires_grad=True) tensor([1.3474], requires_grad=True)
# tensor([1.4038], requires_grad=True) tensor([1.3558], requires_grad=True)
# tensor([1.3993], requires_grad=True) tensor([1.3641], requires_grad=True)
# tensor([1.3948], requires_grad=True) tensor([1.3723], requires_grad=True)
# tensor([1.3904], requires_grad=True) tensor([1.3804], requires_grad=True)
# tensor([1.3860], requires_grad=True) tensor([1.3884], requires_grad=True)
# tensor([1.3817], requires_grad=True) tensor([1.3963], requires_grad=True)
# tensor([1.3775], requires_grad=True) tensor([1.4041], requires_grad=True)
# tensor([1.3733], requires_grad=True) tensor([1.4118], requires_grad=True)
# tensor([1.3692], requires_grad=True) tensor([1.4194], requires_grad=True)
# tensor([1.3651], requires_grad=True) tensor([1.4268], requires_grad=True)
# tensor([1.3611], requires_grad=True) tensor([1.4342], requires_grad=True)
# tensor([1.3571], requires_grad=True) tensor([1.4415], requires_grad=True)
# tensor([1.3532], requires_grad=True) tensor([1.4487], requires_grad=True)
# tensor([1.3493], requires_grad=True) tensor([1.4558], requires_grad=True)
# tensor([1.3455], requires_grad=True) tensor([1.4628], requires_grad=True)
# tensor([1.3417], requires_grad=True) tensor([1.4697], requires_grad=True)
# tensor([1.3380], requires_grad=True) tensor([1.4766], requires_grad=True)
# tensor([1.3343], requires_grad=True) tensor([1.4833], requires_grad=True)
# tensor([1.3307], requires_grad=True) tensor([1.4900], requires_grad=True)
# tensor([1.3271], requires_grad=True) tensor([1.4965], requires_grad=True)
# tensor([1.3236], requires_grad=True) tensor([1.5030], requires_grad=True)
# tensor([1.3201], requires_grad=True) tensor([1.5094], requires_grad=True)
# tensor([1.3167], requires_grad=True) tensor([1.5157], requires_grad=True)
# tensor([1.3133], requires_grad=True) tensor([1.5220], requires_grad=True)
# tensor([1.3099], requires_grad=True) tensor([1.5281], requires_grad=True)
# tensor([1.3066], requires_grad=True) tensor([1.5342], requires_grad=True)
# tensor([1.3034], requires_grad=True) tensor([1.5402], requires_grad=True)
# tensor([1.3001], requires_grad=True) tensor([1.5461], requires_grad=True)
# tensor([1.2970], requires_grad=True) tensor([1.5519], requires_grad=True)
# tensor([1.2938], requires_grad=True) tensor([1.5577], requires_grad=True)
# tensor([1.2907], requires_grad=True) tensor([1.5634], requires_grad=True)
# tensor([1.2877], requires_grad=True) tensor([1.5690], requires_grad=True)
# tensor([1.2846], requires_grad=True) tensor([1.5745], requires_grad=True)
# tensor([1.2817], requires_grad=True) tensor([1.5800], requires_grad=True)
# tensor([1.2787], requires_grad=True) tensor([1.5854], requires_grad=True)
# tensor([1.2758], requires_grad=True) tensor([1.5907], requires_grad=True)
# tensor([1.2730], requires_grad=True) tensor([1.5960], requires_grad=True)
# tensor([1.2701], requires_grad=True) tensor([1.6012], requires_grad=True)
# tensor([1.2673], requires_grad=True) tensor([1.6063], requires_grad=True)
# tensor([1.2646], requires_grad=True) tensor([1.6113], requires_grad=True)
# tensor([1.2619], requires_grad=True) tensor([1.6163], requires_grad=True)
# tensor([1.2592], requires_grad=True) tensor([1.6212], requires_grad=True)
# tensor([1.2565], requires_grad=True) tensor([1.6261], requires_grad=True)
# tensor([1.2539], requires_grad=True) tensor([1.6309], requires_grad=True)
# tensor([1.2514], requires_grad=True) tensor([1.6356], requires_grad=True)
# tensor([1.2488], requires_grad=True) tensor([1.6403], requires_grad=True)
# tensor([1.2463], requires_grad=True) tensor([1.6449], requires_grad=True)
# tensor([1.2438], requires_grad=True) tensor([1.6495], requires_grad=True)
# tensor([1.2414], requires_grad=True) tensor([1.6540], requires_grad=True)
# tensor([1.2390], requires_grad=True) tensor([1.6584], requires_grad=True)
# tensor([1.2366], requires_grad=True) tensor([1.6628], requires_grad=True)
# tensor([1.2342], requires_grad=True) tensor([1.6671], requires_grad=True)
# tensor([1.2319], requires_grad=True) tensor([1.6713], requires_grad=True)
# tensor([1.2296], requires_grad=True) tensor([1.6755], requires_grad=True)
# tensor([1.2273], requires_grad=True) tensor([1.6797], requires_grad=True)
# tensor([1.2251], requires_grad=True) tensor([1.6838], requires_grad=True)
# tensor([1.2229], requires_grad=True) tensor([1.6878], requires_grad=True)
# tensor([1.2207], requires_grad=True) tensor([1.6918], requires_grad=True)
# tensor([1.2186], requires_grad=True) tensor([1.6958], requires_grad=True)
# tensor([1.2165], requires_grad=True) tensor([1.6997], requires_grad=True)
# tensor([1.2144], requires_grad=True) tensor([1.7035], requires_grad=True)
# tensor([1.2123], requires_grad=True) tensor([1.7073], requires_grad=True)
# tensor([1.2103], requires_grad=True) tensor([1.7110], requires_grad=True)
# tensor([1.2083], requires_grad=True) tensor([1.7147], requires_grad=True)
# tensor([1.2063], requires_grad=True) tensor([1.7184], requires_grad=True)
# tensor([1.2043], requires_grad=True) tensor([1.7220], requires_grad=True)
# tensor([1.2024], requires_grad=True) tensor([1.7255], requires_grad=True)
# tensor([1.2005], requires_grad=True) tensor([1.7290], requires_grad=True)
# tensor([1.1986], requires_grad=True) tensor([1.7325], requires_grad=True)
# tensor([1.1967], requires_grad=True) tensor([1.7359], requires_grad=True)
# tensor([1.1949], requires_grad=True) tensor([1.7392], requires_grad=True)
# tensor([1.1931], requires_grad=True) tensor([1.7426], requires_grad=True)
# tensor([1.1913], requires_grad=True) tensor([1.7459], requires_grad=True)
# tensor([1.1895], requires_grad=True) tensor([1.7491], requires_grad=True)
# tensor([1.1878], requires_grad=True) tensor([1.7523], requires_grad=True)
# tensor([1.1861], requires_grad=True) tensor([1.7554], requires_grad=True)
# tensor([1.1844], requires_grad=True) tensor([1.7586], requires_grad=True)
# tensor([1.1827], requires_grad=True) tensor([1.7616], requires_grad=True)
# tensor([1.1811], requires_grad=True) tensor([1.7647], requires_grad=True)
# tensor([1.1794], requires_grad=True) tensor([1.7676], requires_grad=True)
# tensor([1.1778], requires_grad=True) tensor([1.7706], requires_grad=True)
# tensor([1.1762], requires_grad=True) tensor([1.7735], requires_grad=True)
# tensor([1.1747], requires_grad=True) tensor([1.7764], requires_grad=True)
# tensor([1.1731], requires_grad=True) tensor([1.7792], requires_grad=True)
# tensor([1.1716], requires_grad=True) tensor([1.7820], requires_grad=True)
# tensor([1.1701], requires_grad=True) tensor([1.7848], requires_grad=True)
# tensor([1.1686], requires_grad=True) tensor([1.7875], requires_grad=True)
# tensor([1.1671], requires_grad=True) tensor([1.7902], requires_grad=True)
# tensor([1.1657], requires_grad=True) tensor([1.7929], requires_grad=True)
# tensor([1.1642], requires_grad=True) tensor([1.7955], requires_grad=True)
# tensor([1.1628], requires_grad=True) tensor([1.7981], requires_grad=True)
# tensor([1.1614], requires_grad=True) tensor([1.8007], requires_grad=True)
# tensor([1.1601], requires_grad=True) tensor([1.8032], requires_grad=True)
# tensor([1.1587], requires_grad=True) tensor([1.8057], requires_grad=True)
# tensor([1.1574], requires_grad=True) tensor([1.8081], requires_grad=True)
# tensor([1.1560], requires_grad=True) tensor([1.8106], requires_grad=True)
# tensor([1.1547], requires_grad=True) tensor([1.8130], requires_grad=True)
# tensor([1.1535], requires_grad=True) tensor([1.8153], requires_grad=True)
# tensor([1.1522], requires_grad=True) tensor([1.8177], requires_grad=True)
# tensor([1.1509], requires_grad=True) tensor([1.8200], requires_grad=True)
# tensor([1.1497], requires_grad=True) tensor([1.8222], requires_grad=True)
# tensor([1.1485], requires_grad=True) tensor([1.8245], requires_grad=True)
# tensor([1.1473], requires_grad=True) tensor([1.8267], requires_grad=True)
# tensor([1.1461], requires_grad=True) tensor([1.8289], requires_grad=True)
# tensor([1.1449], requires_grad=True) tensor([1.8310], requires_grad=True)
# tensor([1.1437], requires_grad=True) tensor([1.8332], requires_grad=True)
# tensor([1.1426], requires_grad=True) tensor([1.8353], requires_grad=True)
# tensor([1.1415], requires_grad=True) tensor([1.8373], requires_grad=True)
# tensor([1.1403], requires_grad=True) tensor([1.8394], requires_grad=True)
# tensor([1.1392], requires_grad=True) tensor([1.8414], requires_grad=True)
# tensor([1.1382], requires_grad=True) tensor([1.8434], requires_grad=True)
# tensor([1.1371], requires_grad=True) tensor([1.8454], requires_grad=True)
# tensor([1.1360], requires_grad=True) tensor([1.8473], requires_grad=True)
# tensor([1.1350], requires_grad=True) tensor([1.8492], requires_grad=True)
# tensor([1.1340], requires_grad=True) tensor([1.8511], requires_grad=True)
# tensor([1.1329], requires_grad=True) tensor([1.8530], requires_grad=True)
# tensor([1.1319], requires_grad=True) tensor([1.8548], requires_grad=True)
# tensor([1.1309], requires_grad=True) tensor([1.8567], requires_grad=True)
# tensor([1.1300], requires_grad=True) tensor([1.8585], requires_grad=True)
# tensor([1.1290], requires_grad=True) tensor([1.8602], requires_grad=True)
# tensor([1.1280], requires_grad=True) tensor([1.8620], requires_grad=True)
# tensor([1.1271], requires_grad=True) tensor([1.8637], requires_grad=True)
# tensor([1.1262], requires_grad=True) tensor([1.8654], requires_grad=True)
# tensor([1.1253], requires_grad=True) tensor([1.8671], requires_grad=True)
# tensor([1.1244], requires_grad=True) tensor([1.8688], requires_grad=True)
# tensor([1.1235], requires_grad=True) tensor([1.8704], requires_grad=True)
# tensor([1.1226], requires_grad=True) tensor([1.8720], requires_grad=True)
# tensor([1.1217], requires_grad=True) tensor([1.8736], requires_grad=True)
# tensor([1.1208], requires_grad=True) tensor([1.8752], requires_grad=True)
# tensor([1.1200], requires_grad=True) tensor([1.8767], requires_grad=True)
# tensor([1.1192], requires_grad=True) tensor([1.8783], requires_grad=True)
# tensor([1.1183], requires_grad=True) tensor([1.8798], requires_grad=True)
# tensor([1.1175], requires_grad=True) tensor([1.8813], requires_grad=True)
# tensor([1.1167], requires_grad=True) tensor([1.8828], requires_grad=True)
# tensor([1.1159], requires_grad=True) tensor([1.8842], requires_grad=True)
# tensor([1.1151], requires_grad=True) tensor([1.8857], requires_grad=True)
# tensor([1.1144], requires_grad=True) tensor([1.8871], requires_grad=True)
# tensor([1.1136], requires_grad=True) tensor([1.8885], requires_grad=True)
# tensor([1.1129], requires_grad=True) tensor([1.8899], requires_grad=True)
# tensor([1.1121], requires_grad=True) tensor([1.8912], requires_grad=True)
# tensor([1.1114], requires_grad=True) tensor([1.8926], requires_grad=True)
# tensor([1.1107], requires_grad=True) tensor([1.8939], requires_grad=True)
# tensor([1.1099], requires_grad=True) tensor([1.8952], requires_grad=True)
# tensor([1.1092], requires_grad=True) tensor([1.8965], requires_grad=True)
# tensor([1.1085], requires_grad=True) tensor([1.8978], requires_grad=True)
# tensor([1.1079], requires_grad=True) tensor([1.8990], requires_grad=True)
# tensor([1.1072], requires_grad=True) tensor([1.9003], requires_grad=True)
# tensor([1.1065], requires_grad=True) tensor([1.9015], requires_grad=True)
# tensor([1.1058], requires_grad=True) tensor([1.9027], requires_grad=True)
# tensor([1.1052], requires_grad=True) tensor([1.9039], requires_grad=True)
# tensor([1.1045], requires_grad=True) tensor([1.9051], requires_grad=True)
# tensor([1.1039], requires_grad=True) tensor([1.9063], requires_grad=True)
# tensor([1.1033], requires_grad=True) tensor([1.9074], requires_grad=True)
# tensor([1.1027], requires_grad=True) tensor([1.9086], requires_grad=True)
# tensor([1.1021], requires_grad=True) tensor([1.9097], requires_grad=True)
# tensor([1.1015], requires_grad=True) tensor([1.9108], requires_grad=True)
# tensor([1.1009], requires_grad=True) tensor([1.9119], requires_grad=True)
# tensor([1.1003], requires_grad=True) tensor([1.9129], requires_grad=True)
# tensor([1.0997], requires_grad=True) tensor([1.9140], requires_grad=True)
# tensor([1.0991], requires_grad=True) tensor([1.9151], requires_grad=True)
# tensor([1.0986], requires_grad=True) tensor([1.9161], requires_grad=True)
# tensor([1.0980], requires_grad=True) tensor([1.9171], requires_grad=True)
# tensor([1.0975], requires_grad=True) tensor([1.9181], requires_grad=True)
# tensor([1.0969], requires_grad=True) tensor([1.9191], requires_grad=True)
# tensor([1.0964], requires_grad=True) tensor([1.9201], requires_grad=True)
# tensor([1.0958], requires_grad=True) tensor([1.9211], requires_grad=True)
# tensor([1.0953], requires_grad=True) tensor([1.9220], requires_grad=True)
# tensor([1.0948], requires_grad=True) tensor([1.9230], requires_grad=True)
# tensor([1.0943], requires_grad=True) tensor([1.9239], requires_grad=True)
# tensor([1.0938], requires_grad=True) tensor([1.9248], requires_grad=True)
# tensor([1.0933], requires_grad=True) tensor([1.9257], requires_grad=True)
# tensor([1.0928], requires_grad=True) tensor([1.9266], requires_grad=True)
# tensor([1.0923], requires_grad=True) tensor([1.9275], requires_grad=True)
# tensor([1.0919], requires_grad=True) tensor([1.9284], requires_grad=True)
# tensor([1.0914], requires_grad=True) tensor([1.9293], requires_grad=True)
# tensor([1.0909], requires_grad=True) tensor([1.9301], requires_grad=True)
# tensor([1.0905], requires_grad=True) tensor([1.9310], requires_grad=True)
# tensor([1.0900], requires_grad=True) tensor([1.9318], requires_grad=True)
# tensor([1.0896], requires_grad=True) tensor([1.9326], requires_grad=True)
# tensor([1.0891], requires_grad=True) tensor([1.9334], requires_grad=True)
# tensor([1.0887], requires_grad=True) tensor([1.9342], requires_grad=True)
# tensor([1.0883], requires_grad=True) tensor([1.9350], requires_grad=True)
# tensor([1.0878], requires_grad=True) tensor([1.9358], requires_grad=True)
# tensor([1.0874], requires_grad=True) tensor([1.9365], requires_grad=True)
# tensor([1.0870], requires_grad=True) tensor([1.9373], requires_grad=True)
# tensor([1.0866], requires_grad=True) tensor([1.9380], requires_grad=True)
# tensor([1.0862], requires_grad=True) tensor([1.9388], requires_grad=True)
# tensor([1.0858], requires_grad=True) tensor([1.9395], requires_grad=True)
# tensor([1.0854], requires_grad=True) tensor([1.9402], requires_grad=True)
# tensor([1.0850], requires_grad=True) tensor([1.9409], requires_grad=True)
# tensor([1.0846], requires_grad=True) tensor([1.9416], requires_grad=True)
# tensor([1.0843], requires_grad=True) tensor([1.9423], requires_grad=True)
# tensor([1.0839], requires_grad=True) tensor([1.9430], requires_grad=True)
# tensor([1.0835], requires_grad=True) tensor([1.9437], requires_grad=True)
# tensor([1.0832], requires_grad=True) tensor([1.9443], requires_grad=True)
# tensor([1.0828], requires_grad=True) tensor([1.9450], requires_grad=True)
# tensor([1.0825], requires_grad=True) tensor([1.9456], requires_grad=True)
# tensor([1.0821], requires_grad=True) tensor([1.9463], requires_grad=True)
# tensor([1.0818], requires_grad=True) tensor([1.9469], requires_grad=True)
# tensor([1.0814], requires_grad=True) tensor([1.9475], requires_grad=True)
# tensor([1.0811], requires_grad=True) tensor([1.9482], requires_grad=True)
# tensor([1.0808], requires_grad=True) tensor([1.9488], requires_grad=True)
# tensor([1.0804], requires_grad=True) tensor([1.9494], requires_grad=True)
# tensor([1.0801], requires_grad=True) tensor([1.9499], requires_grad=True)
# tensor([1.0798], requires_grad=True) tensor([1.9505], requires_grad=True)
# tensor([1.0795], requires_grad=True) tensor([1.9511], requires_grad=True)
# tensor([1.0792], requires_grad=True) tensor([1.9517], requires_grad=True)
# tensor([1.0789], requires_grad=True) tensor([1.9522], requires_grad=True)
# tensor([1.0786], requires_grad=True) tensor([1.9528], requires_grad=True)
# tensor([1.0783], requires_grad=True) tensor([1.9533], requires_grad=True)
# tensor([1.0780], requires_grad=True) tensor([1.9539], requires_grad=True)
# tensor([1.0777], requires_grad=True) tensor([1.9544], requires_grad=True)
# tensor([1.0774], requires_grad=True) tensor([1.9549], requires_grad=True)
# tensor([1.0771], requires_grad=True) tensor([1.9554], requires_grad=True)
# tensor([1.0768], requires_grad=True) tensor([1.9559], requires_grad=True)
# tensor([1.0766], requires_grad=True) tensor([1.9565], requires_grad=True)
# tensor([1.0763], requires_grad=True) tensor([1.9570], requires_grad=True)
# tensor([1.0760], requires_grad=True) tensor([1.9574], requires_grad=True)
# tensor([1.0758], requires_grad=True) tensor([1.9579], requires_grad=True)
# tensor([1.0755], requires_grad=True) tensor([1.9584], requires_grad=True)
# tensor([1.0753], requires_grad=True) tensor([1.9589], requires_grad=True)
# tensor([1.0750], requires_grad=True) tensor([1.9593], requires_grad=True)
# tensor([1.0747], requires_grad=True) tensor([1.9598], requires_grad=True)
# tensor([1.0745], requires_grad=True) tensor([1.9603], requires_grad=True)
# tensor([1.0743], requires_grad=True) tensor([1.9607], requires_grad=True)
# tensor([1.0740], requires_grad=True) tensor([1.9611], requires_grad=True)
# tensor([1.0738], requires_grad=True) tensor([1.9616], requires_grad=True)
# tensor([1.0735], requires_grad=True) tensor([1.9620], requires_grad=True)
# tensor([1.0733], requires_grad=True) tensor([1.9624], requires_grad=True)
# tensor([1.0731], requires_grad=True) tensor([1.9629], requires_grad=True)
# tensor([1.0729], requires_grad=True) tensor([1.9633], requires_grad=True)
# tensor([1.0726], requires_grad=True) tensor([1.9637], requires_grad=True)
# tensor([1.0724], requires_grad=True) tensor([1.9641], requires_grad=True)
# tensor([1.0722], requires_grad=True) tensor([1.9645], requires_grad=True)
# tensor([1.0720], requires_grad=True) tensor([1.9649], requires_grad=True)
# tensor([1.0718], requires_grad=True) tensor([1.9653], requires_grad=True)
# tensor([1.0716], requires_grad=True) tensor([1.9657], requires_grad=True)
# tensor([1.0714], requires_grad=True) tensor([1.9660], requires_grad=True)
# tensor([1.0712], requires_grad=True) tensor([1.9664], requires_grad=True)
# tensor([1.0710], requires_grad=True) tensor([1.9668], requires_grad=True)
# tensor([1.0708], requires_grad=True) tensor([1.9671], requires_grad=True)
# tensor([1.0706], requires_grad=True) tensor([1.9675], requires_grad=True)
# tensor([1.0704], requires_grad=True) tensor([1.9678], requires_grad=True)
# tensor([1.0702], requires_grad=True) tensor([1.9682], requires_grad=True)
# tensor([1.0700], requires_grad=True) tensor([1.9685], requires_grad=True)
# tensor([1.0698], requires_grad=True) tensor([1.9689], requires_grad=True)
# tensor([1.0696], requires_grad=True) tensor([1.9692], requires_grad=True)
# tensor([1.0694], requires_grad=True) tensor([1.9695], requires_grad=True)
# tensor([1.0693], requires_grad=True) tensor([1.9699], requires_grad=True)
# tensor([1.0691], requires_grad=True) tensor([1.9702], requires_grad=True)
# tensor([1.0689], requires_grad=True) tensor([1.9705], requires_grad=True)
# tensor([1.0687], requires_grad=True) tensor([1.9708], requires_grad=True)
# tensor([1.0686], requires_grad=True) tensor([1.9711], requires_grad=True)
# tensor([1.0684], requires_grad=True) tensor([1.9714], requires_grad=True)
# tensor([1.0682], requires_grad=True) tensor([1.9718], requires_grad=True)
# tensor([1.0681], requires_grad=True) tensor([1.9721], requires_grad=True)
# tensor([1.0679], requires_grad=True) tensor([1.9723], requires_grad=True)
# tensor([1.0678], requires_grad=True) tensor([1.9726], requires_grad=True)
# tensor([1.0676], requires_grad=True) tensor([1.9729], requires_grad=True)
# tensor([1.0674], requires_grad=True) tensor([1.9732], requires_grad=True)
# tensor([1.0673], requires_grad=True) tensor([1.9735], requires_grad=True)
# tensor([1.0671], requires_grad=True) tensor([1.9738], requires_grad=True)
# tensor([1.0670], requires_grad=True) tensor([1.9740], requires_grad=True)
# tensor([1.0668], requires_grad=True) tensor([1.9743], requires_grad=True)
# tensor([1.0667], requires_grad=True) tensor([1.9746], requires_grad=True)
# tensor([1.0666], requires_grad=True) tensor([1.9748], requires_grad=True)
# tensor([1.0664], requires_grad=True) tensor([1.9751], requires_grad=True)
# tensor([1.0663], requires_grad=True) tensor([1.9753], requires_grad=True)
# tensor([1.0661], requires_grad=True) tensor([1.9756], requires_grad=True)
# tensor([1.0660], requires_grad=True) tensor([1.9758], requires_grad=True)
# tensor([1.0659], requires_grad=True) tensor([1.9761], requires_grad=True)
# tensor([1.0657], requires_grad=True) tensor([1.9763], requires_grad=True)
# tensor([1.0656], requires_grad=True) tensor([1.9766], requires_grad=True)
# tensor([1.0655], requires_grad=True) tensor([1.9768], requires_grad=True)
# tensor([1.0654], requires_grad=True) tensor([1.9770], requires_grad=True)
# tensor([1.0652], requires_grad=True) tensor([1.9773], requires_grad=True)
# tensor([1.0651], requires_grad=True) tensor([1.9775], requires_grad=True)
# tensor([1.0650], requires_grad=True) tensor([1.9777], requires_grad=True)
# tensor([1.0649], requires_grad=True) tensor([1.9779], requires_grad=True)
# tensor([1.0647], requires_grad=True) tensor([1.9782], requires_grad=True)
# tensor([1.0646], requires_grad=True) tensor([1.9784], requires_grad=True)
# tensor([1.0645], requires_grad=True) tensor([1.9786], requires_grad=True)
# tensor([1.0644], requires_grad=True) tensor([1.9788], requires_grad=True)
# tensor([1.0643], requires_grad=True) tensor([1.9790], requires_grad=True)
# tensor([1.0642], requires_grad=True) tensor([1.9792], requires_grad=True)
# tensor([1.0641], requires_grad=True) tensor([1.9794], requires_grad=True)
# tensor([1.0640], requires_grad=True) tensor([1.9796], requires_grad=True)
# tensor([1.0638], requires_grad=True) tensor([1.9798], requires_grad=True)
# tensor([1.0637], requires_grad=True) tensor([1.9800], requires_grad=True)
# tensor([1.0636], requires_grad=True) tensor([1.9802], requires_grad=True)
# tensor([1.0635], requires_grad=True) tensor([1.9804], requires_grad=True)
# tensor([1.0634], requires_grad=True) tensor([1.9806], requires_grad=True)
# tensor([1.0633], requires_grad=True) tensor([1.9808], requires_grad=True)
# tensor([1.0632], requires_grad=True) tensor([1.9809], requires_grad=True)
# tensor([1.0631], requires_grad=True) tensor([1.9811], requires_grad=True)
# tensor([1.0630], requires_grad=True) tensor([1.9813], requires_grad=True)
# tensor([1.0629], requires_grad=True) tensor([1.9815], requires_grad=True)
# tensor([1.0629], requires_grad=True) tensor([1.9816], requires_grad=True)
# tensor([1.0628], requires_grad=True) tensor([1.9818], requires_grad=True)
# tensor([1.0627], requires_grad=True) tensor([1.9820], requires_grad=True)
# tensor([1.0626], requires_grad=True) tensor([1.9821], requires_grad=True)
# tensor([1.0625], requires_grad=True) tensor([1.9823], requires_grad=True)
# tensor([1.0624], requires_grad=True) tensor([1.9825], requires_grad=True)
# tensor([1.0623], requires_grad=True) tensor([1.9826], requires_grad=True)
# tensor([1.0622], requires_grad=True) tensor([1.9828], requires_grad=True)
# tensor([1.0621], requires_grad=True) tensor([1.9829], requires_grad=True)
# tensor([1.0621], requires_grad=True) tensor([1.9831], requires_grad=True)
# tensor([1.0620], requires_grad=True) tensor([1.9832], requires_grad=True)
# tensor([1.0619], requires_grad=True) tensor([1.9834], requires_grad=True)
# tensor([1.0618], requires_grad=True) tensor([1.9835], requires_grad=True)
# tensor([1.0617], requires_grad=True) tensor([1.9837], requires_grad=True)
# tensor([1.0617], requires_grad=True) tensor([1.9838], requires_grad=True)
# tensor([1.0616], requires_grad=True) tensor([1.9840], requires_grad=True)
# tensor([1.0615], requires_grad=True) tensor([1.9841], requires_grad=True)
# tensor([1.0614], requires_grad=True) tensor([1.9842], requires_grad=True)
# tensor([1.0614], requires_grad=True) tensor([1.9844], requires_grad=True)
# tensor([1.0613], requires_grad=True) tensor([1.9845], requires_grad=True)
# tensor([1.0612], requires_grad=True) tensor([1.9846], requires_grad=True)
# tensor([1.0611], requires_grad=True) tensor([1.9848], requires_grad=True)
# tensor([1.0611], requires_grad=True) tensor([1.9849], requires_grad=True)
# tensor([1.0610], requires_grad=True) tensor([1.9850], requires_grad=True)
# tensor([1.0609], requires_grad=True) tensor([1.9852], requires_grad=True)
# tensor([1.0609], requires_grad=True) tensor([1.9853], requires_grad=True)
# tensor([1.0608], requires_grad=True) tensor([1.9854], requires_grad=True)
# tensor([1.0607], requires_grad=True) tensor([1.9855], requires_grad=True)
# tensor([1.0607], requires_grad=True) tensor([1.9856], requires_grad=True)
# tensor([1.0606], requires_grad=True) tensor([1.9858], requires_grad=True)
# tensor([1.0605], requires_grad=True) tensor([1.9859], requires_grad=True)
# tensor([1.0605], requires_grad=True) tensor([1.9860], requires_grad=True)
# tensor([1.0604], requires_grad=True) tensor([1.9861], requires_grad=True)
# tensor([1.0604], requires_grad=True) tensor([1.9862], requires_grad=True)
# tensor([1.0603], requires_grad=True) tensor([1.9863], requires_grad=True)
# tensor([1.0602], requires_grad=True) tensor([1.9864], requires_grad=True)
# tensor([1.0602], requires_grad=True) tensor([1.9865], requires_grad=True)
# tensor([1.0601], requires_grad=True) tensor([1.9867], requires_grad=True)
# tensor([1.0601], requires_grad=True) tensor([1.9868], requires_grad=True)
# tensor([1.0600], requires_grad=True) tensor([1.9869], requires_grad=True)
# tensor([1.0599], requires_grad=True) tensor([1.9870], requires_grad=True)
# tensor([1.0599], requires_grad=True) tensor([1.9871], requires_grad=True)
# tensor([1.0598], requires_grad=True) tensor([1.9872], requires_grad=True)
# tensor([1.0598], requires_grad=True) tensor([1.9873], requires_grad=True)
# tensor([1.0597], requires_grad=True) tensor([1.9874], requires_grad=True)
# tensor([1.0597], requires_grad=True) tensor([1.9875], requires_grad=True)
# tensor([1.0596], requires_grad=True) tensor([1.9876], requires_grad=True)
# tensor([1.0596], requires_grad=True) tensor([1.9876], requires_grad=True)
# tensor([1.0595], requires_grad=True) tensor([1.9877], requires_grad=True)
# tensor([1.0595], requires_grad=True) tensor([1.9878], requires_grad=True)
# tensor([1.0594], requires_grad=True) tensor([1.9879], requires_grad=True)
# tensor([1.0594], requires_grad=True) tensor([1.9880], requires_grad=True)
# tensor([1.0593], requires_grad=True) tensor([1.9881], requires_grad=True)
# tensor([1.0593], requires_grad=True) tensor([1.9882], requires_grad=True)
# tensor([1.0592], requires_grad=True) tensor([1.9883], requires_grad=True)
# tensor([1.0592], requires_grad=True) tensor([1.9883], requires_grad=True)
# tensor([1.0592], requires_grad=True) tensor([1.9884], requires_grad=True)
# tensor([1.0591], requires_grad=True) tensor([1.9885], requires_grad=True)
# tensor([1.0591], requires_grad=True) tensor([1.9886], requires_grad=True)
# tensor([1.0590], requires_grad=True) tensor([1.9887], requires_grad=True)
# tensor([1.0590], requires_grad=True) tensor([1.9887], requires_grad=True)
# tensor([1.0589], requires_grad=True) tensor([1.9888], requires_grad=True)
# tensor([1.0589], requires_grad=True) tensor([1.9889], requires_grad=True)
# tensor([1.0589], requires_grad=True) tensor([1.9890], requires_grad=True)
# tensor([1.0588], requires_grad=True) tensor([1.9891], requires_grad=True)
# tensor([1.0588], requires_grad=True) tensor([1.9891], requires_grad=True)
# tensor([1.0587], requires_grad=True) tensor([1.9892], requires_grad=True)
# tensor([1.0587], requires_grad=True) tensor([1.9893], requires_grad=True)
# tensor([1.0587], requires_grad=True) tensor([1.9893], requires_grad=True)
# tensor([1.0586], requires_grad=True) tensor([1.9894], requires_grad=True)
# tensor([1.0586], requires_grad=True) tensor([1.9895], requires_grad=True)
# tensor([1.0585], requires_grad=True) tensor([1.9895], requires_grad=True)
# tensor([1.0585], requires_grad=True) tensor([1.9896], requires_grad=True)
# tensor([1.0585], requires_grad=True) tensor([1.9897], requires_grad=True)
# tensor([1.0584], requires_grad=True) tensor([1.9897], requires_grad=True)
# tensor([1.0584], requires_grad=True) tensor([1.9898], requires_grad=True)
# tensor([1.0584], requires_grad=True) tensor([1.9899], requires_grad=True)
# tensor([1.0583], requires_grad=True) tensor([1.9899], requires_grad=True)
# tensor([1.0583], requires_grad=True) tensor([1.9900], requires_grad=True)
# tensor([1.0583], requires_grad=True) tensor([1.9901], requires_grad=True)
# tensor([1.0582], requires_grad=True) tensor([1.9901], requires_grad=True)
# tensor([1.0582], requires_grad=True) tensor([1.9902], requires_grad=True)
# tensor([1.0582], requires_grad=True) tensor([1.9902], requires_grad=True)
# tensor([1.0581], requires_grad=True) tensor([1.9903], requires_grad=True)
# tensor([1.0581], requires_grad=True) tensor([1.9904], requires_grad=True)
# tensor([1.0581], requires_grad=True) tensor([1.9904], requires_grad=True)
# tensor([1.0580], requires_grad=True) tensor([1.9905], requires_grad=True)
# tensor([1.0580], requires_grad=True) tensor([1.9905], requires_grad=True)
# tensor([1.0580], requires_grad=True) tensor([1.9906], requires_grad=True)
# tensor([1.0580], requires_grad=True) tensor([1.9906], requires_grad=True)
# tensor([1.0579], requires_grad=True) tensor([1.9907], requires_grad=True)
# tensor([1.0579], requires_grad=True) tensor([1.9907], requires_grad=True)
# tensor([1.0579], requires_grad=True) tensor([1.9908], requires_grad=True)
# tensor([1.0578], requires_grad=True) tensor([1.9908], requires_grad=True)
# tensor([1.0578], requires_grad=True) tensor([1.9909], requires_grad=True)
# tensor([1.0578], requires_grad=True) tensor([1.9909], requires_grad=True)
# tensor([1.0578], requires_grad=True) tensor([1.9910], requires_grad=True)
# tensor([1.0577], requires_grad=True) tensor([1.9910], requires_grad=True)
# tensor([1.0577], requires_grad=True) tensor([1.9911], requires_grad=True)
# tensor([1.0577], requires_grad=True) tensor([1.9911], requires_grad=True)
# tensor([1.0577], requires_grad=True) tensor([1.9912], requires_grad=True)
# tensor([1.0576], requires_grad=True) tensor([1.9912], requires_grad=True)
# tensor([1.0576], requires_grad=True) tensor([1.9913], requires_grad=True)
# tensor([1.0576], requires_grad=True) tensor([1.9913], requires_grad=True)
# tensor([1.0576], requires_grad=True) tensor([1.9914], requires_grad=True)
# tensor([1.0575], requires_grad=True) tensor([1.9914], requires_grad=True)
# tensor([1.0575], requires_grad=True) tensor([1.9914], requires_grad=True)
# tensor([1.0575], requires_grad=True) tensor([1.9915], requires_grad=True)
# tensor([1.0575], requires_grad=True) tensor([1.9915], requires_grad=True)
# tensor([1.0574], requires_grad=True) tensor([1.9916], requires_grad=True)
# tensor([1.0574], requires_grad=True) tensor([1.9916], requires_grad=True)
# tensor([1.0574], requires_grad=True) tensor([1.9917], requires_grad=True)
# tensor([1.0574], requires_grad=True) tensor([1.9917], requires_grad=True)
# tensor([1.0574], requires_grad=True) tensor([1.9917], requires_grad=True)
# tensor([1.0573], requires_grad=True) tensor([1.9918], requires_grad=True)
# tensor([1.0573], requires_grad=True) tensor([1.9918], requires_grad=True)
# tensor([1.0573], requires_grad=True) tensor([1.9918], requires_grad=True)
# tensor([1.0573], requires_grad=True) tensor([1.9919], requires_grad=True)
# tensor([1.0573], requires_grad=True) tensor([1.9919], requires_grad=True)
# tensor([1.0572], requires_grad=True) tensor([1.9920], requires_grad=True)
# tensor([1.0572], requires_grad=True) tensor([1.9920], requires_grad=True)
# tensor([1.0572], requires_grad=True) tensor([1.9920], requires_grad=True)
# tensor([1.0572], requires_grad=True) tensor([1.9921], requires_grad=True)
# tensor([1.0572], requires_grad=True) tensor([1.9921], requires_grad=True)
# tensor([1.0571], requires_grad=True) tensor([1.9921], requires_grad=True)
# tensor([1.0571], requires_grad=True) tensor([1.9922], requires_grad=True)
# tensor([1.0571], requires_grad=True) tensor([1.9922], requires_grad=True)
# tensor([1.0571], requires_grad=True) tensor([1.9922], requires_grad=True)
# tensor([1.0571], requires_grad=True) tensor([1.9923], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9923], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9923], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9924], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9924], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9924], requires_grad=True)
# tensor([1.0570], requires_grad=True) tensor([1.9924], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9925], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9925], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9925], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9926], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9926], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9926], requires_grad=True)
# tensor([1.0569], requires_grad=True) tensor([1.9926], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9927], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9927], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9927], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9927], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9928], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9928], requires_grad=True)
# tensor([1.0568], requires_grad=True) tensor([1.9928], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9928], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9929], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9929], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9929], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9929], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9930], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9930], requires_grad=True)
# tensor([1.0567], requires_grad=True) tensor([1.9930], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9930], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9931], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9931], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9931], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9931], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9931], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9932], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9932], requires_grad=True)
# tensor([1.0566], requires_grad=True) tensor([1.9932], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9932], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9932], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9933], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9933], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9933], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9933], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9933], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0565], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9934], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9935], requires_grad=True)
# tensor([1.0564], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9936], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9937], requires_grad=True)
# tensor([1.0563], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9938], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0562], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9939], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9940], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0561], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9941], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9942], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0560], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9943], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9944], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# tensor([1.0559], requires_grad=True) tensor([1.9945], requires_grad=True)
# ...
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0558], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)
# tensor([1.0557], requires_grad=True) tensor([1.9947], requires_grad=True)

# %%
print(loss)
# Out:
# tensor(0.0009, grad_fn=<MseLossBackward0>)

# %%
# Converting to numpy using detach since gradient is being computed 
print(loss.detach().cpu().numpy())
# Out:
# 0.00092545414
