# %%
import torch 
from torch import nn

# %%
# Define the linear regression model with the pytorch `nn.Module` class

# %%
class ManualLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        #Make `b` and `w` be the parameters of the model
        #Wrap them with `nn.Parameter` 
        self.b = nn.Parameter(torch.randn(1,
                                        requires_grad=True,
                                        dtype=torch.float))
        self.w = nn.Parameter(torch.randn(1,
                                        requires_grad=True,
                                        dtype=torch.float))
    def forward(self, x):
        # Compute the outputs /predictions
        return self.b + self.w*x

# %%
#Example to construct a object
dummy = ManualLinearRegression()
dummy.parameters()
print(dummy.parameters())
print(list(dummy.parameters()))
# Out:
# <generator object Module.parameters at 0x7fd8a8d56660>
# [Parameter containing:
# tensor([2.1423], requires_grad=True), Parameter containing:
# tensor([0.8725], requires_grad=True)]

# %%
print(dummy.state_dict())
# Out:
# OrderedDict([('b', tensor([2.1423])), ('w', tensor([0.8725]))])

# %%
#Data generation 
import numpy as np
import torch 


true_b = 1
true_w = 2 
N = 100

# set the random seed for numpy 
np.random.seed(43)

x= np.random.rand(N,1)
epsilon = (.1 * np.random.rand(N,1))

y = true_b + true_w *x + epsilon

# Generate training and validating sets 
idx = np.arange(N)
np.random.shuffle(idx)

# Use first 80 randowm indices for train
train_idx = idx[:int(N*.8)]
val_idx = idx[int(N*.8):]

# Generate train and validation sets
x_train, y_train = x[train_idx], y[train_idx]
x_val, y_val = x[val_idx], y[val_idx]

# Data preparation 
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Tranform the data from numpy array to torch tensor
x_train_tensor = torch.as_tensor(x_train).float().to(device)
y_train_tensor = torch.as_tensor(y_train).float().to(device)

# %%
# Sets learning rate
lr = 0.1 

# Step 0 : Initialize parameters 'b' and 'w' randomly
torch.manual_seed(42)

# Create a model and send it at once to the device
model = ManualLinearRegression().to(device) # 1)

# Define a SGD optimizer to update the parameters
#optimizer = torch.optim.SGD([b,w], lr=lr)
optimizer = torch.optim.SGD(model.parameters(),lr=lr)


#Define a MSE loss function 
loss_fn = nn.MSELoss(reduction="mean")  


# Define number of epochs 
n_epochs=1000

for epoch in range(n_epochs): 
    model.train()  #2)
    # Step 1: Computes the model's predicted output - forward pass
    # No more manula prediction 
    #yhat = b + w*x_train_tensor 
    yhat = model(x_train_tensor)  #3)
    
    # Step 2: Computes the loss
    # No more manual loss
    # error = (yhat - y_train_tensor)
    # loss = (error**2).mean()
    loss = loss_fn(yhat, y_train_tensor) #2
    
    # Step 3: Computes gradients for both 'b' and 'w' parameters
    loss.backward()
    
    # Step 4: Updates parameters using gradients and the learning rate
    # No more manual update
    # with torch.no_grade():
    #    b-=lr*b.grad
    #    w-=lr*w.grad
    optimizer.step()
    
    
    # Graident Zeroing
    # No more telling pytorch to let gradients go 
    #b.grad.zero()
    #w.grad.zero()
    optimizer.zero_grad()
    print(model.state_dict())

#print(b,w)
#Inspect the parameters using its state_dict
print(model.state_dict())
# Out:
# OrderedDict([('b', tensor([0.6706])), ('w', tensor([0.3299]))])
# OrderedDict([('b', tensor([0.9172])), ('w', tensor([0.4832]))])
# OrderedDict([('b', tensor([1.0989])), ('w', tensor([0.6008]))])
# OrderedDict([('b', tensor([1.2323])), ('w', tensor([0.6919]))])
# OrderedDict([('b', tensor([1.3297])), ('w', tensor([0.7632]))])
# OrderedDict([('b', tensor([1.4003])), ('w', tensor([0.8197]))])
# OrderedDict([('b', tensor([1.4511])), ('w', tensor([0.8651]))])
# OrderedDict([('b', tensor([1.4871])), ('w', tensor([0.9022]))])
# OrderedDict([('b', tensor([1.5121])), ('w', tensor([0.9331]))])
# OrderedDict([('b', tensor([1.5290])), ('w', tensor([0.9593]))])
# OrderedDict([('b', tensor([1.5398])), ('w', tensor([0.9820]))])
# OrderedDict([('b', tensor([1.5462])), ('w', tensor([1.0021]))])
# OrderedDict([('b', tensor([1.5492])), ('w', tensor([1.0201]))])
# OrderedDict([('b', tensor([1.5498])), ('w', tensor([1.0366]))])
# OrderedDict([('b', tensor([1.5486])), ('w', tensor([1.0519]))])
# OrderedDict([('b', tensor([1.5460])), ('w', tensor([1.0663]))])
# OrderedDict([('b', tensor([1.5426])), ('w', tensor([1.0800]))])
# OrderedDict([('b', tensor([1.5384])), ('w', tensor([1.0931]))])
# OrderedDict([('b', tensor([1.5337])), ('w', tensor([1.1057]))])
# OrderedDict([('b', tensor([1.5287])), ('w', tensor([1.1179]))])
# OrderedDict([('b', tensor([1.5234])), ('w', tensor([1.1298]))])
# OrderedDict([('b', tensor([1.5180])), ('w', tensor([1.1414]))])
# OrderedDict([('b', tensor([1.5125])), ('w', tensor([1.1527]))])
# OrderedDict([('b', tensor([1.5069])), ('w', tensor([1.1639]))])
# OrderedDict([('b', tensor([1.5013])), ('w', tensor([1.1749]))])
# OrderedDict([('b', tensor([1.4957])), ('w', tensor([1.1856]))])
# OrderedDict([('b', tensor([1.4901])), ('w', tensor([1.1962]))])
# OrderedDict([('b', tensor([1.4846])), ('w', tensor([1.2067]))])
# OrderedDict([('b', tensor([1.4791])), ('w', tensor([1.2170]))])
# OrderedDict([('b', tensor([1.4736])), ('w', tensor([1.2271]))])
# OrderedDict([('b', tensor([1.4683])), ('w', tensor([1.2372]))])
# OrderedDict([('b', tensor([1.4629])), ('w', tensor([1.2470]))])
# OrderedDict([('b', tensor([1.4577])), ('w', tensor([1.2568]))])
# OrderedDict([('b', tensor([1.4524])), ('w', tensor([1.2664]))])
# OrderedDict([('b', tensor([1.4473])), ('w', tensor([1.2759]))])
# OrderedDict([('b', tensor([1.4422])), ('w', tensor([1.2852]))])
# OrderedDict([('b', tensor([1.4372])), ('w', tensor([1.2945]))])
# OrderedDict([('b', tensor([1.4322])), ('w', tensor([1.3036]))])
# OrderedDict([('b', tensor([1.4273])), ('w', tensor([1.3126]))])
# OrderedDict([('b', tensor([1.4225])), ('w', tensor([1.3214]))])
# OrderedDict([('b', tensor([1.4177])), ('w', tensor([1.3302]))])
# OrderedDict([('b', tensor([1.4130])), ('w', tensor([1.3388]))])
# OrderedDict([('b', tensor([1.4084])), ('w', tensor([1.3474]))])
# OrderedDict([('b', tensor([1.4038])), ('w', tensor([1.3558]))])
# OrderedDict([('b', tensor([1.3993])), ('w', tensor([1.3641]))])
# OrderedDict([('b', tensor([1.3948])), ('w', tensor([1.3723]))])
# OrderedDict([('b', tensor([1.3904])), ('w', tensor([1.3804]))])
# OrderedDict([('b', tensor([1.3860])), ('w', tensor([1.3884]))])
# OrderedDict([('b', tensor([1.3817])), ('w', tensor([1.3963]))])
# OrderedDict([('b', tensor([1.3775])), ('w', tensor([1.4041]))])
# OrderedDict([('b', tensor([1.3733])), ('w', tensor([1.4118]))])
# OrderedDict([('b', tensor([1.3692])), ('w', tensor([1.4194]))])
# OrderedDict([('b', tensor([1.3651])), ('w', tensor([1.4268]))])
# OrderedDict([('b', tensor([1.3611])), ('w', tensor([1.4342]))])
# OrderedDict([('b', tensor([1.3571])), ('w', tensor([1.4415]))])
# OrderedDict([('b', tensor([1.3532])), ('w', tensor([1.4487]))])
# OrderedDict([('b', tensor([1.3493])), ('w', tensor([1.4558]))])
# OrderedDict([('b', tensor([1.3455])), ('w', tensor([1.4628]))])
# OrderedDict([('b', tensor([1.3417])), ('w', tensor([1.4697]))])
# OrderedDict([('b', tensor([1.3380])), ('w', tensor([1.4766]))])
# OrderedDict([('b', tensor([1.3343])), ('w', tensor([1.4833]))])
# OrderedDict([('b', tensor([1.3307])), ('w', tensor([1.4900]))])
# OrderedDict([('b', tensor([1.3271])), ('w', tensor([1.4965]))])
# OrderedDict([('b', tensor([1.3236])), ('w', tensor([1.5030]))])
# OrderedDict([('b', tensor([1.3201])), ('w', tensor([1.5094]))])
# OrderedDict([('b', tensor([1.3167])), ('w', tensor([1.5157]))])
# OrderedDict([('b', tensor([1.3133])), ('w', tensor([1.5220]))])
# OrderedDict([('b', tensor([1.3099])), ('w', tensor([1.5281]))])
# OrderedDict([('b', tensor([1.3066])), ('w', tensor([1.5342]))])
# OrderedDict([('b', tensor([1.3034])), ('w', tensor([1.5402]))])
# OrderedDict([('b', tensor([1.3001])), ('w', tensor([1.5461]))])
# OrderedDict([('b', tensor([1.2970])), ('w', tensor([1.5519]))])
# OrderedDict([('b', tensor([1.2938])), ('w', tensor([1.5577]))])
# OrderedDict([('b', tensor([1.2907])), ('w', tensor([1.5634]))])
# OrderedDict([('b', tensor([1.2877])), ('w', tensor([1.5690]))])
# OrderedDict([('b', tensor([1.2846])), ('w', tensor([1.5745]))])
# OrderedDict([('b', tensor([1.2817])), ('w', tensor([1.5800]))])
# OrderedDict([('b', tensor([1.2787])), ('w', tensor([1.5854]))])
# OrderedDict([('b', tensor([1.2758])), ('w', tensor([1.5907]))])
# OrderedDict([('b', tensor([1.2730])), ('w', tensor([1.5960]))])
# OrderedDict([('b', tensor([1.2701])), ('w', tensor([1.6012]))])
# OrderedDict([('b', tensor([1.2673])), ('w', tensor([1.6063]))])
# OrderedDict([('b', tensor([1.2646])), ('w', tensor([1.6113]))])
# OrderedDict([('b', tensor([1.2619])), ('w', tensor([1.6163]))])
# OrderedDict([('b', tensor([1.2592])), ('w', tensor([1.6212]))])
# OrderedDict([('b', tensor([1.2565])), ('w', tensor([1.6261]))])
# OrderedDict([('b', tensor([1.2539])), ('w', tensor([1.6309]))])
# OrderedDict([('b', tensor([1.2514])), ('w', tensor([1.6356]))])
# OrderedDict([('b', tensor([1.2488])), ('w', tensor([1.6403]))])
# OrderedDict([('b', tensor([1.2463])), ('w', tensor([1.6449]))])
# OrderedDict([('b', tensor([1.2438])), ('w', tensor([1.6495]))])
# OrderedDict([('b', tensor([1.2414])), ('w', tensor([1.6540]))])
# OrderedDict([('b', tensor([1.2390])), ('w', tensor([1.6584]))])
# OrderedDict([('b', tensor([1.2366])), ('w', tensor([1.6628]))])
# OrderedDict([('b', tensor([1.2342])), ('w', tensor([1.6671]))])
# OrderedDict([('b', tensor([1.2319])), ('w', tensor([1.6713]))])
# OrderedDict([('b', tensor([1.2296])), ('w', tensor([1.6755]))])
# OrderedDict([('b', tensor([1.2273])), ('w', tensor([1.6797]))])
# OrderedDict([('b', tensor([1.2251])), ('w', tensor([1.6838]))])
# OrderedDict([('b', tensor([1.2229])), ('w', tensor([1.6878]))])
# OrderedDict([('b', tensor([1.2207])), ('w', tensor([1.6918]))])
# OrderedDict([('b', tensor([1.2186])), ('w', tensor([1.6958]))])
# OrderedDict([('b', tensor([1.2165])), ('w', tensor([1.6997]))])
# OrderedDict([('b', tensor([1.2144])), ('w', tensor([1.7035]))])
# OrderedDict([('b', tensor([1.2123])), ('w', tensor([1.7073]))])
# OrderedDict([('b', tensor([1.2103])), ('w', tensor([1.7110]))])
# OrderedDict([('b', tensor([1.2083])), ('w', tensor([1.7147]))])
# OrderedDict([('b', tensor([1.2063])), ('w', tensor([1.7184]))])
# OrderedDict([('b', tensor([1.2043])), ('w', tensor([1.7220]))])
# OrderedDict([('b', tensor([1.2024])), ('w', tensor([1.7255]))])
# OrderedDict([('b', tensor([1.2005])), ('w', tensor([1.7290]))])
# OrderedDict([('b', tensor([1.1986])), ('w', tensor([1.7325]))])
# OrderedDict([('b', tensor([1.1967])), ('w', tensor([1.7359]))])
# OrderedDict([('b', tensor([1.1949])), ('w', tensor([1.7392]))])
# OrderedDict([('b', tensor([1.1931])), ('w', tensor([1.7426]))])
# OrderedDict([('b', tensor([1.1913])), ('w', tensor([1.7459]))])
# OrderedDict([('b', tensor([1.1895])), ('w', tensor([1.7491]))])
# OrderedDict([('b', tensor([1.1878])), ('w', tensor([1.7523]))])
# OrderedDict([('b', tensor([1.1861])), ('w', tensor([1.7554]))])
# OrderedDict([('b', tensor([1.1844])), ('w', tensor([1.7586]))])
# OrderedDict([('b', tensor([1.1827])), ('w', tensor([1.7616]))])
# OrderedDict([('b', tensor([1.1811])), ('w', tensor([1.7647]))])
# OrderedDict([('b', tensor([1.1794])), ('w', tensor([1.7676]))])
# OrderedDict([('b', tensor([1.1778])), ('w', tensor([1.7706]))])
# OrderedDict([('b', tensor([1.1762])), ('w', tensor([1.7735]))])
# OrderedDict([('b', tensor([1.1747])), ('w', tensor([1.7764]))])
# OrderedDict([('b', tensor([1.1731])), ('w', tensor([1.7792]))])
# OrderedDict([('b', tensor([1.1716])), ('w', tensor([1.7820]))])
# OrderedDict([('b', tensor([1.1701])), ('w', tensor([1.7848]))])
# OrderedDict([('b', tensor([1.1686])), ('w', tensor([1.7875]))])
# OrderedDict([('b', tensor([1.1671])), ('w', tensor([1.7902]))])
# OrderedDict([('b', tensor([1.1657])), ('w', tensor([1.7929]))])
# OrderedDict([('b', tensor([1.1642])), ('w', tensor([1.7955]))])
# OrderedDict([('b', tensor([1.1628])), ('w', tensor([1.7981]))])
# OrderedDict([('b', tensor([1.1614])), ('w', tensor([1.8007]))])
# OrderedDict([('b', tensor([1.1601])), ('w', tensor([1.8032]))])
# OrderedDict([('b', tensor([1.1587])), ('w', tensor([1.8057]))])
# OrderedDict([('b', tensor([1.1574])), ('w', tensor([1.8081]))])
# OrderedDict([('b', tensor([1.1560])), ('w', tensor([1.8106]))])
# OrderedDict([('b', tensor([1.1547])), ('w', tensor([1.8130]))])
# OrderedDict([('b', tensor([1.1535])), ('w', tensor([1.8153]))])
# OrderedDict([('b', tensor([1.1522])), ('w', tensor([1.8177]))])
# OrderedDict([('b', tensor([1.1509])), ('w', tensor([1.8200]))])
# OrderedDict([('b', tensor([1.1497])), ('w', tensor([1.8222]))])
# OrderedDict([('b', tensor([1.1485])), ('w', tensor([1.8245]))])
# OrderedDict([('b', tensor([1.1473])), ('w', tensor([1.8267]))])
# OrderedDict([('b', tensor([1.1461])), ('w', tensor([1.8289]))])
# OrderedDict([('b', tensor([1.1449])), ('w', tensor([1.8310]))])
# OrderedDict([('b', tensor([1.1437])), ('w', tensor([1.8332]))])
# OrderedDict([('b', tensor([1.1426])), ('w', tensor([1.8353]))])
# OrderedDict([('b', tensor([1.1415])), ('w', tensor([1.8373]))])
# OrderedDict([('b', tensor([1.1403])), ('w', tensor([1.8394]))])
# OrderedDict([('b', tensor([1.1392])), ('w', tensor([1.8414]))])
# OrderedDict([('b', tensor([1.1382])), ('w', tensor([1.8434]))])
# OrderedDict([('b', tensor([1.1371])), ('w', tensor([1.8454]))])
# OrderedDict([('b', tensor([1.1360])), ('w', tensor([1.8473]))])
# OrderedDict([('b', tensor([1.1350])), ('w', tensor([1.8492]))])
# OrderedDict([('b', tensor([1.1340])), ('w', tensor([1.8511]))])
# OrderedDict([('b', tensor([1.1329])), ('w', tensor([1.8530]))])
# OrderedDict([('b', tensor([1.1319])), ('w', tensor([1.8548]))])
# OrderedDict([('b', tensor([1.1309])), ('w', tensor([1.8567]))])
# OrderedDict([('b', tensor([1.1300])), ('w', tensor([1.8585]))])
# OrderedDict([('b', tensor([1.1290])), ('w', tensor([1.8602]))])
# OrderedDict([('b', tensor([1.1280])), ('w', tensor([1.8620]))])
# OrderedDict([('b', tensor([1.1271])), ('w', tensor([1.8637]))])
# OrderedDict([('b', tensor([1.1262])), ('w', tensor([1.8654]))])
# OrderedDict([('b', tensor([1.1253])), ('w', tensor([1.8671]))])
# OrderedDict([('b', tensor([1.1244])), ('w', tensor([1.8688]))])
# OrderedDict([('b', tensor([1.1235])), ('w', tensor([1.8704]))])
# OrderedDict([('b', tensor([1.1226])), ('w', tensor([1.8720]))])
# OrderedDict([('b', tensor([1.1217])), ('w', tensor([1.8736]))])
# OrderedDict([('b', tensor([1.1208])), ('w', tensor([1.8752]))])
# OrderedDict([('b', tensor([1.1200])), ('w', tensor([1.8767]))])
# OrderedDict([('b', tensor([1.1192])), ('w', tensor([1.8783]))])
# OrderedDict([('b', tensor([1.1183])), ('w', tensor([1.8798]))])
# OrderedDict([('b', tensor([1.1175])), ('w', tensor([1.8813]))])
# OrderedDict([('b', tensor([1.1167])), ('w', tensor([1.8828]))])
# OrderedDict([('b', tensor([1.1159])), ('w', tensor([1.8842]))])
# OrderedDict([('b', tensor([1.1151])), ('w', tensor([1.8857]))])
# OrderedDict([('b', tensor([1.1144])), ('w', tensor([1.8871]))])
# OrderedDict([('b', tensor([1.1136])), ('w', tensor([1.8885]))])
# OrderedDict([('b', tensor([1.1129])), ('w', tensor([1.8899]))])
# OrderedDict([('b', tensor([1.1121])), ('w', tensor([1.8912]))])
# OrderedDict([('b', tensor([1.1114])), ('w', tensor([1.8926]))])
# OrderedDict([('b', tensor([1.1107])), ('w', tensor([1.8939]))])
# OrderedDict([('b', tensor([1.1099])), ('w', tensor([1.8952]))])
# OrderedDict([('b', tensor([1.1092])), ('w', tensor([1.8965]))])
# OrderedDict([('b', tensor([1.1085])), ('w', tensor([1.8978]))])
# OrderedDict([('b', tensor([1.1079])), ('w', tensor([1.8990]))])
# OrderedDict([('b', tensor([1.1072])), ('w', tensor([1.9003]))])
# OrderedDict([('b', tensor([1.1065])), ('w', tensor([1.9015]))])
# OrderedDict([('b', tensor([1.1058])), ('w', tensor([1.9027]))])
# OrderedDict([('b', tensor([1.1052])), ('w', tensor([1.9039]))])
# OrderedDict([('b', tensor([1.1045])), ('w', tensor([1.9051]))])
# OrderedDict([('b', tensor([1.1039])), ('w', tensor([1.9063]))])
# OrderedDict([('b', tensor([1.1033])), ('w', tensor([1.9074]))])
# OrderedDict([('b', tensor([1.1027])), ('w', tensor([1.9086]))])
# OrderedDict([('b', tensor([1.1021])), ('w', tensor([1.9097]))])
# OrderedDict([('b', tensor([1.1015])), ('w', tensor([1.9108]))])
# OrderedDict([('b', tensor([1.1009])), ('w', tensor([1.9119]))])
# OrderedDict([('b', tensor([1.1003])), ('w', tensor([1.9129]))])
# OrderedDict([('b', tensor([1.0997])), ('w', tensor([1.9140]))])
# OrderedDict([('b', tensor([1.0991])), ('w', tensor([1.9151]))])
# OrderedDict([('b', tensor([1.0986])), ('w', tensor([1.9161]))])
# OrderedDict([('b', tensor([1.0980])), ('w', tensor([1.9171]))])
# OrderedDict([('b', tensor([1.0975])), ('w', tensor([1.9181]))])
# OrderedDict([('b', tensor([1.0969])), ('w', tensor([1.9191]))])
# OrderedDict([('b', tensor([1.0964])), ('w', tensor([1.9201]))])
# OrderedDict([('b', tensor([1.0958])), ('w', tensor([1.9211]))])
# OrderedDict([('b', tensor([1.0953])), ('w', tensor([1.9220]))])
# OrderedDict([('b', tensor([1.0948])), ('w', tensor([1.9230]))])
# OrderedDict([('b', tensor([1.0943])), ('w', tensor([1.9239]))])
# OrderedDict([('b', tensor([1.0938])), ('w', tensor([1.9248]))])
# OrderedDict([('b', tensor([1.0933])), ('w', tensor([1.9257]))])
# OrderedDict([('b', tensor([1.0928])), ('w', tensor([1.9266]))])
# OrderedDict([('b', tensor([1.0923])), ('w', tensor([1.9275]))])
# OrderedDict([('b', tensor([1.0919])), ('w', tensor([1.9284]))])
# OrderedDict([('b', tensor([1.0914])), ('w', tensor([1.9293]))])
# OrderedDict([('b', tensor([1.0909])), ('w', tensor([1.9301]))])
# OrderedDict([('b', tensor([1.0905])), ('w', tensor([1.9310]))])
# OrderedDict([('b', tensor([1.0900])), ('w', tensor([1.9318]))])
# OrderedDict([('b', tensor([1.0896])), ('w', tensor([1.9326]))])
# OrderedDict([('b', tensor([1.0891])), ('w', tensor([1.9334]))])
# OrderedDict([('b', tensor([1.0887])), ('w', tensor([1.9342]))])
# OrderedDict([('b', tensor([1.0883])), ('w', tensor([1.9350]))])
# OrderedDict([('b', tensor([1.0878])), ('w', tensor([1.9358]))])
# OrderedDict([('b', tensor([1.0874])), ('w', tensor([1.9365]))])
# OrderedDict([('b', tensor([1.0870])), ('w', tensor([1.9373]))])
# OrderedDict([('b', tensor([1.0866])), ('w', tensor([1.9380]))])
# OrderedDict([('b', tensor([1.0862])), ('w', tensor([1.9388]))])
# OrderedDict([('b', tensor([1.0858])), ('w', tensor([1.9395]))])
# OrderedDict([('b', tensor([1.0854])), ('w', tensor([1.9402]))])
# OrderedDict([('b', tensor([1.0850])), ('w', tensor([1.9409]))])
# OrderedDict([('b', tensor([1.0846])), ('w', tensor([1.9416]))])
# OrderedDict([('b', tensor([1.0843])), ('w', tensor([1.9423]))])
# OrderedDict([('b', tensor([1.0839])), ('w', tensor([1.9430]))])
# OrderedDict([('b', tensor([1.0835])), ('w', tensor([1.9437]))])
# OrderedDict([('b', tensor([1.0832])), ('w', tensor([1.9443]))])
# OrderedDict([('b', tensor([1.0828])), ('w', tensor([1.9450]))])
# OrderedDict([('b', tensor([1.0825])), ('w', tensor([1.9456]))])
# OrderedDict([('b', tensor([1.0821])), ('w', tensor([1.9463]))])
# OrderedDict([('b', tensor([1.0818])), ('w', tensor([1.9469]))])
# OrderedDict([('b', tensor([1.0814])), ('w', tensor([1.9475]))])
# OrderedDict([('b', tensor([1.0811])), ('w', tensor([1.9482]))])
# OrderedDict([('b', tensor([1.0808])), ('w', tensor([1.9488]))])
# OrderedDict([('b', tensor([1.0804])), ('w', tensor([1.9494]))])
# OrderedDict([('b', tensor([1.0801])), ('w', tensor([1.9499]))])
# OrderedDict([('b', tensor([1.0798])), ('w', tensor([1.9505]))])
# OrderedDict([('b', tensor([1.0795])), ('w', tensor([1.9511]))])
# OrderedDict([('b', tensor([1.0792])), ('w', tensor([1.9517]))])
# OrderedDict([('b', tensor([1.0789])), ('w', tensor([1.9522]))])
# OrderedDict([('b', tensor([1.0786])), ('w', tensor([1.9528]))])
# OrderedDict([('b', tensor([1.0783])), ('w', tensor([1.9533]))])
# OrderedDict([('b', tensor([1.0780])), ('w', tensor([1.9539]))])
# OrderedDict([('b', tensor([1.0777])), ('w', tensor([1.9544]))])
# OrderedDict([('b', tensor([1.0774])), ('w', tensor([1.9549]))])
# OrderedDict([('b', tensor([1.0771])), ('w', tensor([1.9554]))])
# OrderedDict([('b', tensor([1.0768])), ('w', tensor([1.9559]))])
# OrderedDict([('b', tensor([1.0766])), ('w', tensor([1.9565]))])
# OrderedDict([('b', tensor([1.0763])), ('w', tensor([1.9570]))])
# OrderedDict([('b', tensor([1.0760])), ('w', tensor([1.9574]))])
# OrderedDict([('b', tensor([1.0758])), ('w', tensor([1.9579]))])
# OrderedDict([('b', tensor([1.0755])), ('w', tensor([1.9584]))])
# OrderedDict([('b', tensor([1.0753])), ('w', tensor([1.9589]))])
# OrderedDict([('b', tensor([1.0750])), ('w', tensor([1.9593]))])
# OrderedDict([('b', tensor([1.0747])), ('w', tensor([1.9598]))])
# OrderedDict([('b', tensor([1.0745])), ('w', tensor([1.9603]))])
# OrderedDict([('b', tensor([1.0743])), ('w', tensor([1.9607]))])
# OrderedDict([('b', tensor([1.0740])), ('w', tensor([1.9611]))])
# OrderedDict([('b', tensor([1.0738])), ('w', tensor([1.9616]))])
# OrderedDict([('b', tensor([1.0735])), ('w', tensor([1.9620]))])
# OrderedDict([('b', tensor([1.0733])), ('w', tensor([1.9624]))])
# OrderedDict([('b', tensor([1.0731])), ('w', tensor([1.9629]))])
# OrderedDict([('b', tensor([1.0729])), ('w', tensor([1.9633]))])
# OrderedDict([('b', tensor([1.0726])), ('w', tensor([1.9637]))])
# OrderedDict([('b', tensor([1.0724])), ('w', tensor([1.9641]))])
# OrderedDict([('b', tensor([1.0722])), ('w', tensor([1.9645]))])
# OrderedDict([('b', tensor([1.0720])), ('w', tensor([1.9649]))])
# OrderedDict([('b', tensor([1.0718])), ('w', tensor([1.9653]))])
# OrderedDict([('b', tensor([1.0716])), ('w', tensor([1.9657]))])
# OrderedDict([('b', tensor([1.0714])), ('w', tensor([1.9660]))])
# OrderedDict([('b', tensor([1.0712])), ('w', tensor([1.9664]))])
# OrderedDict([('b', tensor([1.0710])), ('w', tensor([1.9668]))])
# OrderedDict([('b', tensor([1.0708])), ('w', tensor([1.9671]))])
# OrderedDict([('b', tensor([1.0706])), ('w', tensor([1.9675]))])
# OrderedDict([('b', tensor([1.0704])), ('w', tensor([1.9678]))])
# OrderedDict([('b', tensor([1.0702])), ('w', tensor([1.9682]))])
# OrderedDict([('b', tensor([1.0700])), ('w', tensor([1.9685]))])
# OrderedDict([('b', tensor([1.0698])), ('w', tensor([1.9689]))])
# OrderedDict([('b', tensor([1.0696])), ('w', tensor([1.9692]))])
# OrderedDict([('b', tensor([1.0694])), ('w', tensor([1.9695]))])
# OrderedDict([('b', tensor([1.0693])), ('w', tensor([1.9699]))])
# OrderedDict([('b', tensor([1.0691])), ('w', tensor([1.9702]))])
# OrderedDict([('b', tensor([1.0689])), ('w', tensor([1.9705]))])
# OrderedDict([('b', tensor([1.0687])), ('w', tensor([1.9708]))])
# OrderedDict([('b', tensor([1.0686])), ('w', tensor([1.9711]))])
# OrderedDict([('b', tensor([1.0684])), ('w', tensor([1.9714]))])
# OrderedDict([('b', tensor([1.0682])), ('w', tensor([1.9718]))])
# OrderedDict([('b', tensor([1.0681])), ('w', tensor([1.9721]))])
# OrderedDict([('b', tensor([1.0679])), ('w', tensor([1.9723]))])
# OrderedDict([('b', tensor([1.0678])), ('w', tensor([1.9726]))])
# OrderedDict([('b', tensor([1.0676])), ('w', tensor([1.9729]))])
# OrderedDict([('b', tensor([1.0674])), ('w', tensor([1.9732]))])
# OrderedDict([('b', tensor([1.0673])), ('w', tensor([1.9735]))])
# OrderedDict([('b', tensor([1.0671])), ('w', tensor([1.9738]))])
# OrderedDict([('b', tensor([1.0670])), ('w', tensor([1.9740]))])
# OrderedDict([('b', tensor([1.0668])), ('w', tensor([1.9743]))])
# OrderedDict([('b', tensor([1.0667])), ('w', tensor([1.9746]))])
# OrderedDict([('b', tensor([1.0666])), ('w', tensor([1.9748]))])
# OrderedDict([('b', tensor([1.0664])), ('w', tensor([1.9751]))])
# OrderedDict([('b', tensor([1.0663])), ('w', tensor([1.9753]))])
# OrderedDict([('b', tensor([1.0661])), ('w', tensor([1.9756]))])
# OrderedDict([('b', tensor([1.0660])), ('w', tensor([1.9758]))])
# OrderedDict([('b', tensor([1.0659])), ('w', tensor([1.9761]))])
# OrderedDict([('b', tensor([1.0657])), ('w', tensor([1.9763]))])
# OrderedDict([('b', tensor([1.0656])), ('w', tensor([1.9766]))])
# OrderedDict([('b', tensor([1.0655])), ('w', tensor([1.9768]))])
# OrderedDict([('b', tensor([1.0654])), ('w', tensor([1.9770]))])
# OrderedDict([('b', tensor([1.0652])), ('w', tensor([1.9773]))])
# OrderedDict([('b', tensor([1.0651])), ('w', tensor([1.9775]))])
# OrderedDict([('b', tensor([1.0650])), ('w', tensor([1.9777]))])
# OrderedDict([('b', tensor([1.0649])), ('w', tensor([1.9779]))])
# OrderedDict([('b', tensor([1.0647])), ('w', tensor([1.9782]))])
# OrderedDict([('b', tensor([1.0646])), ('w', tensor([1.9784]))])
# OrderedDict([('b', tensor([1.0645])), ('w', tensor([1.9786]))])
# OrderedDict([('b', tensor([1.0644])), ('w', tensor([1.9788]))])
# OrderedDict([('b', tensor([1.0643])), ('w', tensor([1.9790]))])
# OrderedDict([('b', tensor([1.0642])), ('w', tensor([1.9792]))])
# OrderedDict([('b', tensor([1.0641])), ('w', tensor([1.9794]))])
# OrderedDict([('b', tensor([1.0640])), ('w', tensor([1.9796]))])
# OrderedDict([('b', tensor([1.0638])), ('w', tensor([1.9798]))])
# OrderedDict([('b', tensor([1.0637])), ('w', tensor([1.9800]))])
# OrderedDict([('b', tensor([1.0636])), ('w', tensor([1.9802]))])
# OrderedDict([('b', tensor([1.0635])), ('w', tensor([1.9804]))])
# OrderedDict([('b', tensor([1.0634])), ('w', tensor([1.9806]))])
# OrderedDict([('b', tensor([1.0633])), ('w', tensor([1.9808]))])
# OrderedDict([('b', tensor([1.0632])), ('w', tensor([1.9809]))])
# OrderedDict([('b', tensor([1.0631])), ('w', tensor([1.9811]))])
# OrderedDict([('b', tensor([1.0630])), ('w', tensor([1.9813]))])
# OrderedDict([('b', tensor([1.0629])), ('w', tensor([1.9815]))])
# OrderedDict([('b', tensor([1.0629])), ('w', tensor([1.9816]))])
# OrderedDict([('b', tensor([1.0628])), ('w', tensor([1.9818]))])
# OrderedDict([('b', tensor([1.0627])), ('w', tensor([1.9820]))])
# OrderedDict([('b', tensor([1.0626])), ('w', tensor([1.9821]))])
# OrderedDict([('b', tensor([1.0625])), ('w', tensor([1.9823]))])
# OrderedDict([('b', tensor([1.0624])), ('w', tensor([1.9825]))])
# OrderedDict([('b', tensor([1.0623])), ('w', tensor([1.9826]))])
# OrderedDict([('b', tensor([1.0622])), ('w', tensor([1.9828]))])
# OrderedDict([('b', tensor([1.0621])), ('w', tensor([1.9829]))])
# OrderedDict([('b', tensor([1.0621])), ('w', tensor([1.9831]))])
# OrderedDict([('b', tensor([1.0620])), ('w', tensor([1.9832]))])
# OrderedDict([('b', tensor([1.0619])), ('w', tensor([1.9834]))])
# OrderedDict([('b', tensor([1.0618])), ('w', tensor([1.9835]))])
# OrderedDict([('b', tensor([1.0617])), ('w', tensor([1.9837]))])
# OrderedDict([('b', tensor([1.0617])), ('w', tensor([1.9838]))])
# OrderedDict([('b', tensor([1.0616])), ('w', tensor([1.9840]))])
# OrderedDict([('b', tensor([1.0615])), ('w', tensor([1.9841]))])
# OrderedDict([('b', tensor([1.0614])), ('w', tensor([1.9842]))])
# OrderedDict([('b', tensor([1.0614])), ('w', tensor([1.9844]))])
# OrderedDict([('b', tensor([1.0613])), ('w', tensor([1.9845]))])
# OrderedDict([('b', tensor([1.0612])), ('w', tensor([1.9846]))])
# OrderedDict([('b', tensor([1.0611])), ('w', tensor([1.9848]))])
# OrderedDict([('b', tensor([1.0611])), ('w', tensor([1.9849]))])
# OrderedDict([('b', tensor([1.0610])), ('w', tensor([1.9850]))])
# OrderedDict([('b', tensor([1.0609])), ('w', tensor([1.9852]))])
# OrderedDict([('b', tensor([1.0609])), ('w', tensor([1.9853]))])
# OrderedDict([('b', tensor([1.0608])), ('w', tensor([1.9854]))])
# OrderedDict([('b', tensor([1.0607])), ('w', tensor([1.9855]))])
# OrderedDict([('b', tensor([1.0607])), ('w', tensor([1.9856]))])
# OrderedDict([('b', tensor([1.0606])), ('w', tensor([1.9858]))])
# OrderedDict([('b', tensor([1.0605])), ('w', tensor([1.9859]))])
# OrderedDict([('b', tensor([1.0605])), ('w', tensor([1.9860]))])
# OrderedDict([('b', tensor([1.0604])), ('w', tensor([1.9861]))])
# OrderedDict([('b', tensor([1.0604])), ('w', tensor([1.9862]))])
# OrderedDict([('b', tensor([1.0603])), ('w', tensor([1.9863]))])
# OrderedDict([('b', tensor([1.0602])), ('w', tensor([1.9864]))])
# OrderedDict([('b', tensor([1.0602])), ('w', tensor([1.9865]))])
# OrderedDict([('b', tensor([1.0601])), ('w', tensor([1.9867]))])
# OrderedDict([('b', tensor([1.0601])), ('w', tensor([1.9868]))])
# OrderedDict([('b', tensor([1.0600])), ('w', tensor([1.9869]))])
# OrderedDict([('b', tensor([1.0599])), ('w', tensor([1.9870]))])
# OrderedDict([('b', tensor([1.0599])), ('w', tensor([1.9871]))])
# OrderedDict([('b', tensor([1.0598])), ('w', tensor([1.9872]))])
# OrderedDict([('b', tensor([1.0598])), ('w', tensor([1.9873]))])
# OrderedDict([('b', tensor([1.0597])), ('w', tensor([1.9874]))])
# OrderedDict([('b', tensor([1.0597])), ('w', tensor([1.9875]))])
# OrderedDict([('b', tensor([1.0596])), ('w', tensor([1.9876]))])
# OrderedDict([('b', tensor([1.0596])), ('w', tensor([1.9876]))])
# OrderedDict([('b', tensor([1.0595])), ('w', tensor([1.9877]))])
# OrderedDict([('b', tensor([1.0595])), ('w', tensor([1.9878]))])
# OrderedDict([('b', tensor([1.0594])), ('w', tensor([1.9879]))])
# OrderedDict([('b', tensor([1.0594])), ('w', tensor([1.9880]))])
# OrderedDict([('b', tensor([1.0593])), ('w', tensor([1.9881]))])
# OrderedDict([('b', tensor([1.0593])), ('w', tensor([1.9882]))])
# OrderedDict([('b', tensor([1.0592])), ('w', tensor([1.9883]))])
# OrderedDict([('b', tensor([1.0592])), ('w', tensor([1.9883]))])
# OrderedDict([('b', tensor([1.0592])), ('w', tensor([1.9884]))])
# OrderedDict([('b', tensor([1.0591])), ('w', tensor([1.9885]))])
# OrderedDict([('b', tensor([1.0591])), ('w', tensor([1.9886]))])
# OrderedDict([('b', tensor([1.0590])), ('w', tensor([1.9887]))])
# OrderedDict([('b', tensor([1.0590])), ('w', tensor([1.9887]))])
# OrderedDict([('b', tensor([1.0589])), ('w', tensor([1.9888]))])
# OrderedDict([('b', tensor([1.0589])), ('w', tensor([1.9889]))])
# OrderedDict([('b', tensor([1.0589])), ('w', tensor([1.9890]))])
# OrderedDict([('b', tensor([1.0588])), ('w', tensor([1.9891]))])
# OrderedDict([('b', tensor([1.0588])), ('w', tensor([1.9891]))])
# OrderedDict([('b', tensor([1.0587])), ('w', tensor([1.9892]))])
# OrderedDict([('b', tensor([1.0587])), ('w', tensor([1.9893]))])
# OrderedDict([('b', tensor([1.0587])), ('w', tensor([1.9893]))])
# OrderedDict([('b', tensor([1.0586])), ('w', tensor([1.9894]))])
# OrderedDict([('b', tensor([1.0586])), ('w', tensor([1.9895]))])
# OrderedDict([('b', tensor([1.0585])), ('w', tensor([1.9895]))])
# OrderedDict([('b', tensor([1.0585])), ('w', tensor([1.9896]))])
# OrderedDict([('b', tensor([1.0585])), ('w', tensor([1.9897]))])
# OrderedDict([('b', tensor([1.0584])), ('w', tensor([1.9897]))])
# OrderedDict([('b', tensor([1.0584])), ('w', tensor([1.9898]))])
# OrderedDict([('b', tensor([1.0584])), ('w', tensor([1.9899]))])
# OrderedDict([('b', tensor([1.0583])), ('w', tensor([1.9899]))])
# OrderedDict([('b', tensor([1.0583])), ('w', tensor([1.9900]))])
# OrderedDict([('b', tensor([1.0583])), ('w', tensor([1.9901]))])
# OrderedDict([('b', tensor([1.0582])), ('w', tensor([1.9901]))])
# OrderedDict([('b', tensor([1.0582])), ('w', tensor([1.9902]))])
# OrderedDict([('b', tensor([1.0582])), ('w', tensor([1.9902]))])
# OrderedDict([('b', tensor([1.0581])), ('w', tensor([1.9903]))])
# OrderedDict([('b', tensor([1.0581])), ('w', tensor([1.9904]))])
# OrderedDict([('b', tensor([1.0581])), ('w', tensor([1.9904]))])
# OrderedDict([('b', tensor([1.0580])), ('w', tensor([1.9905]))])
# OrderedDict([('b', tensor([1.0580])), ('w', tensor([1.9905]))])
# OrderedDict([('b', tensor([1.0580])), ('w', tensor([1.9906]))])
# OrderedDict([('b', tensor([1.0580])), ('w', tensor([1.9906]))])
# OrderedDict([('b', tensor([1.0579])), ('w', tensor([1.9907]))])
# OrderedDict([('b', tensor([1.0579])), ('w', tensor([1.9907]))])
# OrderedDict([('b', tensor([1.0579])), ('w', tensor([1.9908]))])
# OrderedDict([('b', tensor([1.0578])), ('w', tensor([1.9908]))])
# OrderedDict([('b', tensor([1.0578])), ('w', tensor([1.9909]))])
# OrderedDict([('b', tensor([1.0578])), ('w', tensor([1.9909]))])
# OrderedDict([('b', tensor([1.0578])), ('w', tensor([1.9910]))])
# OrderedDict([('b', tensor([1.0577])), ('w', tensor([1.9910]))])
# OrderedDict([('b', tensor([1.0577])), ('w', tensor([1.9911]))])
# OrderedDict([('b', tensor([1.0577])), ('w', tensor([1.9911]))])
# OrderedDict([('b', tensor([1.0577])), ('w', tensor([1.9912]))])
# OrderedDict([('b', tensor([1.0576])), ('w', tensor([1.9912]))])
# OrderedDict([('b', tensor([1.0576])), ('w', tensor([1.9913]))])
# OrderedDict([('b', tensor([1.0576])), ('w', tensor([1.9913]))])
# OrderedDict([('b', tensor([1.0576])), ('w', tensor([1.9914]))])
# OrderedDict([('b', tensor([1.0575])), ('w', tensor([1.9914]))])
# OrderedDict([('b', tensor([1.0575])), ('w', tensor([1.9914]))])
# OrderedDict([('b', tensor([1.0575])), ('w', tensor([1.9915]))])
# OrderedDict([('b', tensor([1.0575])), ('w', tensor([1.9915]))])
# OrderedDict([('b', tensor([1.0574])), ('w', tensor([1.9916]))])
# OrderedDict([('b', tensor([1.0574])), ('w', tensor([1.9916]))])
# OrderedDict([('b', tensor([1.0574])), ('w', tensor([1.9917]))])
# OrderedDict([('b', tensor([1.0574])), ('w', tensor([1.9917]))])
# OrderedDict([('b', tensor([1.0574])), ('w', tensor([1.9917]))])
# OrderedDict([('b', tensor([1.0573])), ('w', tensor([1.9918]))])
# OrderedDict([('b', tensor([1.0573])), ('w', tensor([1.9918]))])
# OrderedDict([('b', tensor([1.0573])), ('w', tensor([1.9918]))])
# OrderedDict([('b', tensor([1.0573])), ('w', tensor([1.9919]))])
# OrderedDict([('b', tensor([1.0573])), ('w', tensor([1.9919]))])
# OrderedDict([('b', tensor([1.0572])), ('w', tensor([1.9920]))])
# OrderedDict([('b', tensor([1.0572])), ('w', tensor([1.9920]))])
# OrderedDict([('b', tensor([1.0572])), ('w', tensor([1.9920]))])
# OrderedDict([('b', tensor([1.0572])), ('w', tensor([1.9921]))])
# OrderedDict([('b', tensor([1.0572])), ('w', tensor([1.9921]))])
# OrderedDict([('b', tensor([1.0571])), ('w', tensor([1.9921]))])
# OrderedDict([('b', tensor([1.0571])), ('w', tensor([1.9922]))])
# OrderedDict([('b', tensor([1.0571])), ('w', tensor([1.9922]))])
# OrderedDict([('b', tensor([1.0571])), ('w', tensor([1.9922]))])
# OrderedDict([('b', tensor([1.0571])), ('w', tensor([1.9923]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9923]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9923]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9924]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9924]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9924]))])
# OrderedDict([('b', tensor([1.0570])), ('w', tensor([1.9924]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9925]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9925]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9925]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9926]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9926]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9926]))])
# OrderedDict([('b', tensor([1.0569])), ('w', tensor([1.9926]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9927]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9927]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9927]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9927]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9928]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9928]))])
# OrderedDict([('b', tensor([1.0568])), ('w', tensor([1.9928]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9928]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9929]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9929]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9929]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9929]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9930]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9930]))])
# OrderedDict([('b', tensor([1.0567])), ('w', tensor([1.9930]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9930]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9931]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9931]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9931]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9931]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9931]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9932]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9932]))])
# OrderedDict([('b', tensor([1.0566])), ('w', tensor([1.9932]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9932]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9932]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9933]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9933]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9933]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9933]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9933]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0565])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9934]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9935]))])
# OrderedDict([('b', tensor([1.0564])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9936]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9937]))])
# OrderedDict([('b', tensor([1.0563])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9938]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0562])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9939]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9940]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0561])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9941]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9942]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0560])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9943]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9944]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0559])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9945]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# ...
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9946]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0558])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
# OrderedDict([('b', tensor([1.0557])), ('w', tensor([1.9947]))])
